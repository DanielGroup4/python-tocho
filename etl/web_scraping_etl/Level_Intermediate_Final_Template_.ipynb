# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

params = (
    ('make', 'Tesla'),
    ('location', 'San^%^20Francisco,^%^20CA'),
    ('latitude', '37.7749295'),
    ('longitude', '-122.4194155'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %%
results_json
# Out:
# {'total_results_count': 189,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2022,
#   'age_type': 'new',
#   'app': 'web'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1627692552,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EAXKF428426',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXKF428426',
#    'clickoff_url': 'https://www.shift.com/car/c1271376?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224508872,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/30/18/24/2019_tesla_model_3-pic-7333039219005091037-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--HRkmebK1--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/30/18/24/2019_tesla_model_3-pic-7333039219005091037-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$40,950',
#    'price_unformatted': 40950,
#    'mileage': '12,810 Miles',
#    'mileage_unformatted': 12810,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EAXKF428426',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '309098553',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1271376',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1627570782,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1E25GF151823',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1E25GF151823',
#    'clickoff_url': 'https://www.shift.com/car/c1597414?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224362466,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/29/09/11/2016_tesla_model_s-pic-7605334189485156446-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--F2SUQPGb--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/29/09/11/2016_tesla_model_s-pic-7605334189485156446-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2016,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$48,950',
#    'price_unformatted': 48950,
#    'mileage': '44,203 Miles',
#    'mileage_unformatted': 44203,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJSA1E25GF151823',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308955091',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1597414',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': '75D',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1627087610,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA7JF173622',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7JF173622',
#    'clickoff_url': 'https://www.shift.com/car/c170665?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224018978,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/23/19/16/2018_tesla_model_3-pic-3057365977326896593-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--1HueCZkT--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/23/19/16/2018_tesla_model_3-pic-3057365977326896593-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$41,950',
#    'price_unformatted': 41950,
#    'mileage': '20,538 Miles',
#    'mileage_unformatted': 20538,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA7JF173622',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308534929',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c170665',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1626137303,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EAXKF416115',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXKF416115',
#    'clickoff_url': 'https://www.shift.com/car/c1718696?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 223244925,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/12/17/37/2019_tesla_model_3-pic-6944520004537072128-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--R4ezwVxU--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/12/17/37/2019_tesla_model_3-pic-6944520004537072128-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$42,450',
#    'price_unformatted': 42450,
#    'mileage': '7,546 Miles',
#    'mileage_unformatted': 7546,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EAXKF416115',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '307624525',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1718696',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1627657102,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA1JF037910',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1JF037910',
#    'clickoff_url': 'https://www.shift.com/car/c137658?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224463064,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/30/09/07/2018_tesla_model_3-pic-7859106898785680953-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--jU88YkGm--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/30/09/07/2018_tesla_model_3-pic-7859106898785680953-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$41,950',
#    'price_unformatted': 41950,
#    'mileage': '39,885 Miles',
#    'mileage_unformatted': 39885,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA1JF037910',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308216434',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c137658',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1627570782,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA1KF312550',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1KF312550',
#    'clickoff_url': 'https://www.shift.com/car/c1275133?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224362465,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/29/09/11/2019_tesla_model_3-pic-835969349489722532-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--72axE6sx--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/29/09/11/2019_tesla_model_3-pic-835969349489722532-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$41,500',
#    'price_unformatted': 41500,
#    'mileage': '22,334 Miles',
#    'mileage_unformatted': 22334,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA1KF312550',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308955093',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1275133',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1626620222,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA2KF476499',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2KF476499',
#    'clickoff_url': 'https://www.shift.com/car/c1960774?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 223663944,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/18/01/24/2019_tesla_model_3-pic-1582637420595824116-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--yropTr_g--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/18/01/24/2019_tesla_model_3-pic-1582637420595824116-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$42,450',
#    'price_unformatted': 42450,
#    'mileage': '22,077 Miles',
#    'mileage_unformatted': 22077,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA2KF476499',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308086989',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1960774',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1627397837,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA1LF659376',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1LF659376',
#    'clickoff_url': 'https://www.shift.com/car/c1335030?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224206757,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/27/18/26/2020_tesla_model_3-pic-6116595340956390644-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--_qDcbQ3U--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/27/18/26/2020_tesla_model_3-pic-6116595340956390644-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$43,950',
#    'price_unformatted': 43950,
#    'mileage': '8,462 Miles',
#    'mileage_unformatted': 8462,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA1LF659376',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308789705',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1335030',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1627441173,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA3JF172824',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3JF172824',
#    'clickoff_url': 'https://www.shift.com/car/c115879?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224254797,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/27/18/26/2018_tesla_model_3-pic-4118428601217259744-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--lnBGkqtk--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/27/18/26/2018_tesla_model_3-pic-4118428601217259744-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$41,950',
#    'price_unformatted': 41950,
#    'mileage': '23,834 Miles',
#    'mileage_unformatted': 23834,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA3JF172824',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308789713',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c115879',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1627744699,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA3JF035088',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3JF035088',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224549103,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/30/20/44/2018_tesla_model_3-pic-5925265865562404742-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--sVVcMHim--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/30/20/44/2018_tesla_model_3-pic-5925265865562404742-1024x768.jpeg',
#    'lat': 37.9104,
#    'lon': -122.065,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$48,900',
#    'price_unformatted': 48900,
#    'mileage': '19,297 Miles',
#    'mileage_unformatted': 19297,
#    'city': 'Walnut Creek',
#    'state': 'CA',
#    'distance_from_origin': 21,
#    'dealer_name': 'North State Auto Sales',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJ3E1EA3JF035088',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '309143871',
#     'remote_dealer_id': '287296',
#     'dealer_name': None,
#     'remote_sku': '77203',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'Long Range',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1626655286,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA7JF042982',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7JF042982',
#    'clickoff_url': 'https://www.shift.com/car/c127036?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 223690547,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/18/17/06/2018_tesla_model_3-pic-1969199470070695070-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--hH63fJu7--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/18/17/06/2018_tesla_model_3-pic-1969199470070695070-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$42,450',
#    'price_unformatted': 42450,
#    'mileage': '14,989 Miles',
#    'mileage_unformatted': 14989,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA7JF042982',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308146397',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c127036',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1626620222,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA1JF162583',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1JF162583',
#    'clickoff_url': 'https://www.shift.com/car/c120315?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 223663943,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/18/01/24/2018_tesla_model_3-pic-3330053396513549596-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--hBx5wly9--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/18/01/24/2018_tesla_model_3-pic-3330053396513549596-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$40,950',
#    'price_unformatted': 40950,
#    'mileage': '15,222 Miles',
#    'mileage_unformatted': 15222,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA1JF162583',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308086988',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c120315',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1624637605,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1E43JF274450',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1E43JF274450',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 222062829,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/06/24/23/29/2018_tesla_model_s-pic-8968888769742819347-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--jBoUo3yi--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/06/24/23/29/2018_tesla_model_s-pic-8968888769742819347-1024x768.jpeg',
#    'lat': 37.9633,
#    'lon': -122.512,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$87,943',
#    'price_unformatted': 87943,
#    'mileage': '8,885 Miles',
#    'mileage_unformatted': 8885,
#    'city': 'San Rafael',
#    'state': 'CA',
#    'distance_from_origin': 13,
#    'dealer_name': 'Audi Marin And Volkswagen Marin',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJSA1E43JF274450',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '305188414',
#     'remote_dealer_id': '437452',
#     'dealer_name': None,
#     'remote_sku': 'PJF274450',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'P100D',
#    'provider_id': 199,
#    'provider_group_id': 227,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1624554511,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJSA1E43JF236460',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1E43JF236460',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 221990951,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/17/18/33/2018_tesla_model_s-pic-1937626176257225111-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ON6wkIZ0--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/17/18/33/2018_tesla_model_s-pic-1937626176257225111-1024x768.jpeg',
#    'lat': 37.675,
#    'lon': -122.461,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model S',
#    'model_id': 2006,
#    'display_color': '',
#    'price': '$89,995',
#    'price_unformatted': 89995,
#    'mileage': '27,908 Miles',
#    'mileage_unformatted': 27908,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 7,
#    'dealer_name': 'Serramonte Subaru Volkswagen',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 3,
#    'partner_type': 'metasearch',
#    'vin': '5YJSA1E43JF236460',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '306149880',
#     'remote_dealer_id': '387409',
#     'dealer_name': None,
#     'remote_sku': '21D0213A',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'dealer_group_unique_name': None,
#     'dealer_group_uuid': None},
#    'trim': 'P100D',
#    'provider_id': 199,
#    'provider_group_id': 228,
#    'experience': 'local',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': True},
#   {'available_nationwide': False,
#    'created_at': 1627692552,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA3LF740766',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3LF740766',
#    'clickoff_url': 'https://www.shift.com/car/c106164?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224508871,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/30/18/24/2020_tesla_model_3-pic-1552107464397643542-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--hVmhjMsH--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/30/18/24/2020_tesla_model_3-pic-1552107464397643542-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$43,500',
#    'price_unformatted': 43500,
#    'mileage': '15,256 Miles',
#    'mileage_unformatted': 15256,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA3LF740766',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '309098529',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c106164',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1626915021,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA2JF172040',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2JF172040',
#    'clickoff_url': 'https://www.shift.com/car/c133815?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 223858007,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/21/18/42/2018_tesla_model_3-pic-2634505484031904058-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--IZ5RC3hm--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/21/18/42/2018_tesla_model_3-pic-2634505484031904058-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$40,950',
#    'price_unformatted': 40950,
#    'mileage': '14,415 Miles',
#    'mileage_unformatted': 14415,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA2JF172040',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308338090',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c133815',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1623286982,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA6KF483326',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6KF483326',
#    'clickoff_url': 'https://www.shift.com/car/c110936?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 220874699,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/06/09/23/25/2019_tesla_model_3-pic-6436851712061059861-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--1kW4bu47--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/06/09/23/25/2019_tesla_model_3-pic-6436851712061059861-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$40,850',
#    'price_unformatted': 40850,
#    'mileage': '16,295 Miles',
#    'mileage_unformatted': 16295,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA6KF483326',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '304931331',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c110936',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1627441173,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA2KF412978',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2KF412978',
#    'clickoff_url': 'https://www.shift.com/car/c1984364?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224254796,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/27/18/26/2019_tesla_model_3-pic-8870853144196450115-1024x768.jpeg',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ejucJ6Zp--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/27/18/26/2019_tesla_model_3-pic-8870853144196450115-1024x768.jpeg',
#    'lat': 37.6397,
#    'lon': -122.416,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$42,500',
#    'price_unformatted': 42500,
#    'mileage': '32,407 Miles',
#    'mileage_unformatted': 32407,
#    'city': 'South San Francisco',
#    'state': 'CA',
#    'distance_from_origin': 9,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA2KF412978',
#    'provider': None,
#    'provider_name': 'car_gurus',
#    'always_ask_for_zip': False,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '308789724',
#     'remote_dealer_id': '413397',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'remote_sku': 'c1984364',
#     'experience': 'regional',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#    'trim': 'Standard Range',
#    'provider_id': 199,
#    'provider_group_id': 231,
#    'experience': 'regional',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1626845316,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA6LF807618',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6LF807618',
#    'clickoff_url': 'https://www.carmax.com/car/20580501?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 223798924,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20580501/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--eAseaRt0--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20580501/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.6905682959734,
#    'lon': -122.446677657875,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$46,998',
#    'price_unformatted': 46998,
#    'mileage': '5,349 Miles',
#    'mileage_unformatted': 5349,
#    'city': 'Colma',
#    'state': 'CA',
#    'distance_from_origin': 6,
#    'dealer_name': 'CarMax Serramonte - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA6LF807618',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA6LF807618',
#     'remote_dealer_id': '6080',
#     'dealer_name': 'CarMax Serramonte',
#     'remote_sku': '20580501',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_serramonte',
#     'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1627450126,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB4MF937701',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB4MF937701',
#    'clickoff_url': 'https://www.carmax.com/car/21037434?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 224269939,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21037434/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s---PjVqwKD--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21037434/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.500874,
#    'lon': -121.966481,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$60,998',
#    'price_unformatted': 60998,
#    'mileage': '2,692 Miles',
#    'mileage_unformatted': 2692,
#    'city': 'Fremont',
#    'state': 'CA',
#    'distance_from_origin': 31,
#    'dealer_name': 'CarMax Fremont - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB4MF937701',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB4MF937701',
#     'remote_dealer_id': '6071',
#     'dealer_name': 'CarMax Fremont',
#     'remote_sku': '21037434',
#     'experience': 'local',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_fremont',
#     'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': False,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False}],
#  'html': {'search_results': '<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EAXKF428426"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--HRkmebK1--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/30/18/24/2019_tesla_model_3-pic-7333039219005091037-1024x768.jpeg)\' title=\'used 2019 Tesla Model 3 Standard Range Red 5YJ3E1EAXKF428426\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2019 Tesla Model 3 Standard Range</div>\n<div class=\'subtext\'>\n12,810 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Online Only</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$40,950</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $590/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+s#vin=5YJSA1E25GF151823"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--F2SUQPGb--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/29/09/11/2016_tesla_model_s-pic-7605334189485156446-1024x768.jpeg)\' title=\'used 2016 Tesla Model S 75D White 5YJSA1E25GF151823\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'badge price_drop\' data-spot=\'1\'>\nPrice Drop\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2016 Tesla Model S 75D</div>\n<div class=\'subtext\'>\n44,203 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Online Only</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$48,950</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $706/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EA7JF173622"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' data-background-image=\'https://images.autolist.co ...
#   'pagination': '<ul><li class="previous disabled"><a>Previous</a></li><li class="selected"><a>1</a></li><li data-page="2"><a>2</a></li><li data-page="3"><a>3</a></li><li data-page="4"><a>...</a></li><li data-page="8"><a>8</a></li><li data-page="9"><a>9</a></li><li data-page="2" class="next"><a>Next</a></li></ul>'}}

# %%
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
# model
# mileage
# year
# dealer name
# price

# %%
results_json['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1627692552,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EAXKF428426',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXKF428426',
#   'clickoff_url': 'https://www.shift.com/car/c1271376?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224508872,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/30/18/24/2019_tesla_model_3-pic-7333039219005091037-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--HRkmebK1--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/30/18/24/2019_tesla_model_3-pic-7333039219005091037-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$40,950',
#   'price_unformatted': 40950,
#   'mileage': '12,810 Miles',
#   'mileage_unformatted': 12810,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EAXKF428426',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '309098553',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1271376',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard Range',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1627570782,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1E25GF151823',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1E25GF151823',
#   'clickoff_url': 'https://www.shift.com/car/c1597414?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224362466,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/29/09/11/2016_tesla_model_s-pic-7605334189485156446-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--F2SUQPGb--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/29/09/11/2016_tesla_model_s-pic-7605334189485156446-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2016,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$48,950',
#   'price_unformatted': 48950,
#   'mileage': '44,203 Miles',
#   'mileage_unformatted': 44203,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJSA1E25GF151823',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308955091',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1597414',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': '75D',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1627087610,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA7JF173622',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7JF173622',
#   'clickoff_url': 'https://www.shift.com/car/c170665?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224018978,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/23/19/16/2018_tesla_model_3-pic-3057365977326896593-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--1HueCZkT--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/23/19/16/2018_tesla_model_3-pic-3057365977326896593-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$41,950',
#   'price_unformatted': 41950,
#   'mileage': '20,538 Miles',
#   'mileage_unformatted': 20538,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA7JF173622',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308534929',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c170665',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1626137303,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EAXKF416115',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXKF416115',
#   'clickoff_url': 'https://www.shift.com/car/c1718696?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 223244925,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/12/17/37/2019_tesla_model_3-pic-6944520004537072128-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--R4ezwVxU--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/12/17/37/2019_tesla_model_3-pic-6944520004537072128-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$42,450',
#   'price_unformatted': 42450,
#   'mileage': '7,546 Miles',
#   'mileage_unformatted': 7546,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EAXKF416115',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '307624525',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1718696',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard Range',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1627657102,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA1JF037910',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1JF037910',
#   'clickoff_url': 'https://www.shift.com/car/c137658?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224463064,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/30/09/07/2018_tesla_model_3-pic-7859106898785680953-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--jU88YkGm--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/30/09/07/2018_tesla_model_3-pic-7859106898785680953-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$41,950',
#   'price_unformatted': 41950,
#   'mileage': '39,885 Miles',
#   'mileage_unformatted': 39885,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA1JF037910',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308216434',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c137658',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1627570782,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA1KF312550',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1KF312550',
#   'clickoff_url': 'https://www.shift.com/car/c1275133?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224362465,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/29/09/11/2019_tesla_model_3-pic-835969349489722532-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--72axE6sx--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/29/09/11/2019_tesla_model_3-pic-835969349489722532-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$41,500',
#   'price_unformatted': 41500,
#   'mileage': '22,334 Miles',
#   'mileage_unformatted': 22334,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA1KF312550',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308955093',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1275133',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1626620222,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA2KF476499',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2KF476499',
#   'clickoff_url': 'https://www.shift.com/car/c1960774?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 223663944,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/18/01/24/2019_tesla_model_3-pic-1582637420595824116-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--yropTr_g--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/18/01/24/2019_tesla_model_3-pic-1582637420595824116-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$42,450',
#   'price_unformatted': 42450,
#   'mileage': '22,077 Miles',
#   'mileage_unformatted': 22077,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA2KF476499',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308086989',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1960774',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1627397837,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA1LF659376',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1LF659376',
#   'clickoff_url': 'https://www.shift.com/car/c1335030?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224206757,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/27/18/26/2020_tesla_model_3-pic-6116595340956390644-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--_qDcbQ3U--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/27/18/26/2020_tesla_model_3-pic-6116595340956390644-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$43,950',
#   'price_unformatted': 43950,
#   'mileage': '8,462 Miles',
#   'mileage_unformatted': 8462,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA1LF659376',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308789705',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1335030',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1627441173,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA3JF172824',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3JF172824',
#   'clickoff_url': 'https://www.shift.com/car/c115879?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224254797,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/27/18/26/2018_tesla_model_3-pic-4118428601217259744-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--lnBGkqtk--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/27/18/26/2018_tesla_model_3-pic-4118428601217259744-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$41,950',
#   'price_unformatted': 41950,
#   'mileage': '23,834 Miles',
#   'mileage_unformatted': 23834,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA3JF172824',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308789713',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c115879',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1627744699,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA3JF035088',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3JF035088',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224549103,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/30/20/44/2018_tesla_model_3-pic-5925265865562404742-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--sVVcMHim--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/30/20/44/2018_tesla_model_3-pic-5925265865562404742-1024x768.jpeg',
#   'lat': 37.9104,
#   'lon': -122.065,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$48,900',
#   'price_unformatted': 48900,
#   'mileage': '19,297 Miles',
#   'mileage_unformatted': 19297,
#   'city': 'Walnut Creek',
#   'state': 'CA',
#   'distance_from_origin': 21,
#   'dealer_name': 'North State Auto Sales',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJ3E1EA3JF035088',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '309143871',
#    'remote_dealer_id': '287296',
#    'dealer_name': None,
#    'remote_sku': '77203',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'Long Range',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1626655286,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA7JF042982',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7JF042982',
#   'clickoff_url': 'https://www.shift.com/car/c127036?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 223690547,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/18/17/06/2018_tesla_model_3-pic-1969199470070695070-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--hH63fJu7--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/18/17/06/2018_tesla_model_3-pic-1969199470070695070-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$42,450',
#   'price_unformatted': 42450,
#   'mileage': '14,989 Miles',
#   'mileage_unformatted': 14989,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA7JF042982',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308146397',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c127036',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1626620222,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA1JF162583',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA1JF162583',
#   'clickoff_url': 'https://www.shift.com/car/c120315?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 223663943,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/18/01/24/2018_tesla_model_3-pic-3330053396513549596-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--hBx5wly9--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/18/01/24/2018_tesla_model_3-pic-3330053396513549596-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$40,950',
#   'price_unformatted': 40950,
#   'mileage': '15,222 Miles',
#   'mileage_unformatted': 15222,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA1JF162583',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308086988',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c120315',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1624637605,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1E43JF274450',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1E43JF274450',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 222062829,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/06/24/23/29/2018_tesla_model_s-pic-8968888769742819347-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--jBoUo3yi--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/06/24/23/29/2018_tesla_model_s-pic-8968888769742819347-1024x768.jpeg',
#   'lat': 37.9633,
#   'lon': -122.512,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$87,943',
#   'price_unformatted': 87943,
#   'mileage': '8,885 Miles',
#   'mileage_unformatted': 8885,
#   'city': 'San Rafael',
#   'state': 'CA',
#   'distance_from_origin': 13,
#   'dealer_name': 'Audi Marin And Volkswagen Marin',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJSA1E43JF274450',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '305188414',
#    'remote_dealer_id': '437452',
#    'dealer_name': None,
#    'remote_sku': 'PJF274450',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'P100D',
#   'provider_id': 199,
#   'provider_group_id': 227,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1624554511,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJSA1E43JF236460',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1E43JF236460',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 221990951,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/17/18/33/2018_tesla_model_s-pic-1937626176257225111-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ON6wkIZ0--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/17/18/33/2018_tesla_model_s-pic-1937626176257225111-1024x768.jpeg',
#   'lat': 37.675,
#   'lon': -122.461,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$89,995',
#   'price_unformatted': 89995,
#   'mileage': '27,908 Miles',
#   'mileage_unformatted': 27908,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 7,
#   'dealer_name': 'Serramonte Subaru Volkswagen',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 3,
#   'partner_type': 'metasearch',
#   'vin': '5YJSA1E43JF236460',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '306149880',
#    'remote_dealer_id': '387409',
#    'dealer_name': None,
#    'remote_sku': '21D0213A',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'dealer_group_unique_name': None,
#    'dealer_group_uuid': None},
#   'trim': 'P100D',
#   'provider_id': 199,
#   'provider_group_id': 228,
#   'experience': 'local',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': True},
#  {'available_nationwide': False,
#   'created_at': 1627692552,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA3LF740766',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3LF740766',
#   'clickoff_url': 'https://www.shift.com/car/c106164?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224508871,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/30/18/24/2020_tesla_model_3-pic-1552107464397643542-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--hVmhjMsH--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/30/18/24/2020_tesla_model_3-pic-1552107464397643542-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$43,500',
#   'price_unformatted': 43500,
#   'mileage': '15,256 Miles',
#   'mileage_unformatted': 15256,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA3LF740766',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '309098529',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c106164',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1626915021,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA2JF172040',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2JF172040',
#   'clickoff_url': 'https://www.shift.com/car/c133815?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 223858007,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/21/18/42/2018_tesla_model_3-pic-2634505484031904058-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--IZ5RC3hm--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/21/18/42/2018_tesla_model_3-pic-2634505484031904058-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$40,950',
#   'price_unformatted': 40950,
#   'mileage': '14,415 Miles',
#   'mileage_unformatted': 14415,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA2JF172040',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308338090',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c133815',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1623286982,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA6KF483326',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6KF483326',
#   'clickoff_url': 'https://www.shift.com/car/c110936?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 220874699,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/06/09/23/25/2019_tesla_model_3-pic-6436851712061059861-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--1kW4bu47--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/06/09/23/25/2019_tesla_model_3-pic-6436851712061059861-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$40,850',
#   'price_unformatted': 40850,
#   'mileage': '16,295 Miles',
#   'mileage_unformatted': 16295,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA6KF483326',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '304931331',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c110936',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1627441173,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA2KF412978',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2KF412978',
#   'clickoff_url': 'https://www.shift.com/car/c1984364?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224254796,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/27/18/26/2019_tesla_model_3-pic-8870853144196450115-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ejucJ6Zp--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/27/18/26/2019_tesla_model_3-pic-8870853144196450115-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2019,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$42,500',
#   'price_unformatted': 42500,
#   'mileage': '32,407 Miles',
#   'mileage_unformatted': 32407,
#   'city': 'South San Francisco',
#   'state': 'CA',
#   'distance_from_origin': 9,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA2KF412978',
#   'provider': None,
#   'provider_name': 'car_gurus',
#   'always_ask_for_zip': False,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '308789724',
#    'remote_dealer_id': '413397',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'remote_sku': 'c1984364',
#    'experience': 'regional',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#   'trim': 'Standard Range',
#   'provider_id': 199,
#   'provider_group_id': 231,
#   'experience': 'regional',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1626845316,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA6LF807618',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA6LF807618',
#   'clickoff_url': 'https://www.carmax.com/car/20580501?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 223798924,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20580501/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--eAseaRt0--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20580501/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.6905682959734,
#   'lon': -122.446677657875,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$46,998',
#   'price_unformatted': 46998,
#   'mileage': '5,349 Miles',
#   'mileage_unformatted': 5349,
#   'city': 'Colma',
#   'state': 'CA',
#   'distance_from_origin': 6,
#   'dealer_name': 'CarMax Serramonte - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EA6LF807618',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EA6LF807618',
#    'remote_dealer_id': '6080',
#    'dealer_name': 'CarMax Serramonte',
#    'remote_sku': '20580501',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_serramonte',
#    'dealer_uuid': '2bf4fe81-333d-498d-8994-1b7e0d050334',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Standard Range Plus',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1627450126,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB4MF937701',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB4MF937701',
#   'clickoff_url': 'https://www.carmax.com/car/21037434?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 224269939,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21037434/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s---PjVqwKD--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21037434/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.500874,
#   'lon': -121.966481,
#   'year': 2021,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$60,998',
#   'price_unformatted': 60998,
#   'mileage': '2,692 Miles',
#   'mileage_unformatted': 2692,
#   'city': 'Fremont',
#   'state': 'CA',
#   'distance_from_origin': 31,
#   'dealer_name': 'CarMax Fremont - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '5YJ3E1EB4MF937701',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '5YJ3E1EB4MF937701',
#    'remote_dealer_id': '6071',
#    'dealer_name': 'CarMax Fremont',
#    'remote_sku': '21037434',
#    'experience': 'local',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_fremont',
#    'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Long Range',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': False,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False}]

# %%
len(results_json['search_results'])
# Out:
# 20

# %%
result_items = results_json['search_results']

# %%
# starting point for first result
results_json['search_results'][0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1627692552,
#  'recent_price_drop': None,
#  'is_hot': False,
#  'href_target': '/listings/5YJ3E1EAXKF428426',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXKF428426',
#  'clickoff_url': 'https://www.shift.com/car/c1271376?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 224508872,
#  'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/30/18/24/2019_tesla_model_3-pic-7333039219005091037-1024x768.jpeg',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--HRkmebK1--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/30/18/24/2019_tesla_model_3-pic-7333039219005091037-1024x768.jpeg',
#  'lat': 37.6397,
#  'lon': -122.416,
#  'year': 2019,
#  'make': 'Tesla',
#  'model': 'Model 3',
#  'model_id': 2217,
#  'display_color': '',
#  'price': '$40,950',
#  'price_unformatted': 40950,
#  'mileage': '12,810 Miles',
#  'mileage_unformatted': 12810,
#  'city': 'South San Francisco',
#  'state': 'CA',
#  'distance_from_origin': 9,
#  'dealer_name': 'Shift SF - Test Drives Delivered To You',
#  'show_message_box': None,
#  'email_opt_default': True,
#  'show_financing_checkbox': None,
#  'show_new_mileage': False,
#  'show_thankyou_page': False,
#  'show_rsrp': True,
#  'click_off': False,
#  'pre_check_thankyou': True,
#  'cpl_value': 15,
#  'partner_type': 'dealer_direct',
#  'vin': '5YJ3E1EAXKF428426',
#  'provider': None,
#  'provider_name': 'car_gurus',
#  'always_ask_for_zip': False,
#  'listing_id': None,
#  'time_on_market': None,
#  'total_price_change': None,
#  'relative_price_difference': None,
#  'listimate_category': None,
#  'listimate_text': None,
#  'photo_urls': [],
#  'tracking_params': {'id_from_provider': '309098553',
#   'remote_dealer_id': '413397',
#   'dealer_name': 'Shift SF - Test Drives Delivered to You',
#   'remote_sku': 'c1271376',
#   'experience': 'regional',
#   'rooftop_unique_name': None,
#   'rooftop_uuid': None,
#   'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#   'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#   'dealer_group_unique_name': 'shift_cargurus',
#   'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#  'trim': 'Standard Range',
#  'provider_id': 199,
#  'provider_group_id': 231,
#  'experience': 'regional',
#  'regional': True,
#  'badges': {'position0': None, 'position1': None},
#  'quick_picks_eligible': False}

# %%
# model 
results_json['search_results'][0]['model']
# Out:
# 'Model 3'

# %%
# mileage
results_json['search_results'][0]['mileage']
# Out:
# '12,810 Miles'

# %%
# year
results_json['search_results'][0]['year']
# Out:
# 2019

# %%
# dealer name
results_json['search_results'][0]['dealer_name']
# Out:
# 'Shift SF - Test Drives Delivered To You'

# %%
# price
results_json['search_results'][0]['price']
# Out:
# '$40,950'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []

for result in result_items:
    
    # model
    model.append(result['model'])
    
    # mileage
    mileage.append(result['mileage'])
    
    # year
    year.append(result['year']) 
    
    # dealer name
    dealer_name.append(result['dealer_name']) 
    
    # price
    price.append(result['price'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
tesla_df = pd.DataFrame({'Model': model, 'Mileage':mileage, 'Year':year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_df
# Out:
#       Model       Mileage  Year                              Dealer Name  \
# 0   Model 3  12,810 Miles  2019  Shift SF - Test Drives Delivered To You
# 1   Model S  44,203 Miles  2016  Shift SF - Test Drives Delivered To You
# 2   Model 3  20,538 Miles  2018  Shift SF - Test Drives Delivered To You
# 3   Model 3   7,546 Miles  2019  Shift SF - Test Drives Delivered To You
# 4   Model 3  39,885 Miles  2018  Shift SF - Test Drives Delivered To You
# 5   Model 3  22,334 Miles  2019  Shift SF - Test Drives Delivered To You
# 6   Model 3  22,077 Miles  2019  Shift SF - Test Drives Delivered To You
# 7   Model 3   8,462 Miles  2020  Shift SF - Test Drives Delivered To You
# 8   Model 3  23,834 Miles  2018  Shift SF - Test Drives Delivered To You
# 9   Model 3  19,297 Miles  2018                   North State Auto Sales
# 10  Model 3  14,989 Miles  2018  Shift SF - Test Drives Delivered To You
# 11  Model 3  15,222 Miles  2018  Shift SF - Test Drives Delivered To You
# 12  Model S   8,885 Miles  2018          Audi Marin And Volkswagen Marin
# 13  Model S  27,908 Miles  2018             Serramonte Subaru Volkswagen
# 14  Model 3  15,256 Miles  2020  Shift SF - Test Drives Delivered To You
# 15  Model 3  14,415 Miles  2018  Shift SF - Test Drives Delivered To You
# 16  Model 3  16,295 Miles  2019  Shift SF - Test Drives Delivered To You
# 17  Model 3  32,407 Miles  2019  Shift SF - Test Drives Delivered To You
# 18  Model 3   5,349 Miles  2020             CarMax Serramonte - Now Open
# 19  Model 3   2,692 Miles  2021                CarMax Fremont - Now Open
#
#       Price
# 0   $40,950
# 1   $48,950
# 2   $41,950
# 3   $42,450
# 4   $41,950
# 5   $41,500
# 6   $42,450
# 7   $43,950
# 8   $41,950
# 9   $48,900
# 10  $42,450
# 11  $40,950
# 12  $87,943
# 13  $89,995
# 14  $43,500
# 15  $40,950
# 16  $40,850
# 17  $42,500
# 18  $46,998
# 19  $60,998

# %%
tesla_df.to_excel('tesla_single_page.xlsx', index=False)

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 5pages to get 100 results)

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}


model = []
mileage = []
year = []
dealer_name = []
price = []

for i in range(1,6):

    params = (
        ('make', 'Tesla'),
        ('location', 'San^%^20Francisco,^%^20CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page', str(i)),
    )
    
    # response variable for the get request
    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    
    # json object
    results_json = response.json()
    
    # result items (20 items for each page)
    result_items = results_json['search_results']
    
    for result in result_items:
    
        # model
        model.append(result['model'])

        # mileage
        mileage.append(result['mileage'])

        # year
        year.append(result['year']) 

        # dealer name
        dealer_name.append(result['dealer_name']) 

        # price
        price.append(result['price'])

# %%
tesla_multiple_df = pd.DataFrame({'Model': model, 'Mileage':mileage, 'Year':year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_multiple_df
# Out:
#       Model       Mileage  Year                              Dealer Name  \
# 0   Model 3  12,810 Miles  2019  Shift SF - Test Drives Delivered To You
# 1   Model S  44,203 Miles  2016  Shift SF - Test Drives Delivered To You
# 2   Model 3  20,538 Miles  2018  Shift SF - Test Drives Delivered To You
# 3   Model 3   7,546 Miles  2019  Shift SF - Test Drives Delivered To You
# 4   Model 3  39,885 Miles  2018  Shift SF - Test Drives Delivered To You
# ..      ...           ...   ...                                      ...
# 95  Model Y   9,200 Miles  2021                        Texas Direct Auto
# 96  Model Y   7,723 Miles  2021                        Texas Direct Auto
# 97  Model Y      98 Miles  2021                        Texas Direct Auto
# 98  Model Y     988 Miles  2021                        Texas Direct Auto
# 99  Model 3  22,487 Miles  2018                        Texas Direct Auto
#
#       Price
# 0   $40,950
# 1   $48,950
# 2   $41,950
# 3   $42,450
# 4   $41,950
# ..      ...
# 95  $52,810
# 96  $61,810
# 97  $62,980
# 98  $54,660
# 99  $40,999
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
tesla_multiple_df.to_excel('tesla_multiple_pages.xlsx', index=False)
