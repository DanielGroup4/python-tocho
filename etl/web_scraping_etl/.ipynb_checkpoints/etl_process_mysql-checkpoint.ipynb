# %% [markdown]
# ## ETL process (AutoList)

# %%
import requests
import pandas as pd

# %%
# url by calaya
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

url = "https://www.autolist.com/api/cwv/seo/listings?make=Volkswagen&location=Celaya,%20Gto.&latitude=20.5135374&longitude=-100.8160686&radius=50&page=1"

response = requests.get(url, headers=headers)

# %%
 # Checkar Status de response
response
# Out:
# <Response [200]>

# %%
# Crear Json Object
results_json = response.json()

# %%
results_json
# Out:
# {'total_results_count': 510,
#  'make_model_name': 'Volkswagen',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Volkswagen',
#   'make': 'Volkswagen',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2022,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1632893319,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWDB7AJ6HM349133',
#    'vdp_url': '/volkswagen-jetta#vin=3VWDB7AJ6HM349133',
#    'clickoff_url': 'https://www.carmax.com/car/20608353?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 228471370,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20608353/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--owmQDD23--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20608353/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 45.06417853067431,
#    'lon': -93.38080223309863,
#    'year': 2017,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$18,998',
#    'price_unformatted': 18998,
#    'mileage': '43,183 Miles',
#    'mileage_unformatted': 43183,
#    'city': 'Brooklyn Park',
#    'state': 'MN',
#    'distance_from_origin': 1748,
#    'dealer_name': 'CarMax Brooklyn Park - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWDB7AJ6HM349133',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWDB7AJ6HM349133',
#     'remote_dealer_id': '6008',
#     'dealer_name': 'CarMax Brooklyn Park',
#     'remote_sku': '20608353',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_brooklyn_park',
#     'dealer_uuid': 'c38f3527-189c-439c-af69-24b17e80914a',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.4T SE',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1633930395,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/WVWUF7AU8GW042613',
#    'vdp_url': '/volkswagen-golf+r#vin=WVWUF7AU8GW042613',
#    'clickoff_url': 'https://www.carmax.com/car/20951161?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 229305156,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20951161/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--7pcsTP8T--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20951161/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.2706246070151,
#    'lon': -121.8513164222633,
#    'year': 2016,
#    'make': 'Volkswagen',
#    'model': 'Golf R',
#    'model_id': 1665,
#    'display_color': '',
#    'price': '$31,998',
#    'price_unformatted': 31998,
#    'mileage': '54,682 Miles',
#    'mileage_unformatted': 54682,
#    'city': 'San Jose',
#    'state': 'CA',
#    'distance_from_origin': 1712,
#    'dealer_name': 'CarMax Capitol Expressway - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': 'WVWUF7AU8GW042613',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': 'WVWUF7AU8GW042613',
#     'remote_dealer_id': '6072',
#     'dealer_name': 'CarMax Capitol Expressway',
#     'remote_sku': '20951161',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_capitol_expressway',
#     'dealer_uuid': '59dddca6-1a7a-4f7c-a382-e8af52fdc9d8',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Base',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1634880515,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/3VWD17AJ2FM315142',
#    'vdp_url': '/volkswagen-jetta#vin=3VWD17AJ2FM315142',
#    'clickoff_url': 'https://www.carmax.com/car/20538003?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 229999058,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20538003/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--wSer-aL1--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20538003/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 33.016163,
#    'lon': -96.781067,
#    'year': 2015,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$14,998',
#    'price_unformatted': 14998,
#    'mileage': '87,585 Miles',
#    'mileage_unformatted': 87585,
#    'city': 'Plano',
#    'state': 'TX',
#    'distance_from_origin': 898,
#    'dealer_name': 'CarMax Plano - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWD17AJ2FM315142',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWD17AJ2FM315142',
#     'remote_dealer_id': '7207',
#     'dealer_name': 'CarMax Plano',
#     'remote_sku': '20538003',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_plano',
#     'dealer_uuid': 'c158dd13-61b6-4ead-bf94-5d8644786c1e',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'SE PZEV',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1634362138,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/1VWAT7A3XGC051816',
#    'vdp_url': '/volkswagen-passat#vin=1VWAT7A3XGC051816',
#    'clickoff_url': 'https://www.carmax.com/car/21326352?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 229639501,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21326352/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--qip7we7k--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21326352/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 26.097263,
#    'lon': -80.245949,
#    'year': 2016,
#    'make': 'Volkswagen',
#    'model': 'Passat',
#    'model_id': 1645,
#    'display_color': '',
#    'price': '$16,998',
#    'price_unformatted': 16998,
#    'mileage': '64,144 Miles',
#    'mileage_unformatted': 64144,
#    'city': 'Davie',
#    'state': 'FL',
#    'distance_from_origin': 1359,
#    'dealer_name': 'CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '1VWAT7A3XGC051816',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '1VWAT7A3XGC051816',
#     'remote_dealer_id': '7108',
#     'dealer_name': 'CarMax Ft. Lauderdale',
#     'remote_sku': '21326352',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_ft_lauderdale',
#     'dealer_uuid': 'e021e97a-0130-48f0-a061-638533e61fbd',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.8T S PZEV',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1634692722,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/3VV1B7AX4JM043131',
#    'vdp_url': '/volkswagen-tiguan#vin=3VV1B7AX4JM043131',
#    'clickoff_url': 'https://www.carmax.com/car/20989962?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 229830310,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20989962/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--IMm2HvqS--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20989962/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 31.14116854862144,
#    'lon': -97.66014214033629,
#    'year': 2018,
#    'make': 'Volkswagen',
#    'model': 'Tiguan',
#    'model_id': 1657,
#    'display_color': '',
#    'price': '$21,998',
#    'price_unformatted': 21998,
#    'mileage': '28,959 Miles',
#    'mileage_unformatted': 28959,
#    'city': 'Killeen',
#    'state': 'TX',
#    'distance_from_origin': 759,
#    'dealer_name': 'CarMax Killeen - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VV1B7AX4JM043131',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VV1B7AX4JM043131',
#     'remote_dealer_id': '6128',
#     'dealer_name': 'CarMax - Killeen',
#     'remote_sku': '20989962',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_killeen',
#     'dealer_uuid': 'fa148922-eb99-459c-984b-a4c564f05650',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.0T S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1634448529,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWDB7AJ1HM303807',
#    'vdp_url': '/volkswagen-jetta#vin=3VWDB7AJ1HM303807',
#    'clickoff_url': 'https://www.carmax.com/car/20608180?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 229711512,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20608180/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--luB0ZuF6--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20608180/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 41.26424,
#    'lon': -96.187141,
#    'year': 2017,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$17,998',
#    'price_unformatted': 17998,
#    'mileage': '46,804 Miles',
#    'mileage_unformatted': 46804,
#    'city': 'Omaha',
#    'state': 'NE',
#    'distance_from_origin': 1459,
#    'dealer_name': 'CarMax Omaha - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWDB7AJ1HM303807',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWDB7AJ1HM303807',
#     'remote_dealer_id': '7270',
#     'dealer_name': 'CarMax Omaha',
#     'remote_sku': '20608180',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_omaha',
#     'dealer_uuid': '290d7fe3-541c-4f77-a166-fd2513592671',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.4T SE',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1634880518,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/WVGRF7BP7HD006595',
#    'vdp_url': '/volkswagen-touareg#vin=WVGRF7BP7HD006595',
#    'clickoff_url': 'https://www.carmax.com/car/20971007?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 229999246,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20971007/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--HnaaMRpu--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20971007/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 36.308613,
#    'lon': -86.680939,
#    'year': 2017,
#    'make': 'Volkswagen',
#    'model': 'Touareg',
#    'model_id': 1656,
#    'display_color': '',
#    'price': '$31,998',
#    'price_unformatted': 31998,
#    'mileage': '53,590 Miles',
#    'mileage_unformatted': 53590,
#    'city': 'Madison',
#    'state': 'TN',
#    'distance_from_origin': 1385,
#    'dealer_name': 'CarMax Rivergate - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': 'WVGRF7BP7HD006595',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': 'WVGRF7BP7HD006595',
#     'remote_dealer_id': '7284',
#     'dealer_name': 'CarMax Rivergate',
#     'remote_sku': '20971007',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'camax_rivergate',
#     'dealer_uuid': 'ebfda404-014c-44ba-8484-f5a94ef66a94',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'V6 Wolfsburg',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1633224773,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/1VWAT7A3XGC005550',
#    'vdp_url': '/volkswagen-passat#vin=1VWAT7A3XGC005550',
#    'clickoff_url': 'https://www.carmax.com/car/21279533?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 228804921,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21279533/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--V9oUAHE6--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21279533/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 35.91317121959425,
#    'lon': -86.77828881182035,
#    'year': 2016,
#    'make': 'Volkswagen',
#    'model': 'Passat',
#    'model_id': 1645,
#    'display_color': '',
#    'price': '$18,998',
#    'price_unformatted': 18998,
#    'mileage': '40,191 Miles',
#    'mileage_unformatted': 40191,
#    'city': 'Franklin',
#    'state': 'TN',
#    'distance_from_origin': 1361,
#    'dealer_name': 'CarMax Cool Springs - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '1VWAT7A3XGC005550',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '1VWAT7A3XGC005550',
#     'remote_dealer_id': '6042',
#     'dealer_name': 'CarMax Cool Springs',
#     'remote_sku': '21279533',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_cool_springs',
#     'dealer_uuid': '1bc278ff-c955-47fd-a9ee-25e13816b24c',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.8T S PZEV',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1631251743,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/3VWD67AJ8GM308179',
#    'vdp_url': '/volkswagen-jetta#vin=3VWD67AJ8GM308179',
#    'clickoff_url': 'https://www.carmax.com/car/20931049?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 227247325,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20931049/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--kCB4LCBL--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20931049/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 47.81055093002225,
#    'lon': -122.2807501062141,
#    'year': 2016,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$15,998',
#    'price_unformatted': 15998,
#    'mileage': '62,366 Miles',
#    'mileage_unformatted': 62366,
#    'city': 'Lynnwood',
#    'state': 'WA',
#    'distance_from_origin': 2233,
#    'dealer_name': 'CarMax Lynnwood - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWD67AJ8GM308179',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWD67AJ8GM308179',
#     'remote_dealer_id': '7250',
#     'dealer_name': 'CarMax Lynnwood',
#     'remote_sku': '20931049',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_lynnwood',
#     'dealer_uuid': '04cb1617-8ff4-4348-80b1-7c6e0dd411b8',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.4T SE',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1633757621,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VW2K7AJ0EM335733',
#    'vdp_url': '/volkswagen-jetta#vin=3VW2K7AJ0EM335733',
#    'clickoff_url': 'https://www.carmax.com/car/21419038?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 229186710,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21419038/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--uzOHUVoK--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21419038/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 27.90780503218586,
#    'lon': -82.71477008897357,
#    'year': 2014,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$14,599',
#    'price_unformatted': 14599,
#    'mileage': '69,527 Miles',
#    'mileage_unformatted': 69527,
#    'city': 'Clearwater',
#    'state': 'FL',
#    'distance_from_origin': 1247,
#    'dealer_name': 'CarMax Clearwater - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VW2K7AJ0EM335733',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VW2K7AJ0EM335733',
#     'remote_dealer_id': '7172',
#     'dealer_name': 'CarMax Clearwater',
#     'remote_sku': '21419038',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_clearwater',
#     'dealer_uuid': '2c1699e1-4766-4dcf-9103-ff8db59afb1e',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1632029340,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/WVWVA7AU4KW187501',
#    'vdp_url': '/volkswagen-golf+r#vin=WVWVA7AU4KW187501',
#    'clickoff_url': 'https://www.carmax.com/car/21232426?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 227867446,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21232426/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--fAoXJmtY--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21232426/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 36.14393939975176,
#    'lon': -115.2280381909176,
#    'year': 2019,
#    'make': 'Volkswagen',
#    'model': 'Golf R',
#    'model_id': 1665,
#    'display_color': '',
#    'price': '$44,998',
#    'price_unformatted': 44998,
#    'mileage': '9,886 Miles',
#    'mileage_unformatted': 9886,
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'distance_from_origin': 1387,
#    'dealer_name': 'CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': 'WVWVA7AU4KW187501',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': 'WVWVA7AU4KW187501',
#     'remote_dealer_id': '7244',
#     'dealer_name': 'CarMax West Sahara',
#     'remote_sku': '21232426',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_west_sahara',
#     'dealer_uuid': '66f323f4-16b6-494a-9829-3d181220432d',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'w/DCC and Navigation',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1633152889,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWN57BU6KM174295',
#    'vdp_url': '/volkswagen-jetta#vin=3VWN57BU6KM174295',
#    'clickoff_url': 'https://www.carmax.com/car/21224006?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 228736883,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21224006/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--J6j2ZmXS--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21224006/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 39.61071138904866,
#    'lon': -104.9542024889482,
#    'year': 2019,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$19,998',
#    'price_unformatted': 19998,
#    'mileage': '14,970 Miles',
#    'mileage_unformatted': 14970,
#    'city': 'Littleton',
#    'state': 'CO',
#    'distance_from_origin': 1342,
#    'dealer_name': 'CarMax South Broadway - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWN57BU6KM174295',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWN57BU6KM174295',
#     'remote_dealer_id': '6045',
#     'dealer_name': 'CarMax South Broadway',
#     'remote_sku': '21224006',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_south_broadway',
#     'dealer_uuid': '1fbca647-9cda-449e-b12f-564560e53f25',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.4T S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1634522257,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWN57BU4KM034861',
#    'vdp_url': '/volkswagen-jetta#vin=3VWN57BU4KM034861',
#    'clickoff_url': 'https://www.carmax.com/car/21297771?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 229746749,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21297771/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--B29e0dqz--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21297771/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 42.26776029832964,
#    'lon': -71.61455938733123,
#    'year': 2019,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$19,998',
#    'price_unformatted': 19998,
#    'mileage': '22,769 Miles',
#    'mileage_unformatted': 22769,
#    'city': 'Westborough',
#    'state': 'MA',
#    'distance_from_origin': 2265,
#    'dealer_name': 'CarMax Westborough - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWN57BU4KM034861',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWN57BU4KM034861',
#     'remote_dealer_id': '6067',
#     'dealer_name': 'CarMax Westborough',
#     'remote_sku': '21297771',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_westborough',
#     'dealer_uuid': '68f828c5-9165-4f32-8f17-7ceb8fd9246b',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.4T S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1632548051,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VW117AU4JM751450',
#    'vdp_url': '/volkswagen-golf+sportwagen#vin=3VW117AU4JM751450',
#    'clickoff_url': 'https://www.carmax.com/car/21162832?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 228241437,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21162832/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--0Ifvt8WY--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21162832/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 44.9029419050844,
#    'lon': -122.9088876482375,
#    'year': 2018,
#    'make': 'Volkswagen',
#    'model': 'Golf SportWagen',
#    'model_id': 2064,
#    'display_color': '',
#    'price': '$24,998',
#    'price_unformatted': 24998,
#    'mileage': '15,234 Miles',
#    'mileage_unformatted': 15234,
#    'city': 'Salem',
#    'state': 'OR',
#    'distance_from_origin': 2104,
#    'dealer_name': 'CarMax Salem - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VW117AU4JM751450',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VW117AU4JM751450',
#     'remote_dealer_id': '6005',
#     'dealer_name': 'CarMax Salem',
#     'remote_sku': '21162832',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_salem',
#     'dealer_uuid': 'c3c566b9-8e45-4920-a3c4-28aa075b2f01',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'TSI S 4Motion',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1630746859,
#    'recent_price_drop': False,
#    'is_hot': True,
#    'href_target': '/listings/WVWBR7ANXKE000336',
#    'vdp_url': '/volkswagen-arteon#vin=WVWBR7ANXKE000336',
#    'clickoff_url': 'https://www.carmax.com/car/21218679?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 226854078,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21218679/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--XQ4DbmFR--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21218679/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 33.67870681721259,
#    'lon': -117.9071677943577,
#    'year': 2019,
#    'make': 'Volkswagen',
#    'model': 'Arteon',
#    'model_id': 2306,
#    'display_color': '',
#    'price': '$29,998',
#    'price_unformatted': 29998,
#    'mileage': '12,138 Miles',
#    'mileage_unformatted': 12138,
#    'city': 'Costa Mesa',
#    'state': 'CA',
#    'distance_from_origin': 1386,
#    'dealer_name': 'CarMax Costa Mesa - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': 'WVWBR7ANXKE000336',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': 'WVWBR7ANXKE000336',
#     'remote_dealer_id': '7297',
#     'dealer_name': 'CarMax Costa Mesa',
#     'remote_sku': '21218679',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_costa_mesa',
#     'dealer_uuid': 'a1b00823-902b-4b81-b8ac-d6cb028a5497',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.0T SE 4Motion',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'hot_car'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1631578648,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VV1B7AXXKM110140',
#    'vdp_url': '/volkswagen-tiguan#vin=3VV1B7AXXKM110140',
#    'clickoff_url': 'https://www.carmax.com/car/21110936?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 227471372,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21110936/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--9-SLK2cR--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21110936/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 35.08562420195032,
#    'lon': -80.89100575717302,
#    'year': 2019,
#    'make': 'Volkswagen',
#    'model': 'Tiguan',
#    'model_id': 1657,
#    'display_color': '',
#    'price': '$23,998',
#    'price_unformatted': 23998,
#    'mileage': '28,934 Miles',
#    'mileage_unformatted': 28934,
#    'city': 'Pineville',
#    'state': 'NC',
#    'distance_from_origin': 1574,
#    'dealer_name': 'CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VV1B7AXXKM110140',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VV1B7AXXKM110140',
#     'remote_dealer_id': '7197',
#     'dealer_name': 'CarMax South Boulevard',
#     'remote_sku': '21110936',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_south_boulevard',
#     'dealer_uuid': '0bf171f2-9b5f-493b-b770-fc45cfb32db7',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.0T S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1633584826,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWC57BU8KM068079',
#    'vdp_url': '/volkswagen-jetta#vin=3VWC57BU8KM068079',
#    'clickoff_url': 'https://www.carmax.com/car/21371931?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 229026661,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21371931/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--wF0Oxs94--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21371931/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 33.95697153649062,
#    'lon': -118.3569741542017,
#    'year': 2019,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$20,998',
#    'price_unformatted': 20998,
#    'mileage': '48,183 Miles',
#    'mileage_unformatted': 48183,
#    'city': 'Inglewood',
#    'state': 'CA',
#    'distance_from_origin': 1418,
#    'dealer_name': 'CarMax LAX - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWC57BU8KM068079',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWC57BU8KM068079',
#     'remote_dealer_id': '7810',
#     'dealer_name': 'CarMax LAX',
#     'remote_sku': '21371931',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_lax',
#     'dealer_uuid': '0dbef435-1a36-4e2e-bb7f-6a3db2c43ffd',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.4T R-Line',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1632878869,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VV2B7AX4JM161362',
#    'vdp_url': '/volkswagen-tiguan#vin=3VV2B7AX4JM161362',
#    'clickoff_url': 'https://www.carmax.com/car/21352905?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 228458567,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21352905/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--pQE-eWzI--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21352905/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 35.8665825735939,
#    'lon': -78.53713370982733,
#    'year': 2018,
#    'make': 'Volkswagen',
#    'model': 'Tiguan',
#    'model_id': 1657,
#    'display_color': '',
#    'price': '$31,998',
#    'price_unformatted': 31998,
#    'mileage': '10,391 Miles',
#    'mileage_unformatted': 10391,
#    'city': 'Raleigh',
#    'state': 'NC',
#    'distance_from_origin': 1714,
#    'dealer_name': 'CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VV2B7AX4JM161362',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VV2B7AX4JM161362',
#     'remote_dealer_id': '7282',
#     'dealer_name': 'CarMax Capital Boulevard',
#     'remote_sku': '21352905',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_capital_boulevard',
#     'dealer_uuid': '37dab682-0d2a-4174-b8d0-187d7ede25c7',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.0T SEL 4Motion',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1633671251,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWL17AJ7HM401187',
#    'vdp_url': '/volkswagen-jetta#vin=3VWL17AJ7HM401187',
#    'clickoff_url': 'https://www.carmax.com/car/21149956?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 229111698,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21149956/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Xs8Dy8Wj--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21149956/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 45.45937092772807,
#    'lon': -122.8043480260167,
#    'year': 2017,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$19,998',
#    'price_unformatted': 19998,
#    'mileage': '40,448 Miles',
#    'mileage_unformatted': 40448,
#    'city': 'Beaverton',
#    'state': 'OR',
#    'distance_from_origin': 2128,
#    'dealer_name': 'CarMax Beaverton - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWL17AJ7HM401187',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWL17AJ7HM401187',
#     'remote_dealer_id': '7164',
#     'dealer_name': 'CarMax Beaverton',
#     'remote_sku': '21149956',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_beaverton',
#     'dealer_uuid': 'dcdaf3f1-8376-491a-8376-86d53314d086',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.8T SEL',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1631510896,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VV4B7AX3LM094880',
#    'vdp_url': '/volkswagen-tiguan#vin=3VV4B7AX3LM094880',
#    'clickoff_url': 'https://www.carmax.com/car/21111415?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 227456177,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21111415/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--G_XYuvLw--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21111415/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 35.08562420195032,
#    'lon': -80.89100575717302,
#    'year': 2020,
#    'make': 'Volkswagen',
#    'model': 'Tiguan',
#    'model_id': 1657,
#    'display_color': '',
#    'price': '$39,998',
#    'price_unformatted': 39998,
#    'mileage': '8,757 Miles',
#    'mileage_unformatted': 8757,
#    'city': 'Pineville',
#    'state': 'NC',
#    'distance_from_origin': 1574,
#    'dealer_name': 'CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VV4B7AX3LM094880',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VV4B7AX3LM094880',
#     'remote_dealer_id': '7197',
#     'dealer_name': 'CarMax South Boulevard',
#     'remote_sku': '21111415',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_south_boulevard',
#     'dealer_uuid': '0bf171f2-9b5f-493b-b770-fc45cfb32db7',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.0T SEL Premium R-Line 4Motion',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False}],
#  'html': {'search_results': '<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/volkswagen-jetta#vin=3VWDB7AJ6HM349133"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--owmQDD23--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20608353/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a)\' title=\'used 2017 Volkswagen Jetta 1.4T SE Red 3VWDB7AJ6HM349133\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2017 Volkswagen Jetta 1.4T SE</div>\n<div class=\'subtext\'>\n43,183 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Transfer Available</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$18,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $274/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/volkswagen-golf+r#vin=WVWUF7AU8GW042613"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--7pcsTP8T--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20951161/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a)\' title=\'used 2016 Volkswagen Golf R Base Blue WVWUF7AU8GW042613\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2016 Volkswagen Golf R Base</div>\n<div class=\'subtext\'>\n54,682 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Transfer Available</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$31,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $461/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/volkswagen-jetta#vin=3VWD17AJ2FM315142"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' data-background-image=\'https://images.autolist.com/image/fetch/s--wSer-aL1--/c_fill,f_auto,q_auto,w_320/ht ...
#   'pagination': '<ul><li class="previous disabled"><a>Previous</a></li><li class="selected"><a>1</a></li><li data-page="2"><a>2</a></li><li data-page="3"><a>3</a></li><li data-page="4"><a>...</a></li><li data-page="24"><a>24</a></li><li data-page="25"><a>25</a></li><li data-page="2" class="next"><a>Next</a></li></ul>'}}

# %%
type(results_json)
# Out:
# dict

# %%
# Output Keys
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# **Find the Data**
#
# * modelo
# * kilometraje
# * año
# * nombre de distribuidor
# * precio

# %%
type(results_json['search_results'])
# Out:
# list

# %%
results_json['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1632893319,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWDB7AJ6HM349133',
#   'vdp_url': '/volkswagen-jetta#vin=3VWDB7AJ6HM349133',
#   'clickoff_url': 'https://www.carmax.com/car/20608353?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 228471370,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20608353/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--owmQDD23--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20608353/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 45.06417853067431,
#   'lon': -93.38080223309863,
#   'year': 2017,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$18,998',
#   'price_unformatted': 18998,
#   'mileage': '43,183 Miles',
#   'mileage_unformatted': 43183,
#   'city': 'Brooklyn Park',
#   'state': 'MN',
#   'distance_from_origin': 1748,
#   'dealer_name': 'CarMax Brooklyn Park - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWDB7AJ6HM349133',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWDB7AJ6HM349133',
#    'remote_dealer_id': '6008',
#    'dealer_name': 'CarMax Brooklyn Park',
#    'remote_sku': '20608353',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_brooklyn_park',
#    'dealer_uuid': 'c38f3527-189c-439c-af69-24b17e80914a',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.4T SE',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1633930395,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/WVWUF7AU8GW042613',
#   'vdp_url': '/volkswagen-golf+r#vin=WVWUF7AU8GW042613',
#   'clickoff_url': 'https://www.carmax.com/car/20951161?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 229305156,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20951161/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--7pcsTP8T--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20951161/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.2706246070151,
#   'lon': -121.8513164222633,
#   'year': 2016,
#   'make': 'Volkswagen',
#   'model': 'Golf R',
#   'model_id': 1665,
#   'display_color': '',
#   'price': '$31,998',
#   'price_unformatted': 31998,
#   'mileage': '54,682 Miles',
#   'mileage_unformatted': 54682,
#   'city': 'San Jose',
#   'state': 'CA',
#   'distance_from_origin': 1712,
#   'dealer_name': 'CarMax Capitol Expressway - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': 'WVWUF7AU8GW042613',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': 'WVWUF7AU8GW042613',
#    'remote_dealer_id': '6072',
#    'dealer_name': 'CarMax Capitol Expressway',
#    'remote_sku': '20951161',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_capitol_expressway',
#    'dealer_uuid': '59dddca6-1a7a-4f7c-a382-e8af52fdc9d8',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'Base',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1634880515,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/3VWD17AJ2FM315142',
#   'vdp_url': '/volkswagen-jetta#vin=3VWD17AJ2FM315142',
#   'clickoff_url': 'https://www.carmax.com/car/20538003?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 229999058,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20538003/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--wSer-aL1--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20538003/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 33.016163,
#   'lon': -96.781067,
#   'year': 2015,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$14,998',
#   'price_unformatted': 14998,
#   'mileage': '87,585 Miles',
#   'mileage_unformatted': 87585,
#   'city': 'Plano',
#   'state': 'TX',
#   'distance_from_origin': 898,
#   'dealer_name': 'CarMax Plano - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWD17AJ2FM315142',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWD17AJ2FM315142',
#    'remote_dealer_id': '7207',
#    'dealer_name': 'CarMax Plano',
#    'remote_sku': '20538003',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_plano',
#    'dealer_uuid': 'c158dd13-61b6-4ead-bf94-5d8644786c1e',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'SE PZEV',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1634362138,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/1VWAT7A3XGC051816',
#   'vdp_url': '/volkswagen-passat#vin=1VWAT7A3XGC051816',
#   'clickoff_url': 'https://www.carmax.com/car/21326352?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 229639501,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21326352/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--qip7we7k--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21326352/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 26.097263,
#   'lon': -80.245949,
#   'year': 2016,
#   'make': 'Volkswagen',
#   'model': 'Passat',
#   'model_id': 1645,
#   'display_color': '',
#   'price': '$16,998',
#   'price_unformatted': 16998,
#   'mileage': '64,144 Miles',
#   'mileage_unformatted': 64144,
#   'city': 'Davie',
#   'state': 'FL',
#   'distance_from_origin': 1359,
#   'dealer_name': 'CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '1VWAT7A3XGC051816',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '1VWAT7A3XGC051816',
#    'remote_dealer_id': '7108',
#    'dealer_name': 'CarMax Ft. Lauderdale',
#    'remote_sku': '21326352',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_ft_lauderdale',
#    'dealer_uuid': 'e021e97a-0130-48f0-a061-638533e61fbd',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.8T S PZEV',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1634692722,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/3VV1B7AX4JM043131',
#   'vdp_url': '/volkswagen-tiguan#vin=3VV1B7AX4JM043131',
#   'clickoff_url': 'https://www.carmax.com/car/20989962?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 229830310,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20989962/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--IMm2HvqS--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20989962/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 31.14116854862144,
#   'lon': -97.66014214033629,
#   'year': 2018,
#   'make': 'Volkswagen',
#   'model': 'Tiguan',
#   'model_id': 1657,
#   'display_color': '',
#   'price': '$21,998',
#   'price_unformatted': 21998,
#   'mileage': '28,959 Miles',
#   'mileage_unformatted': 28959,
#   'city': 'Killeen',
#   'state': 'TX',
#   'distance_from_origin': 759,
#   'dealer_name': 'CarMax Killeen - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VV1B7AX4JM043131',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VV1B7AX4JM043131',
#    'remote_dealer_id': '6128',
#    'dealer_name': 'CarMax - Killeen',
#    'remote_sku': '20989962',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_killeen',
#    'dealer_uuid': 'fa148922-eb99-459c-984b-a4c564f05650',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.0T S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1634448529,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWDB7AJ1HM303807',
#   'vdp_url': '/volkswagen-jetta#vin=3VWDB7AJ1HM303807',
#   'clickoff_url': 'https://www.carmax.com/car/20608180?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 229711512,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20608180/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--luB0ZuF6--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20608180/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 41.26424,
#   'lon': -96.187141,
#   'year': 2017,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$17,998',
#   'price_unformatted': 17998,
#   'mileage': '46,804 Miles',
#   'mileage_unformatted': 46804,
#   'city': 'Omaha',
#   'state': 'NE',
#   'distance_from_origin': 1459,
#   'dealer_name': 'CarMax Omaha - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWDB7AJ1HM303807',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWDB7AJ1HM303807',
#    'remote_dealer_id': '7270',
#    'dealer_name': 'CarMax Omaha',
#    'remote_sku': '20608180',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_omaha',
#    'dealer_uuid': '290d7fe3-541c-4f77-a166-fd2513592671',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.4T SE',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1634880518,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/WVGRF7BP7HD006595',
#   'vdp_url': '/volkswagen-touareg#vin=WVGRF7BP7HD006595',
#   'clickoff_url': 'https://www.carmax.com/car/20971007?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 229999246,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20971007/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--HnaaMRpu--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20971007/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 36.308613,
#   'lon': -86.680939,
#   'year': 2017,
#   'make': 'Volkswagen',
#   'model': 'Touareg',
#   'model_id': 1656,
#   'display_color': '',
#   'price': '$31,998',
#   'price_unformatted': 31998,
#   'mileage': '53,590 Miles',
#   'mileage_unformatted': 53590,
#   'city': 'Madison',
#   'state': 'TN',
#   'distance_from_origin': 1385,
#   'dealer_name': 'CarMax Rivergate - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': 'WVGRF7BP7HD006595',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': 'WVGRF7BP7HD006595',
#    'remote_dealer_id': '7284',
#    'dealer_name': 'CarMax Rivergate',
#    'remote_sku': '20971007',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'camax_rivergate',
#    'dealer_uuid': 'ebfda404-014c-44ba-8484-f5a94ef66a94',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'V6 Wolfsburg',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1633224773,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/1VWAT7A3XGC005550',
#   'vdp_url': '/volkswagen-passat#vin=1VWAT7A3XGC005550',
#   'clickoff_url': 'https://www.carmax.com/car/21279533?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 228804921,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21279533/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--V9oUAHE6--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21279533/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 35.91317121959425,
#   'lon': -86.77828881182035,
#   'year': 2016,
#   'make': 'Volkswagen',
#   'model': 'Passat',
#   'model_id': 1645,
#   'display_color': '',
#   'price': '$18,998',
#   'price_unformatted': 18998,
#   'mileage': '40,191 Miles',
#   'mileage_unformatted': 40191,
#   'city': 'Franklin',
#   'state': 'TN',
#   'distance_from_origin': 1361,
#   'dealer_name': 'CarMax Cool Springs - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '1VWAT7A3XGC005550',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '1VWAT7A3XGC005550',
#    'remote_dealer_id': '6042',
#    'dealer_name': 'CarMax Cool Springs',
#    'remote_sku': '21279533',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_cool_springs',
#    'dealer_uuid': '1bc278ff-c955-47fd-a9ee-25e13816b24c',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.8T S PZEV',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1631251743,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/3VWD67AJ8GM308179',
#   'vdp_url': '/volkswagen-jetta#vin=3VWD67AJ8GM308179',
#   'clickoff_url': 'https://www.carmax.com/car/20931049?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 227247325,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20931049/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--kCB4LCBL--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20931049/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 47.81055093002225,
#   'lon': -122.2807501062141,
#   'year': 2016,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$15,998',
#   'price_unformatted': 15998,
#   'mileage': '62,366 Miles',
#   'mileage_unformatted': 62366,
#   'city': 'Lynnwood',
#   'state': 'WA',
#   'distance_from_origin': 2233,
#   'dealer_name': 'CarMax Lynnwood - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWD67AJ8GM308179',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWD67AJ8GM308179',
#    'remote_dealer_id': '7250',
#    'dealer_name': 'CarMax Lynnwood',
#    'remote_sku': '20931049',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_lynnwood',
#    'dealer_uuid': '04cb1617-8ff4-4348-80b1-7c6e0dd411b8',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.4T SE',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1633757621,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VW2K7AJ0EM335733',
#   'vdp_url': '/volkswagen-jetta#vin=3VW2K7AJ0EM335733',
#   'clickoff_url': 'https://www.carmax.com/car/21419038?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 229186710,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21419038/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--uzOHUVoK--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21419038/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 27.90780503218586,
#   'lon': -82.71477008897357,
#   'year': 2014,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$14,599',
#   'price_unformatted': 14599,
#   'mileage': '69,527 Miles',
#   'mileage_unformatted': 69527,
#   'city': 'Clearwater',
#   'state': 'FL',
#   'distance_from_origin': 1247,
#   'dealer_name': 'CarMax Clearwater - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VW2K7AJ0EM335733',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VW2K7AJ0EM335733',
#    'remote_dealer_id': '7172',
#    'dealer_name': 'CarMax Clearwater',
#    'remote_sku': '21419038',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_clearwater',
#    'dealer_uuid': '2c1699e1-4766-4dcf-9103-ff8db59afb1e',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1632029340,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/WVWVA7AU4KW187501',
#   'vdp_url': '/volkswagen-golf+r#vin=WVWVA7AU4KW187501',
#   'clickoff_url': 'https://www.carmax.com/car/21232426?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 227867446,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21232426/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--fAoXJmtY--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21232426/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 36.14393939975176,
#   'lon': -115.2280381909176,
#   'year': 2019,
#   'make': 'Volkswagen',
#   'model': 'Golf R',
#   'model_id': 1665,
#   'display_color': '',
#   'price': '$44,998',
#   'price_unformatted': 44998,
#   'mileage': '9,886 Miles',
#   'mileage_unformatted': 9886,
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'distance_from_origin': 1387,
#   'dealer_name': 'CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': 'WVWVA7AU4KW187501',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': 'WVWVA7AU4KW187501',
#    'remote_dealer_id': '7244',
#    'dealer_name': 'CarMax West Sahara',
#    'remote_sku': '21232426',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_west_sahara',
#    'dealer_uuid': '66f323f4-16b6-494a-9829-3d181220432d',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'w/DCC and Navigation',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1633152889,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWN57BU6KM174295',
#   'vdp_url': '/volkswagen-jetta#vin=3VWN57BU6KM174295',
#   'clickoff_url': 'https://www.carmax.com/car/21224006?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 228736883,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21224006/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--J6j2ZmXS--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21224006/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 39.61071138904866,
#   'lon': -104.9542024889482,
#   'year': 2019,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$19,998',
#   'price_unformatted': 19998,
#   'mileage': '14,970 Miles',
#   'mileage_unformatted': 14970,
#   'city': 'Littleton',
#   'state': 'CO',
#   'distance_from_origin': 1342,
#   'dealer_name': 'CarMax South Broadway - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWN57BU6KM174295',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWN57BU6KM174295',
#    'remote_dealer_id': '6045',
#    'dealer_name': 'CarMax South Broadway',
#    'remote_sku': '21224006',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_south_broadway',
#    'dealer_uuid': '1fbca647-9cda-449e-b12f-564560e53f25',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.4T S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1634522257,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWN57BU4KM034861',
#   'vdp_url': '/volkswagen-jetta#vin=3VWN57BU4KM034861',
#   'clickoff_url': 'https://www.carmax.com/car/21297771?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 229746749,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21297771/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--B29e0dqz--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21297771/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 42.26776029832964,
#   'lon': -71.61455938733123,
#   'year': 2019,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$19,998',
#   'price_unformatted': 19998,
#   'mileage': '22,769 Miles',
#   'mileage_unformatted': 22769,
#   'city': 'Westborough',
#   'state': 'MA',
#   'distance_from_origin': 2265,
#   'dealer_name': 'CarMax Westborough - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWN57BU4KM034861',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWN57BU4KM034861',
#    'remote_dealer_id': '6067',
#    'dealer_name': 'CarMax Westborough',
#    'remote_sku': '21297771',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_westborough',
#    'dealer_uuid': '68f828c5-9165-4f32-8f17-7ceb8fd9246b',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.4T S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1632548051,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VW117AU4JM751450',
#   'vdp_url': '/volkswagen-golf+sportwagen#vin=3VW117AU4JM751450',
#   'clickoff_url': 'https://www.carmax.com/car/21162832?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 228241437,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21162832/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--0Ifvt8WY--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21162832/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 44.9029419050844,
#   'lon': -122.9088876482375,
#   'year': 2018,
#   'make': 'Volkswagen',
#   'model': 'Golf SportWagen',
#   'model_id': 2064,
#   'display_color': '',
#   'price': '$24,998',
#   'price_unformatted': 24998,
#   'mileage': '15,234 Miles',
#   'mileage_unformatted': 15234,
#   'city': 'Salem',
#   'state': 'OR',
#   'distance_from_origin': 2104,
#   'dealer_name': 'CarMax Salem - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VW117AU4JM751450',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VW117AU4JM751450',
#    'remote_dealer_id': '6005',
#    'dealer_name': 'CarMax Salem',
#    'remote_sku': '21162832',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_salem',
#    'dealer_uuid': 'c3c566b9-8e45-4920-a3c4-28aa075b2f01',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'TSI S 4Motion',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1630746859,
#   'recent_price_drop': False,
#   'is_hot': True,
#   'href_target': '/listings/WVWBR7ANXKE000336',
#   'vdp_url': '/volkswagen-arteon#vin=WVWBR7ANXKE000336',
#   'clickoff_url': 'https://www.carmax.com/car/21218679?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 226854078,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21218679/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--XQ4DbmFR--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21218679/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 33.67870681721259,
#   'lon': -117.9071677943577,
#   'year': 2019,
#   'make': 'Volkswagen',
#   'model': 'Arteon',
#   'model_id': 2306,
#   'display_color': '',
#   'price': '$29,998',
#   'price_unformatted': 29998,
#   'mileage': '12,138 Miles',
#   'mileage_unformatted': 12138,
#   'city': 'Costa Mesa',
#   'state': 'CA',
#   'distance_from_origin': 1386,
#   'dealer_name': 'CarMax Costa Mesa - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': 'WVWBR7ANXKE000336',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': 'WVWBR7ANXKE000336',
#    'remote_dealer_id': '7297',
#    'dealer_name': 'CarMax Costa Mesa',
#    'remote_sku': '21218679',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_costa_mesa',
#    'dealer_uuid': 'a1b00823-902b-4b81-b8ac-d6cb028a5497',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.0T SE 4Motion',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'hot_car'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1631578648,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VV1B7AXXKM110140',
#   'vdp_url': '/volkswagen-tiguan#vin=3VV1B7AXXKM110140',
#   'clickoff_url': 'https://www.carmax.com/car/21110936?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 227471372,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21110936/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--9-SLK2cR--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21110936/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 35.08562420195032,
#   'lon': -80.89100575717302,
#   'year': 2019,
#   'make': 'Volkswagen',
#   'model': 'Tiguan',
#   'model_id': 1657,
#   'display_color': '',
#   'price': '$23,998',
#   'price_unformatted': 23998,
#   'mileage': '28,934 Miles',
#   'mileage_unformatted': 28934,
#   'city': 'Pineville',
#   'state': 'NC',
#   'distance_from_origin': 1574,
#   'dealer_name': 'CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VV1B7AXXKM110140',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VV1B7AXXKM110140',
#    'remote_dealer_id': '7197',
#    'dealer_name': 'CarMax South Boulevard',
#    'remote_sku': '21110936',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_south_boulevard',
#    'dealer_uuid': '0bf171f2-9b5f-493b-b770-fc45cfb32db7',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.0T S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1633584826,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWC57BU8KM068079',
#   'vdp_url': '/volkswagen-jetta#vin=3VWC57BU8KM068079',
#   'clickoff_url': 'https://www.carmax.com/car/21371931?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 229026661,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21371931/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--wF0Oxs94--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21371931/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 33.95697153649062,
#   'lon': -118.3569741542017,
#   'year': 2019,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$20,998',
#   'price_unformatted': 20998,
#   'mileage': '48,183 Miles',
#   'mileage_unformatted': 48183,
#   'city': 'Inglewood',
#   'state': 'CA',
#   'distance_from_origin': 1418,
#   'dealer_name': 'CarMax LAX - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWC57BU8KM068079',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWC57BU8KM068079',
#    'remote_dealer_id': '7810',
#    'dealer_name': 'CarMax LAX',
#    'remote_sku': '21371931',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_lax',
#    'dealer_uuid': '0dbef435-1a36-4e2e-bb7f-6a3db2c43ffd',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.4T R-Line',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1632878869,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VV2B7AX4JM161362',
#   'vdp_url': '/volkswagen-tiguan#vin=3VV2B7AX4JM161362',
#   'clickoff_url': 'https://www.carmax.com/car/21352905?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 228458567,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21352905/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--pQE-eWzI--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21352905/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 35.8665825735939,
#   'lon': -78.53713370982733,
#   'year': 2018,
#   'make': 'Volkswagen',
#   'model': 'Tiguan',
#   'model_id': 1657,
#   'display_color': '',
#   'price': '$31,998',
#   'price_unformatted': 31998,
#   'mileage': '10,391 Miles',
#   'mileage_unformatted': 10391,
#   'city': 'Raleigh',
#   'state': 'NC',
#   'distance_from_origin': 1714,
#   'dealer_name': 'CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VV2B7AX4JM161362',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VV2B7AX4JM161362',
#    'remote_dealer_id': '7282',
#    'dealer_name': 'CarMax Capital Boulevard',
#    'remote_sku': '21352905',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_capital_boulevard',
#    'dealer_uuid': '37dab682-0d2a-4174-b8d0-187d7ede25c7',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.0T SEL 4Motion',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1633671251,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWL17AJ7HM401187',
#   'vdp_url': '/volkswagen-jetta#vin=3VWL17AJ7HM401187',
#   'clickoff_url': 'https://www.carmax.com/car/21149956?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 229111698,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21149956/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Xs8Dy8Wj--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21149956/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 45.45937092772807,
#   'lon': -122.8043480260167,
#   'year': 2017,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$19,998',
#   'price_unformatted': 19998,
#   'mileage': '40,448 Miles',
#   'mileage_unformatted': 40448,
#   'city': 'Beaverton',
#   'state': 'OR',
#   'distance_from_origin': 2128,
#   'dealer_name': 'CarMax Beaverton - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWL17AJ7HM401187',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWL17AJ7HM401187',
#    'remote_dealer_id': '7164',
#    'dealer_name': 'CarMax Beaverton',
#    'remote_sku': '21149956',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_beaverton',
#    'dealer_uuid': 'dcdaf3f1-8376-491a-8376-86d53314d086',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.8T SEL',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1631510896,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VV4B7AX3LM094880',
#   'vdp_url': '/volkswagen-tiguan#vin=3VV4B7AX3LM094880',
#   'clickoff_url': 'https://www.carmax.com/car/21111415?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 227456177,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21111415/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--G_XYuvLw--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21111415/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 35.08562420195032,
#   'lon': -80.89100575717302,
#   'year': 2020,
#   'make': 'Volkswagen',
#   'model': 'Tiguan',
#   'model_id': 1657,
#   'display_color': '',
#   'price': '$39,998',
#   'price_unformatted': 39998,
#   'mileage': '8,757 Miles',
#   'mileage_unformatted': 8757,
#   'city': 'Pineville',
#   'state': 'NC',
#   'distance_from_origin': 1574,
#   'dealer_name': 'CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VV4B7AX3LM094880',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VV4B7AX3LM094880',
#    'remote_dealer_id': '7197',
#    'dealer_name': 'CarMax South Boulevard',
#    'remote_sku': '21111415',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_south_boulevard',
#    'dealer_uuid': '0bf171f2-9b5f-493b-b770-fc45cfb32db7',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.0T SEL Premium R-Line 4Motion',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False}]

# %%
# 20 listas
len(results_json['search_results'])
# Out:
# 20

# %%
result_items = results_json['search_results']

# %%
# punto de partida para el primer resultado
results_json['search_results'][0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1627692552,
#  'recent_price_drop': None,
#  'is_hot': False,
#  'href_target': '/listings/5YJ3E1EAXKF428426',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXKF428426',
#  'clickoff_url': 'https://www.shift.com/car/c1271376?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 224508872,
#  'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/07/30/18/24/2019_tesla_model_3-pic-7333039219005091037-1024x768.jpeg',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--HRkmebK1--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/07/30/18/24/2019_tesla_model_3-pic-7333039219005091037-1024x768.jpeg',
#  'lat': 37.6397,
#  'lon': -122.416,
#  'year': 2019,
#  'make': 'Tesla',
#  'model': 'Model 3',
#  'model_id': 2217,
#  'display_color': '',
#  'price': '$40,950',
#  'price_unformatted': 40950,
#  'mileage': '12,810 Miles',
#  'mileage_unformatted': 12810,
#  'city': 'South San Francisco',
#  'state': 'CA',
#  'distance_from_origin': 9,
#  'dealer_name': 'Shift SF - Test Drives Delivered To You',
#  'show_message_box': None,
#  'email_opt_default': True,
#  'show_financing_checkbox': None,
#  'show_new_mileage': False,
#  'show_thankyou_page': False,
#  'show_rsrp': True,
#  'click_off': False,
#  'pre_check_thankyou': True,
#  'cpl_value': 15,
#  'partner_type': 'dealer_direct',
#  'vin': '5YJ3E1EAXKF428426',
#  'provider': None,
#  'provider_name': 'car_gurus',
#  'always_ask_for_zip': False,
#  'listing_id': None,
#  'time_on_market': None,
#  'total_price_change': None,
#  'relative_price_difference': None,
#  'listimate_category': None,
#  'listimate_text': None,
#  'photo_urls': [],
#  'tracking_params': {'id_from_provider': '309098553',
#   'remote_dealer_id': '413397',
#   'dealer_name': 'Shift SF - Test Drives Delivered to You',
#   'remote_sku': 'c1271376',
#   'experience': 'regional',
#   'rooftop_unique_name': None,
#   'rooftop_uuid': None,
#   'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#   'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#   'dealer_group_unique_name': 'shift_cargurus',
#   'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540'},
#  'trim': 'Standard Range',
#  'provider_id': 199,
#  'provider_group_id': 231,
#  'experience': 'regional',
#  'regional': True,
#  'badges': {'position0': None, 'position1': None},
#  'quick_picks_eligible': False}

# %%
# modelo 
results_json['search_results'][0]['model']
# Out:
# 'Jetta'

# %%
# Kilometraje
results_json['search_results'][0]['mileage']
# Out:
# '43,183 Miles'

# %%
# año
results_json['search_results'][0]['year']
# Out:
# 2017

# %%
# nombre de distribuidor
results_json['search_results'][0]['dealer_name']
# Out:
# 'CarMax Brooklyn Park - Now Offering Curbside Pickup'

# %%
# precio (dolares)
results_json['search_results'][0]['price']
# Out:
# '$18,998'

# %%
# Poner todo junto - Hacer un loop for a través de los resultados y añadir datos dentro de una lista
modelo = []
kilometraje = []
año = []
nom_distribuidor = []
precio = []

for result in result_items:
    
    # modelo
    modelo.append(result['model'])
    
    # kilometraje
    kilometraje.append(result['mileage'])
    
    # año
    año.append(result['year']) 
    
    # nombre de distribuidor
    nom_distribuidor.append(result['dealer_name']) 
    
    # precio
    precio.append(result['price'])

# %%
# crear Dataframe - una pagina
df = pd.DataFrame({'Modelo': modelo, 'Kilometraje':kilometraje, 'Año':año, 
                   'Nom_distribuidor': nom_distribuidor,'Precio': precio})

# %%
df
# Out:
#              Modelo   Kilometraje   Año  \
# 0             Jetta  43,183 Miles  2017
# 1            Golf R  54,682 Miles  2016
# 2             Jetta  87,585 Miles  2015
# 3            Passat  64,144 Miles  2016
# 4            Tiguan  28,959 Miles  2018
# 5             Jetta  46,804 Miles  2017
# 6           Touareg  53,590 Miles  2017
# 7            Passat  40,191 Miles  2016
# 8             Jetta  62,366 Miles  2016
# 9             Jetta  69,527 Miles  2014
# 10           Golf R   9,886 Miles  2019
# 11            Jetta  14,970 Miles  2019
# 12            Jetta  22,769 Miles  2019
# 13  Golf SportWagen  15,234 Miles  2018
# 14           Arteon  12,138 Miles  2019
# 15           Tiguan  28,934 Miles  2019
# 16            Jetta  48,183 Miles  2019
# 17           Tiguan  10,391 Miles  2018
# 18            Jetta  40,448 Miles  2017
# 19           Tiguan   8,757 Miles  2020
#
#                                      Nom_distribuidor   Precio
# 0   CarMax Brooklyn Park - Now Offering Curbside P...  $18,998
# 1                CarMax Capitol Expressway - Now Open  $31,998
# 2   CarMax Plano - Now Offering Curbside Pickup An...  $14,998
# 3   CarMax Ft. Lauderdale - Now Offering Curbside ...  $16,998
# 4   CarMax Killeen - Now Offering Curbside Pickup ...  $21,998
# 5         CarMax Omaha - Now Offering Curbside Pickup  $17,998
# 6     CarMax Rivergate - Now Offering Curbside Pickup  $31,998
# 7   CarMax Cool Springs - Now Offering Curbside Pi...  $18,998
# 8      CarMax Lynnwood - Now Offering Curbside Pickup  $15,998
# 9   CarMax Clearwater - Now Offering Curbside Pick...  $14,599
# 10  CarMax West Sahara - Now Offering Curbside Pic...  $44,998
# 11  CarMax South Broadway - Now Offering Curbside ...  $19,998
# 12  CarMax Westborough - Now Offering Curbside Pickup  $19,998
# 13        CarMax Salem - Now Offering Curbside Pickup  $24,998
# 14  CarMax Costa Mesa - Now Offering Curbside Pick...  $29,998
# 15  CarMax South Boulevard - Now Offering Curbside...  $23,998
# 16  CarMax LAX - Now Offering Curbside Pickup And ...  $20,998
# 17  CarMax Capital Boulevard - Now Offering Curbsi...  $31,998
# 18    CarMax Beaverton - Now Offering Curbside Pickup  $19,998
# 19  CarMax South Boulevard - Now Offering Curbside...  $39,998

# %%
# crear archivo csv
# df.to_csv('tesla_single_page.csv', index=False)

# %% [markdown]
# ####  Scraping Multiples paginas  ( 5 paginas )

# %%
# url by calaya
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

url = "https://www.autolist.com/api/cwv/seo/listings?make=Volkswagen&location=Celaya,%20Gto.&latitude=20.5135374&longitude=-100.8160686&radius=50&page=1"

response = requests.get(url, headers=headers)

modelo = []
kilometraje = []
año = []
nom_distribuidor = []
precio = []

# 5 paginas
for i in range(1,6):

    """params = (
        ('make', 'Tesla'),
        ('location', 'San^%^20Francisco,^%^20CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page', str(i)),
    )"""
    
    
    # json object
    results_json = response.json()
    
    # result items (20 items por cada pagina)
    result_items = results_json['search_results']
    
    for result in result_items:
        modelo.append(result['model'])
        kilometraje.append(result['mileage'])
        año.append(result['year']) 
        nom_distribuidor.append(result['dealer_name']) 
        precio.append(result['price'])

# %%
multiple_df = pd.DataFrame({'Modelo': modelo, 'Kilometraje':kilometraje, 'Año':año, 
                            'Nom_distribuidor': nom_distribuidor, 'Precio': precio})

# %%
multiple_df
# Out:
#     Modelo   Kilometraje   Año  \
# 0    Jetta  43,183 Miles  2017
# 1   Golf R  54,682 Miles  2016
# 2    Jetta  87,585 Miles  2015
# 3   Passat  64,144 Miles  2016
# 4   Tiguan  28,959 Miles  2018
# ..     ...           ...   ...
# 95  Tiguan  28,934 Miles  2019
# 96   Jetta  48,183 Miles  2019
# 97  Tiguan  10,391 Miles  2018
# 98   Jetta  40,448 Miles  2017
# 99  Tiguan   8,757 Miles  2020
#
#                                      Nom_distribuidor   Precio
# 0   CarMax Brooklyn Park - Now Offering Curbside P...  $18,998
# 1                CarMax Capitol Expressway - Now Open  $31,998
# 2   CarMax Plano - Now Offering Curbside Pickup An...  $14,998
# 3   CarMax Ft. Lauderdale - Now Offering Curbside ...  $16,998
# 4   CarMax Killeen - Now Offering Curbside Pickup ...  $21,998
# ..                                                ...      ...
# 95  CarMax South Boulevard - Now Offering Curbside...  $23,998
# 96  CarMax LAX - Now Offering Curbside Pickup And ...  $20,998
# 97  CarMax Capital Boulevard - Now Offering Curbsi...  $31,998
# 98    CarMax Beaverton - Now Offering Curbside Pickup  $19,998
# 99  CarMax South Boulevard - Now Offering Curbside...  $39,998
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Crear archivo csv y almacenar los datos

# %%
multiple_df.to_csv('volkswagen_multiple_pages.csv', index=False)

# %%
# revisar el csv creado
pd.read_csv('volkswagen_multiple_pages.csv')
# Out:
#     Modelo   Kilometraje   Año  \
# 0    Jetta  43,183 Miles  2017
# 1   Golf R  54,682 Miles  2016
# 2    Jetta  87,585 Miles  2015
# 3   Passat  64,144 Miles  2016
# 4   Tiguan  28,959 Miles  2018
# ..     ...           ...   ...
# 95  Tiguan  28,934 Miles  2019
# 96   Jetta  48,183 Miles  2019
# 97  Tiguan  10,391 Miles  2018
# 98   Jetta  40,448 Miles  2017
# 99  Tiguan   8,757 Miles  2020
#
#                                      Nom_distribuidor   Precio
# 0   CarMax Brooklyn Park - Now Offering Curbside P...  $18,998
# 1                CarMax Capitol Expressway - Now Open  $31,998
# 2   CarMax Plano - Now Offering Curbside Pickup An...  $14,998
# 3   CarMax Ft. Lauderdale - Now Offering Curbside ...  $16,998
# 4   CarMax Killeen - Now Offering Curbside Pickup ...  $21,998
# ..                                                ...      ...
# 95  CarMax South Boulevard - Now Offering Curbside...  $23,998
# 96  CarMax LAX - Now Offering Curbside Pickup And ...  $20,998
# 97  CarMax Capital Boulevard - Now Offering Curbsi...  $31,998
# 98    CarMax Beaverton - Now Offering Curbside Pickup  $19,998
# 99  CarMax South Boulevard - Now Offering Curbside...  $39,998
#
# [100 rows x 5 columns]

# %%
import pymysql

# %%
# creando connecion con mysql
conn = pymysql.connect(database= 'autolist_volkswagen', user= 'root', password= 'dadax_0331//_1330')

# %%
# creando cursor
cursor = conn.cursor()

# %%
# probando conceccion la base de datos
cursor.execute('SELECT * FROM cars_volkswagen_celaya')
# Out:
# 0

# %% [markdown]
# **creando INSERT TO statement**

# %%
insert_query = 'INSERT INTO cars_volkswagen_celaya VALUES '

# %%
insert_query
# Out:
# 'INSERT INTO cars_volkswagen_celaya VALUES '

# %%
# 100 filas 5 columnas
multiple_df.shape
# Out:
# (100, 5)

# %%
multiple_df.columns.values
# Out:
# array(['Modelo', 'Kilometraje', 'Año', 'Nom_distribuidor', 'Precio'],
#       dtype=object)

# %%
multiple_df.columns.values[3]
# Out:
# 'Nom_distribuidor'

# %%
multiple_df['Nom_distribuidor']
# Out:
# 0     CarMax Brooklyn Park - Now Offering Curbside P...
# 1                  CarMax Capitol Expressway - Now Open
# 2     CarMax Plano - Now Offering Curbside Pickup An...
# 3     CarMax Ft. Lauderdale - Now Offering Curbside ...
# 4     CarMax Killeen - Now Offering Curbside Pickup ...
#                             ...
# 95    CarMax South Boulevard - Now Offering Curbside...
# 96    CarMax LAX - Now Offering Curbside Pickup And ...
# 97    CarMax Capital Boulevard - Now Offering Curbsi...
# 98      CarMax Beaverton - Now Offering Curbside Pickup
# 99    CarMax South Boulevard - Now Offering Curbside...
# Name: Nom_distribuidor, Length: 100, dtype: object

# %%
# revisando los valores correctos
multiple_df['Nom_distribuidor'][0]
# Out:
# 'CarMax Brooklyn Park - Now Offering Curbside Pickup'

# %%
# creando los valores de la query INSERT TO
for i in range(multiple_df.shape[0]):
    insert_query += '('
    
    for j in range(multiple_df.shape[1]):
        insert_query += str(multiple_df[multiple_df.columns.values[j]][i]) + ', '
        
    insert_query = insert_query[:-2] + '), '

# %%
insert_query
# Out:
# 'INSERT INTO cars_volkswagen_celaya VALUES (Jetta, 43,183 Miles, 2017, CarMax Brooklyn Park - Now Offering Curbside Pickup, $18,998) (Golf R, 54,682 Miles, 2016, CarMax Capitol Expressway - Now Open, $31,998) (Jetta, 87,585 Miles, 2015, CarMax Plano - Now Offering Curbside Pickup And Home Delivery, $14,998) (Passat, 64,144 Miles, 2016, CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery, $16,998) (Tiguan, 28,959 Miles, 2018, CarMax Killeen - Now Offering Curbside Pickup And Home Delivery, $21,998) (Jetta, 46,804 Miles, 2017, CarMax Omaha - Now Offering Curbside Pickup, $17,998) (Touareg, 53,590 Miles, 2017, CarMax Rivergate - Now Offering Curbside Pickup, $31,998) (Passat, 40,191 Miles, 2016, CarMax Cool Springs - Now Offering Curbside Pickup, $18,998) (Jetta, 62,366 Miles, 2016, CarMax Lynnwood - Now Offering Curbside Pickup, $15,998) (Jetta, 69,527 Miles, 2014, CarMax Clearwater - Now Offering Curbside Pickup And Home Delivery, $14,599) (Golf R, 9,886 Miles, 2019, CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery, $44,998) (Jetta, 14,970 Miles, 2019, CarMax South Broadway - Now Offering Curbside Pickup And Home Delivery, $19,998) (Jetta, 22,769 Miles, 2019, CarMax Westborough - Now Offering Curbside Pickup, $19,998) (Golf SportWagen, 15,234 Miles, 2018, CarMax Salem - Now Offering Curbside Pickup, $24,998) (Arteon, 12,138 Miles, 2019, CarMax Costa Mesa - Now Offering Curbside Pickup And Home Delivery, $29,998) (Tiguan, 28,934 Miles, 2019, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $23,998) (Jetta, 48,183 Miles, 2019, CarMax LAX - Now Offering Curbside Pickup And Home Delivery, $20,998) (Tiguan, 10,391 Miles, 2018, CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery, $31,998) (Jetta, 40,448 Miles, 2017, CarMax Beaverton - Now Offering Curbside Pickup, $19,998) (Tiguan, 8,757 Miles, 2020, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $39,998) (Jetta, 43,183 Miles, 2017, CarMax Brooklyn Park - Now Offering Curbside Pickup, $18,998) (Golf R, 54,682 Miles, 2016, CarMax Capitol Expressway - Now Open, $31,998) (Jetta, 87,585 Miles, 2015, CarMax Plano - Now Offering Curbside Pickup And Home Delivery, $14,998) (Passat, 64,144 Miles, 2016, CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery, $16,998) (Tiguan, 28,959 Miles, 2018, CarMax Killeen - Now Offering Curbside Pickup And Home Delivery, $21,998) (Jetta, 46,804 Miles, 2017, CarMax Omaha - Now Offering Curbside Pickup, $17,998) (Touareg, 53,590 Miles, 2017, CarMax Rivergate - Now Offering Curbside Pickup, $31,998) (Passat, 40,191 Miles, 2016, CarMax Cool Springs - Now Offering Curbside Pickup, $18,998) (Jetta, 62,366 Miles, 2016, CarMax Lynnwood - Now Offering Curbside Pickup, $15,998) (Jetta, 69,527 Miles, 2014, CarMax Clearwater - Now Offering Curbside Pickup And Home Delivery, $14,599) (Golf R, 9,886 Miles, 2019, CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery, $44,998) (Jetta, 14,970 Miles, 2019, CarMax South Broadway - Now Offering Curbside Pickup And Home Delivery, $19,998) (Jetta, 22,769 Miles, 2019, CarMax Westborough - Now Offering Curbside Pickup, $19,998) (Golf SportWagen, 15,234 Miles, 2018, CarMax Salem - Now Offering Curbside Pickup, $24,998) (Arteon, 12,138 Miles, 2019, CarMax Costa Mesa - Now Offering Curbside Pickup And Home Delivery, $29,998) (Tiguan, 28,934 Miles, 2019, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $23,998) (Jetta, 48,183 Miles, 2019, CarMax LAX - Now Offering Curbside Pickup And Home Delivery, $20,998) (Tiguan, 10,391 Miles, 2018, CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery, $31,998) (Jetta, 40,448 Miles, 2017, CarMax Beaverton - Now Offering Curbside Pickup, $19,998) (Tiguan, 8,757 Miles, 2020, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $39,998) (Jetta, 43,183 Miles, 2017, CarMax Brooklyn Park - Now Offeri ...

# %%
insert_query = insert_query[:-2] + ';'

# %%
insert_query
# Out:
# 'INSERT INTO cars_volkswagen_celaya VALUES (Jetta, 43,183 Miles, 2017, CarMax Brooklyn Park - Now Offering Curbside Pickup, $18,998) (Golf R, 54,682 Miles, 2016, CarMax Capitol Expressway - Now Open, $31,998) (Jetta, 87,585 Miles, 2015, CarMax Plano - Now Offering Curbside Pickup And Home Delivery, $14,998) (Passat, 64,144 Miles, 2016, CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery, $16,998) (Tiguan, 28,959 Miles, 2018, CarMax Killeen - Now Offering Curbside Pickup And Home Delivery, $21,998) (Jetta, 46,804 Miles, 2017, CarMax Omaha - Now Offering Curbside Pickup, $17,998) (Touareg, 53,590 Miles, 2017, CarMax Rivergate - Now Offering Curbside Pickup, $31,998) (Passat, 40,191 Miles, 2016, CarMax Cool Springs - Now Offering Curbside Pickup, $18,998) (Jetta, 62,366 Miles, 2016, CarMax Lynnwood - Now Offering Curbside Pickup, $15,998) (Jetta, 69,527 Miles, 2014, CarMax Clearwater - Now Offering Curbside Pickup And Home Delivery, $14,599) (Golf R, 9,886 Miles, 2019, CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery, $44,998) (Jetta, 14,970 Miles, 2019, CarMax South Broadway - Now Offering Curbside Pickup And Home Delivery, $19,998) (Jetta, 22,769 Miles, 2019, CarMax Westborough - Now Offering Curbside Pickup, $19,998) (Golf SportWagen, 15,234 Miles, 2018, CarMax Salem - Now Offering Curbside Pickup, $24,998) (Arteon, 12,138 Miles, 2019, CarMax Costa Mesa - Now Offering Curbside Pickup And Home Delivery, $29,998) (Tiguan, 28,934 Miles, 2019, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $23,998) (Jetta, 48,183 Miles, 2019, CarMax LAX - Now Offering Curbside Pickup And Home Delivery, $20,998) (Tiguan, 10,391 Miles, 2018, CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery, $31,998) (Jetta, 40,448 Miles, 2017, CarMax Beaverton - Now Offering Curbside Pickup, $19,998) (Tiguan, 8,757 Miles, 2020, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $39,998) (Jetta, 43,183 Miles, 2017, CarMax Brooklyn Park - Now Offering Curbside Pickup, $18,998) (Golf R, 54,682 Miles, 2016, CarMax Capitol Expressway - Now Open, $31,998) (Jetta, 87,585 Miles, 2015, CarMax Plano - Now Offering Curbside Pickup And Home Delivery, $14,998) (Passat, 64,144 Miles, 2016, CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery, $16,998) (Tiguan, 28,959 Miles, 2018, CarMax Killeen - Now Offering Curbside Pickup And Home Delivery, $21,998) (Jetta, 46,804 Miles, 2017, CarMax Omaha - Now Offering Curbside Pickup, $17,998) (Touareg, 53,590 Miles, 2017, CarMax Rivergate - Now Offering Curbside Pickup, $31,998) (Passat, 40,191 Miles, 2016, CarMax Cool Springs - Now Offering Curbside Pickup, $18,998) (Jetta, 62,366 Miles, 2016, CarMax Lynnwood - Now Offering Curbside Pickup, $15,998) (Jetta, 69,527 Miles, 2014, CarMax Clearwater - Now Offering Curbside Pickup And Home Delivery, $14,599) (Golf R, 9,886 Miles, 2019, CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery, $44,998) (Jetta, 14,970 Miles, 2019, CarMax South Broadway - Now Offering Curbside Pickup And Home Delivery, $19,998) (Jetta, 22,769 Miles, 2019, CarMax Westborough - Now Offering Curbside Pickup, $19,998) (Golf SportWagen, 15,234 Miles, 2018, CarMax Salem - Now Offering Curbside Pickup, $24,998) (Arteon, 12,138 Miles, 2019, CarMax Costa Mesa - Now Offering Curbside Pickup And Home Delivery, $29,998) (Tiguan, 28,934 Miles, 2019, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $23,998) (Jetta, 48,183 Miles, 2019, CarMax LAX - Now Offering Curbside Pickup And Home Delivery, $20,998) (Tiguan, 10,391 Miles, 2018, CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery, $31,998) (Jetta, 40,448 Miles, 2017, CarMax Beaverton - Now Offering Curbside Pickup, $19,998) (Tiguan, 8,757 Miles, 2020, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $39,998) (Jetta, 43,183 Miles, 2017, CarMax Brooklyn Park - Now Offeri ...

# %%
# ingresando la query a la base de datos
cursor.execute(insert_query)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-127-fef8f19cda10> in <module>
#       1 # ingresando la query a la base de datos
# ----> 2 cursor.execute(insert_query)
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~\anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'Miles, 2017, CarMax Brooklyn Park - Now Offering Curbside Pickup, $18,998) (Golf' at line 1")

# %%
conn.commit()

# %%
conn.close()
