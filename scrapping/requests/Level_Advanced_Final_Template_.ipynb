# %% [markdown]
# # Part 1 - Truecar.com - New York

# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd 
from sqlalchemy import create_engine

# %% [markdown]
# #### Step 2 - Python Request

# %%
headers = {
    'authority': 'www.truecar.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
    'accept': 'application/json, text/plain, */*',
    'x-xsrf-token': 'Ur/kxt0PrKLpIlS3QELPXZBZHMSME0gTzs47TPfIUiC1LJqIt9HlLYrLTMgwB5qE6zC2M5Psn5Er+4Qm82MgEA==',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-new-york-ny/',
    'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
    'cookie': 'tc_v=732d8f6c-016d-4e04-99ea-962821b285bd; u=rBEABWDn9kVuLQARuYhKAg==; user_zip_code_san-francisco-ca=94102; user_zip_code_new-york-ny=10001; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=aLdzR1stp7FxiV6Cbnggg8fmtny6X9FAap2fnCqWeXg; referrer=ZTC0000000; g_state=^{^\\^i_p^\\^:1628151776913,^\\^i_l^\\^:2^}; capselaPreferredPostalCode=10001; XSRF-TOKEN=Ur^%^2Fkxt0PrKLpIlS3QELPXZBZHMSME0gTzs47TPfIUiC1LJqIt9HlLYrLTMgwB5qE6zC2M5Psn5Er^%^2B4Qm82MgEA^%^3D^%^3D; _abp_backend_session=cnN3bFdMQjJQYTlwRFFvS3oybm1oWTl0SVc3NVNGRng5Y01GWHlxa3BybWFJRXM1UkFueTFRWUhMYUtSVW1YZWxNaUFIZ2ZjS2FUQ2pVeURRNG5PeEh6VlRFQjZnRmFLN01PWHZFdjBQTis5UG9VRGFtWko4MFZNY2ZUUGRmS1pkSFdmcnB4TVkwMnJGREZBblZla1RRPT0tLW5BQjFPdHVvTk1VbHJZL3lwQ2MrTUE9PQ^%^3D^%^3D--a4caf99167368bcbbcd454b4ffe52eb35169abe0; _dd_s=rum=0&expire=1628067151364',
    'if-none-match': 'W/^\\^ad5f12263df3f1f7dad67afa854d2880^\\^',
}

params = (
    ('city', 'new-york'),
    ('collapse', 'true'),
    ('fallback', 'true'),
    ('include_incentives', 'true'),
    ('include_targeted_incentives', 'true'),
    ('new_or_used', 'u'),
    ('page', '1'),
    ('per_page', '30'),
    ('postal_code', '10001'),
    ('search_event', 'true'),
    ('sort^/[^/]', 'best_match'),
    ('sponsored', 'true'),
    ('state', 'ny'),
)

response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings?city=new-york&collapse=true&fallback=true&include_incentives=true&include_targeted_incentives=true&new_or_used=u&page=2&per_page=30&postal_code=10001&search_event=true&sort^\[^\]=best_match&sponsored=true&state=ny', headers=headers)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
response.json()
# Out:
# {'listings': [{'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'AWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7318,
#     'model_slug': 'c-class',
#     'model': 'C-Class',
#     'mpg_city': 23,
#     'mpg_combined': 26,
#     'mpg_highway': 32,
#     'style_id': 59105,
#     'style_slug': 'c-300-4matic-sedan',
#     'style': 'C 300 4MATIC Sedan',
#     'transmission': 'Automatic',
#     'trim_slug': 'c-300',
#     'trim': 'C 300 4MATIC Sedan',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395165,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'Black',
#     'exterior_color_rgb': '0A0A0B',
#     'exterior_color': 'Black',
#     'exterior_color_id': 887865,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': '1B1C20',
#     'interior_color_id': 887849,
#     'list_price': 32901.0,
#     'member_discount': 500.0,
#     'mileage': 33578,
#     'new_or_used': 'USED',
#     'stock_number': '706336',
#     'vin': '55SWF4KB2JU263445',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 41,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1633203785758,
#      'isFrameDamaged': False,
#      'ownerCount': 2,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB2JU263445',
#      'reportPullDateString': '2021-10-02T19:43:05.758+00:00'},
#     'truecar_plus_eligible': None,
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB2JU263445',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/45/34/55SWF4KB2JU263445/5KGRRRXITTJWGEHCACZ4LTSHDQ-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/45/34/55SWF4KB2JU263445/5KGRRRXITTJWGEHCACZ4LTSHDQ-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-10-02T18:40:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 1024,
#       'cropAvailable': True,
#       'hash': 'listings/2441/45/34/55SWF4KB2JU263445/5KGRRRXITTJWGEHCACZ4LTSHDQ',
#       'height': 768}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 32901,
#     'member_discount': None,
#     'member_price': 32901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 32901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 93,
#     'market_difference': 2182.98,
#     'market_difference_display': 1289,
#     'market_difference_percent': 0.062,
#     'market_difference_percent_display': 3.9,
#     'rating': 'EXCELLENT',
#     'callout': {'label': 'Excellent Price',
#      'quality': 'EXCELLENT',
#      'quality_index': 0},
#     'great': 34733.14,
#     'good': 36136.5,
#     'min': 26312.98,
#     'max': 43854.98,
#     'avg': 35083.98,
#     'exceptional': 33329.78},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': '55SWF4KB2JU263445'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'AWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7318,
#     'model_slug': 'c-class',
#     'model': 'C-Class',
#     'mpg_city': 23,
#     'mpg_combined': 26,
#     'mpg_highway': 32,
#     'style_id': 59105,
#     'style_slug': 'c-300-4matic-sedan',
#     'style': 'C 300 4MATIC Sedan',
#     'transmission': 'Automatic',
#     'trim_slug': 'c-300',
#     'trim': 'C 300 4MATIC Sedan',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395165,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'Black',
#     'exterior_color_rgb': '0A0A0B',
#     'exterior_color': 'Black',
#     'exterior_color_id': 887865,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': '1B1C20',
#     'interior_color_id': 887854,
#     'list_price': 33901.0,
#     'member_discount': 500.0,
#     'mileage': 23709,
#     'new_or_used': 'USED',
#     'stock_number': '183199',
#     'vin': 'WDDWF4KB9JR423290',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 75,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1632862816906,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDWF4KB9JR423290',
#      'reportPullDateString': '2021-09-28T21:00:16.906+00:00'},
#     'truecar_plus_eligible': None,
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDWF4KB9JR423290',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/90/32/WDDWF4KB9JR423290/GWT5BRKDFWHZH67AMK3LBZLJXM-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/90/32/WDDWF4KB9JR423290/GWT5BRKDFWHZH67AMK3LBZLJXM-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-09-28T18:40:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 640,
#       'cropAvailable': True,
#       'hash': 'listings/2441/90/32/WDDWF4KB9JR423290/GWT5BRKDFWHZH67AMK3LBZLJXM',
#       'height': 480}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 33901,
#     'member_discount': None,
#     'member_price': 33901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 33901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 18,
#     'market_difference': 1509.66,
#     'market_difference_display': 830,
#     'market_difference_percent': 0.043,
#     'market_difference_percent_display': 2.4,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 35056.55,
#     'good': 36472.98,
#     'min': 26557.99,
#     'max': 44263.32,
#     'avg': 35410.66,
#     'exceptional': 33640.12},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': 'WDDWF4KB9JR423290'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'AWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7318,
#     'model_slug': 'c-class',
#     'model': 'C-Class',
#     'mpg_city': 23,
#     'mpg_combined': 26,
#     'mpg_highway': 32,
#     'style_id': 59105,
#     'style_slug': 'c-300-4matic-sedan',
#     'style': 'C 300 4MATIC Sedan',
#     'transmission': 'Automatic',
#     'trim_slug': 'c-300',
#     'trim': 'C 300 4MATIC Sedan',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395165,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'White',
#     'exterior_color_rgb': 'E3E4E8',
#     'exterior_color': 'Polar White',
#     'exterior_color_id': 887864,
#     'interior_color': 'Silk Beige/Black',
#     'interior_color_generic': 'Beige',
#     'interior_color_rgb': 'E8D8BE',
#     'interior_color_id': 887855,
#     'list_price': 32901.0,
#     'member_discount': 500.0,
#     'mileage': 39768,
#     'new_or_used': 'USED',
#     'stock_number': '18748',
#     'vin': '55SWF4KB3JU282506',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 19,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1637696714736,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 1,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB3JU282506',
#      'reportPullDateString': '2021-11-23T19:45:14.736+00:00'},
#     'truecar_plus_eligible': None,
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB3JU282506',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/06/25/55SWF4KB3JU282506/35QAO63JZ3YTCXSGSSZ4Z6ZVCU-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/06/25/55SWF4KB3JU282506/35QAO63JZ3YTCXSGSSZ4Z6ZVCU-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-11-23T18:43:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 640,
#       'cropAvailable': True,
#       'hash': 'listings/2441/06/25/55SWF4KB3JU282506/35QAO63JZ3YTCXSGSSZ4Z6ZVCU',
#       'height': 480}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 32901,
#     'member_discount': None,
#     'member_price': 32901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 32901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 34,
#     'market_difference': 1230.99,
#     'market_difference_display': 643,
#     'market_difference_percent': 0.036,
#     'market_difference_percent_display': 2.0,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 33790.67,
#     'good': 35155.95,
#     'min': 25598.99,
#     'max': 42664.99,
#     'avg': 34131.99,
#     'exceptional': 32425.39},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': '55SWF4KB3JU282506'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'AWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7318,
#     'model_slug': 'c-class',
#     'model': 'C-Class',
#     'mpg_city': 23,
#     'mpg_combined': 26,
#     'mpg_highway': 32,
#     'style_id': 59105,
#     'style_slug': 'c-300-4matic-sedan',
#     'style': 'C 300 4MATIC Sedan',
#     'transmission': 'Automatic',
#     'trim_slug': 'c-300',
#     'trim': 'C 300 4MATIC Sedan',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395165,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'Black',
#     'exterior_color_rgb': '0A0A0B',
#     'exterior_color': 'Black',
#     'exterior_color_id': 887865,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': '1B1C20',
#     'interior_color_id': 887854,
#     'list_price': 34901.0,
#     'member_discount': 500.0,
#     'mileage': 20685,
#     'new_or_used': 'USED',
#     'stock_number': '18542',
#     'vin': '55SWF4KB4JU273751',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 8,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1638560201992,
#      'isFrameDamaged': False,
#      'ownerCount': 2,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB4JU273751',
#      'reportPullDateString': '2021-12-03T19:36:41.992+00:00'},
#     'truecar_plus_eligible': None,
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB4JU273751',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-12-04T00:43:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 640,
#       'cropAvailable': True,
#       'hash': 'listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54',
#       'height': 480}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 34901,
#     'member_discount': None,
#     'member_price': 34901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 34901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 34,
#     'market_difference': 1313.39,
#     'market_difference_display': 688,
#     'market_difference_percent': 0.036,
#     'market_difference_percent_display': 2.0,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 35852.25,
#     'good': 37300.82,
#     'min': 27160.79,
#     'max': 45267.99,
#     'avg': 36214.39,
#     'exceptional': 34403.67},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': '55SWF4KB4JU273751'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'RWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 7318,
#     'model_slug': 'c-class',
#     'model': 'C-Class',
#     'mpg_city': 24,
#     'mpg_combined': 27,
#     'mpg_highway': 33,
#     'style_id': 59102,
#     'style_slug': 'c-300-sedan-rwd',
#     'style': 'C 300 Sedan RWD',
#     'transmission': 'Automatic',
#     'trim_slug': 'c-300',
#     'trim': 'C 300 Sedan RWD',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 395164,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'Gray',
#     'exterior_color_rgb': '363938',
#     'exterior_color': 'Selenite Grey Metallic',
#     'exterior_color_id': 887729,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': '1B1C20',
#     'interior_color_id': 887665,
#     'list_price': 30901.0,
#     'member_discount': 500.0,
#     'mileage': 28863,
#     'new_or_used': 'USED',
#     'stock_number': '53169N',
#     'vin': '55SWF4JB2JU275189',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 22,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1637436833228,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4JB2JU275189',
#      'reportPullDateString': '2021-11-20T19:33:53.228+00:00'},
#     'truecar_plus_eligible': None,
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4JB2JU275189',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/89/51/55SWF4JB2JU275189/35N7YGLFXKUPMAGNLJDFLL6F74-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/89/51/55SWF4JB2JU275189/35N7YGLFXKUPMAGNLJDFLL6F74-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-11-20T18:42:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 640,
#       'cropAvailable': True,
#       'hash': 'listings/2441/89/51/55SWF4JB2JU275189/35N7YGLFXKUPMAGNLJDFLL6F74',
#       'height': 480}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 30901,
#     'member_discount': None,
#     'member_price': 30901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 30901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 80,
#     'market_difference': 2991.64,
#     'market_difference_display': 1814,
#     'market_difference_percent': 0.088,
#     'market_difference_percent_display': 5.9,
#     'rating': 'EXCELLENT',
#     'callout': {'label': 'Excellent Price',
#      'quality': 'EXCELLENT',
#      'quality_index': 0},
#     'great': 33553.72,
#     'good': 34909.42,
#     'min': 25419.48,
#     'max': 42365.81,
#     'avg': 33892.64,
#     'exceptional': 32198.01},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': '55SWF4JB2JU275189'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': 'AWD',
#     'engine': '3.5L V-6 Gas',
#     'fuel_type': 'Gas',
#     'make_id': 50,
#     'make_slug': 'lexus',
#     'make': 'Lexus',
#     'model_id': 8196,
#     'model_slug': 'rx',
#     'model': 'RX',
#     'mpg_city': 19,
#     'mpg_combined': 22,
#     'mpg_highway': 26,
#     'style_id': 63202,
#     'style_slug': 'rx-350-awd',
#     'style': 'RX 350 AWD',
#     'transmission': 'Automatic',
#     'trim_slug': 'rx-350',
#     'trim': 'RX 350 AWD',
#     'trim_id': None,
#     'year': 2019,
#     'chrome_trim_id': 403176,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_member',
#     'exterior_color_generic': 'Gray',
#     'exterior_color_rgb': '3C3D3E',
#     'exterior_color': 'Nebula Gray Pearl',
#     'exterior_color_id': 950221,
#     'interior_color': 'Black',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': '1B1C20',
#     'interior_color_id': 950210,
#     'list_price': 38569.0,
#     'member_discount': None,
#     'mileage': 34989,
#     'new_or_used': 'USED',
#     'stock_number': 'LM18047',
#     'vin': '2T2BZMCA1KC171676',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 66,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1633723869354,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=2T2BZMCA1KC171676',
#      'reportPullDateString': '2021-10-08T20:11:09.354+00:00'},
#     'truecar_plus_eligible': None,
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=2T2BZMCA1KC171676',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/5836/76/16/2T2BZMCA1KC171676/OZSYZINMDLGBZ3IAZGMTJNMTVU-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/5836/76/16/2T2BZMCA1KC171676/OZSYZINMDLGBZ3IAZGMTJNMTVU-318.jpg'],
#     'member_price': 38569.0},
#    'dealership': {'id': 5836,
#     'name': 'Lexus of Manhattan',
#     'links': {'website_link': 'www.lexusofmanhattan.com'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '627 11th Avenue',
#      'address2': None,
#      'postal_code': '10036',
#      'lat': 40.76402,
#      'lng': -73.99644,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 0.96},
#     'parent_id': 19544},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-10-08T18:40:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 1600,
#       'cropAvailable': True,
#       'hash': 'listings/5836/76/16/2T2BZMCA1KC171676/OZSYZINMDLGBZ3IAZGMTJNMTVU',
#       'height': 1067}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': None,
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your <span class="true-price"><strong>TRUE</strong>Price</span>',
#     'show_discount_post_lead': False,
#     'description': 'no_discounts',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': None},
#    'pricing': {'list_price': 38569,
#     'member_discount': None,
#     'member_price': 38569,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 38569,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 93,
#     'market_difference': 2632.26,
#     'market_difference_display': 1543,
#     'market_difference_percent': 0.064,
#     'market_difference_percent_display': 4.0,
#     'rating': 'EXCELLENT',
#     'callout': {'label': 'Excellent Price',
#      'quality': 'EXCELLENT',
#      'quality_index': 0},
#     'great': 40789.25,
#     'good': 42437.3,
#     'min': 30900.94,
#     'max': 51501.58,
#     'avg': 41201.26,
#     'exceptional': 39141.2},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': '2T2BZMCA1KC171676'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': 'AWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 4,
#     'make_slug': 'mercedes-benz',
#     'make': 'Mercedes-Benz',
#     'model_id': 8130,
#     'model_slug': 'glc',
#     'model': 'GLC',
#     'mpg_city': 22,
#     'mpg_combined': 24,
#     'mpg_highway': 27,
#     'style_id': 62744,
#     'style_slug': 'glc-300-4matic',
#     'style': 'GLC 300 4MATIC',
#     'transmission': 'Automatic',
#     'trim_slug': 'glc-300',
#     'trim': 'GLC 300 4MATIC',
#     'trim_id': None,
#     'year': 2019,
#     'chrome_trim_id': 402571,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'White',
#     'exterior_color_rgb': 'D2D0C1',
#     'exterior_color': 'Polar White',
#     'exterior_color_id': 944212,
#     'interior_color': 'Silk Beige Mb-Tex',
#     'interior_color_generic': 'Beige',
#     'interior_color_rgb': None,
#     'interior_color_id': None,
#     'list_price': 40901.0,
#     'member_discount': 500.0,
#     'mileage': 31021,
#     'new_or_used': 'USED',
#     'stock_number': '190816',
#     'vin': 'WDC0G4KBXKF545344',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 17,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1637786638435,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDC0G4KBXKF545344',
#      'reportPullDateString': '2021-11-24T20:43:58.435+00:00'},
#     'truecar_plus_eligible': None,
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDC0G4KBXKF545344',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/2441/44/53/WDC0G4KBXKF545344/ZIDUVKSRSQK2S4MWRMDOWCTDTI-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/2441/44/53/WDC0G4KBXKF545344/ZIDUVKSRSQK2S4MWRMDOWCTDTI-318.jpg']},
#    'dealership': {'id': 2441,
#     'name': 'Mercedes-Benz Manhattan',
#     'links': {'website_link': 'http://www.mb-manhattan.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '770 11th Avenue',
#      'address2': None,
#      'postal_code': '10019',
#      'lat': 40.76813,
#      'lng': -73.99287,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 1.26},
#     'parent_id': None},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-11-24T19:49:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 640,
#       'cropAvailable': True,
#       'hash': 'listings/2441/44/53/WDC0G4KBXKF545344/ZIDUVKSRSQK2S4MWRMDOWCTDTI',
#       'height': 480}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your Upfront Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': 'Upfront Price Available'},
#    'pricing': {'list_price': 40901,
#     'member_discount': None,
#     'member_price': 40901,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 40901,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 80,
#     'market_difference': 749.53,
#     'market_difference_display': 245,
#     'market_difference_percent': 0.018,
#     'market_difference_percent_display': 0.6,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 41234.02,
#     'good': 42900.05,
#     'min': 31237.9,
#     'max': 52063.16,
#     'avg': 41650.53,
#     'exceptional': 39568.0},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': 'WDC0G4KBXKF545344'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': 'AWD',
#     'engine': '2.5L Inline-4 Gas',
#     'fuel_type': 'Gas',
#     'make_id': 43,
#     'make_slug': 'nissan',
#     'make': 'Nissan',
#     'model_id': 7495,
#     'model_slug': 'rogue',
#     'model': 'Rogue',
#     'mpg_city': 25,
#     'mpg_combined': 27,
#     'mpg_highway': 32,
#     'style_id': 60664,
#     'style_slug': 'sv-awd',
#     'style': 'SV AWD',
#     'transmission': 'Automatic',
#     'trim_slug': 'sv',
#     'trim': 'SV AWD',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 392017,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_all_tc',
#     'exterior_color_generic': 'Black',
#     'exterior_color_rgb': '1D2020',
#     'exterior_color': 'Magnetic Black',
#     'exterior_color_id': None,
#     'interior_color': 'Charcoal',
#     'interior_color_generic': 'Black',
#     'interior_color_rgb': None,
#     'interior_color_id': None,
#     'list_price': 18495.0,
#     'member_discount': 0.0,
#     'mileage': 45032,
#     'new_or_used': 'USED',
#     'stock_number': '616587',
#     'vin': 'KNMAT2MV5JP616587',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 43,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {'interior': [{'description': 'CHARCOAL, CLOTH SEAT TRIM',
#        'msrp': 0.0,
#        'features': None,
#        'oem_code': 'G'}],
#      'additional equipment': [{'description': 'MARCH SOP SPEC',
#        'msrp': 0.0,
#        'features': None,
#        'oem_code': 'MAR'},
#       {'description': 'CHROME REAR BUMPER PROTECTOR',
#        'msrp': 155.0,
#        'features': None,
#        'oem_code': 'BUM'},
#       {'description': 'BLACK SPLASH GUARDS (SET OF 4)',
#        'msrp': 160.0,
#        'features': None,
#        'oem_code': 'SGD'},
#       {'description': 'FLOOR MATS & 2-PC CARGO AREA PROTECTOR',
#        'msrp': 275.0,
#        'features': ['2-pc front and 2-pc 2nd row floor mats', 'First Aid Kit'],
#        'oem_code': 'FL2'}]},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1635669297054,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 1,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=KNMAT2MV5JP616587',
#      'reportPullDateString': '2021-10-31T08:34:57.054+00:00'},
#     'truecar_plus_eligible': None,
#     'multilocation': False,
#     'equipment_rating': 'basicEquipped',
#     'location': 'Middle Village, NY',
#     'price_dropped': False,
#     'certified_pre_owned': None,
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=KNMAT2MV5JP616587',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/24344/87/65/KNMAT2MV5JP616587/6BSPZLAW4R55NQF2GAAXDQWLH4-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/24344/87/65/KNMAT2MV5JP616587/6BSPZLAW4R55NQF2GAAXDQWLH4-318.jpg']},
#    'dealership': {'id': 24344,
#     'name': 'Road Masters II Inc.',
#     'links': {'website_link': 'http://www.roadmasters2.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '62-01 Freshpond Road',
#      'address2': None,
#      'postal_code': '11379',
#      'lat': 40.7136,
#      'lng': -73.90062,
#      'city': 'Middle Village',
#      'state': 'NY',
#      'distance': 5.63},
#     'parent_id': None},
#    'payments': {'lease': None,
#     'loan': {'total_monthly_payment': 331.05,
#      'monthly_payment': 301.53,
#      'monthly_tax': 29.52,
#      'total_due_at_signing': 1849.5,
#      'due_at_signing': 1849.5,
#      'taxes_due_at_signing': 0.0,
#      'term': 60,
#      'credit_score': 850,
#      'disclaimer': 'This loan estimate is based off a 60 month term and $1,849.50 down payment. It does not include fees charged by this dealer and may not reflect your actual tax liability.',
#      'down_payment': 1849.5}},
#    'listed_at': '2021-10-31T07:41:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 900,
#       'cropAvailable': True,
#       'hash': 'listings/24344/87/65/KNMAT2MV5JP616587/6BSPZLAW4R55NQF2GAAXDQWLH4',
#       'height': 675}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': 'Upfront Price Available',
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Dealer Price',
#     'show_discount_post_lead': True,
#     'description': 'restricted_state_and_list_prices',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': None},
#    'pricing': {'list_price': 18495,
#     'member_discount': None,
#     'member_price': 18495,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 18495,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 86,
#     'market_difference': 1549.6,
#     'market_difference_display': 934,
#     'market_difference_percent': 0.077,
#     'market_difference_percent_display': 5.0,
#     'rating': 'EXCELLENT',
#     'callout': {'label': 'Excellent Price',
#      'quality': 'EXCELLENT',
#      'quality_index': 0},
#     'great': 19844.15,
#     'good': 20645.94,
#     'min': 15033.45,
#     'max': 25055.75,
#     'avg': 20044.6,
#     'exceptional': 19042.37},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': 'KNMAT2MV5JP616587'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': 'AWD',
#     'engine': '3.5L V-6 Gas',
#     'fuel_type': 'Gas',
#     'make_id': 50,
#     'make_slug': 'lexus',
#     'make': 'Lexus',
#     'model_id': 7515,
#     'model_slug': 'rx',
#     'model': 'RX',
#     'mpg_city': 19,
#     'mpg_combined': 22,
#     'mpg_highway': 26,
#     'style_id': 60812,
#     'style_slug': 'rx-350-awd',
#     'style': 'RX 350 AWD',
#     'transmission': 'Automatic',
#     'trim_slug': 'rx-350',
#     'trim': 'RX 350 AWD',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 397903,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_member',
#     'exterior_color_generic': 'Black',
#     'exterior_color_rgb': '1A1A1F',
#     'exterior_color': 'Caviar',
#     'exterior_color_id': 916869,
#     'interior_color': 'Noble Brown',
#     'interior_color_generic': 'Brown',
#     'interior_color_rgb': '513D3C',
#     'interior_color_id': 945344,
#     'list_price': 37869.0,
#     'member_discount': None,
#     'mileage': 24935,
#     'new_or_used': 'USED',
#     'stock_number': 'LM18113',
#     'vin': '2T2BZMCAXJC163526',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 27,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 1,
#      'reportPullDate': 1637178272380,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=2T2BZMCAXJC163526',
#      'reportPullDateString': '2021-11-17T19:44:32.380+00:00'},
#     'truecar_plus_eligible': None,
#     'multilocation': False,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': 'oem-certified',
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=2T2BZMCAXJC163526',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/5836/26/35/2T2BZMCAXJC163526/XAHZYMYJB4EYJTMUPVOG44YEV4-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/5836/26/35/2T2BZMCAXJC163526/XAHZYMYJB4EYJTMUPVOG44YEV4-318.jpg'],
#     'member_price': 37869.0},
#    'dealership': {'id': 5836,
#     'name': 'Lexus of Manhattan',
#     'links': {'website_link': 'www.lexusofmanhattan.com'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '627 11th Avenue',
#      'address2': None,
#      'postal_code': '10036',
#      'lat': 40.76402,
#      'lng': -73.99644,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 0.96},
#     'parent_id': 19544},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-11-17T18:42:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 1600,
#       'cropAvailable': True,
#       'hash': 'listings/5836/26/35/2T2BZMCAXJC163526/XAHZYMYJB4EYJTMUPVOG44YEV4',
#       'height': 1200}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': None,
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Your <span class="true-price"><strong>TRUE</strong>Price</span>',
#     'show_discount_post_lead': False,
#     'description': 'no_discounts',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': None},
#    'pricing': {'list_price': 37869,
#     'member_discount': None,
#     'member_price': 37869,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 37869,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 17,
#     'market_difference': 1693.33,
#     'market_difference_display': 947,
#     'market_difference_percent': 0.043,
#     'market_difference_percent_display': 2.5,
#     'rating': 'GREAT',
#     'callout': {'label': 'Great Price',
#      'quality': 'GREAT',
#      'quality_index': 1},
#     'great': 39166.7,
#     'good': 40749.19,
#     'min': 29671.74,
#     'max': 49452.91,
#     'avg': 39562.33,
#     'exceptional': 37584.21},
#    'collapse': {'collapsed': False,
#     'count': 1,
#     'consolidated_dealer': '2T2BZMCAXJC163526'},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'sedan',
#     'body_style': 'Sedan',
#     'drive_train': 'AWD',
#     'engine': '3.5L V-6 Gas',
#     'fuel_type': 'Gas',
#     'make_id': 50,
#     'make_slug': 'lexus',
#     'make': 'Lexus',
#     'model_id': 7466,
#     'model_slug': 'is',
#     'model': 'IS',
#     'mpg_city': 19,
#     'mpg_combined': 22,
#     'mpg_highway': 26,
#     'style_id': 60504,
#     'style_slug': 'is-300-awd',
#     'style': 'IS 300 AWD',
#     'transmission': 'Automatic',
#     'trim_slug': 'is-300',
#     'trim': 'IS 300 AWD',
#     'trim_id': None,
#     'year': 2018,
#     'chrome_trim_id': 397397,
#     'carfax_report_available': False,
#     'enable_discount': 'yes_member',
#     'exterior_color_generic': 'White',
#     'exterior_color_rgb': 'D7D4CC',
#     'exterior_color': 'Eminent White Pearl',
#     'exterior_color_id': 912404,
#     'interior_color': 'Chateau',
#     'interior_color_generic': 'Beige',
#     'interior_color_rgb': 'E8D8BE',
#     'interior_color_id': 912395,
#     'list_price': 31969.0,
#     'member_discount': None,
# ...
#      'lat': 40.65228,
#      'lng': -73.92129,
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'distance': 7.83},
#     'parent_id': 213191},
#    'payments': {'lease': None,
#     'loan': {'total_monthly_payment': 671.94,
#      'monthly_payment': 611.95,
#      'monthly_tax': 59.99,
#      'total_due_at_signing': 3638.4,
#      'due_at_signing': 3638.4,
#      'taxes_due_at_signing': 0.0,
#      'term': 60,
#      'credit_score': 850,
#      'disclaimer': 'This loan estimate is based off a 60 month term and $3,638.40 down payment. It does not include fees charged by this dealer and may not reflect your actual tax liability.',
#      'down_payment': 3638.4}},
#    'listed_at': '2021-10-28T00:36:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 1024,
#       'cropAvailable': True,
#       'hash': 'listings/22214/09/28/3PCAJ5M30KF102809/U3SRLOJ4DFR3JXGNEIMVJX2JGA',
#       'height': 768}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': None,
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Dealer Price',
#     'show_discount_post_lead': False,
#     'description': 'no_discounts',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': None},
#    'pricing': {'list_price': 36384,
#     'member_discount': None,
#     'member_price': 36384,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 36384,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 19,
#     'market_difference': -215.84,
#     'market_difference_display': 0,
#     'market_difference_percent': -0.006,
#     'market_difference_percent_display': 0.0,
#     'rating': 'FAIR',
#     'callout': {'label': 'Fair Price', 'quality': 'FAIR', 'quality_index': 2},
#     'great': 35806.48,
#     'good': 37253.21,
#     'min': 27126.12,
#     'max': 45210.2,
#     'avg': 36168.16,
#     'exceptional': 34359.75},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': '4WD',
#     'engine': '3.6L V-6 Gas',
#     'fuel_type': 'Gas',
#     'make_id': 34,
#     'make_slug': 'jeep',
#     'make': 'Jeep',
#     'model_id': 3803,
#     'model_slug': 'wrangler',
#     'model': 'Wrangler',
#     'mpg_city': 16,
#     'mpg_combined': 18,
#     'mpg_highway': 21,
#     'style_id': 55427,
#     'style_slug': 'unlimited-sahara',
#     'style': 'Unlimited Sahara',
#     'transmission': 'Automatic',
#     'trim_slug': 'sahara',
#     'trim': 'Unlimited Sahara',
#     'trim_id': None,
#     'year': 2017,
#     'chrome_trim_id': 386412,
#     'carfax_report_available': False,
#     'enable_discount': None,
#     'exterior_color_generic': 'Black',
#     'exterior_color_rgb': '0E0E0F',
#     'exterior_color': 'Black Clearcoat',
#     'exterior_color_id': None,
#     'interior_color': 'Dark Olive/Black',
#     'interior_color_generic': 'Green',
#     'interior_color_rgb': None,
#     'interior_color_id': None,
#     'list_price': 38995.0,
#     'member_discount': None,
#     'mileage': 49858,
#     'new_or_used': 'USED',
#     'stock_number': 'UR335',
#     'vin': '1C4HJWEGXHL627694',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 72,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {'mechanical': [{'description': 'ENGINE: 3.6L V6 24V VVT',
#        'msrp': 0.0,
#        'features': ['(STD)'],
#        'oem_code': 'ERB'},
#       {'description': 'TRANSMISSION: 5-SPEED AUTOMATIC (W5A580)',
#        'msrp': 1400.0,
#        'features': ['Tip Start', 'Hill Descent Control'],
#        'oem_code': 'DGJ'},
#       {'description': '3.21 REAR AXLE RATIO',
#        'msrp': 0.0,
#        'features': ['(STD)'],
#        'oem_code': 'DMC'}],
#      'packages': [{'description': 'QUICK ORDER PACKAGE 24G',
#        'msrp': 0.0,
#        'features': ['Engine: 3.6L V6 24V VVT',
#         'Transmission: 5-Speed Automatic (W5A580)',
#         'Body Color/Accent Color Grille',
#         'Body Color Appliques Front Bumper',
#         'Body Color Appliques Rear Bumper'],
#        'oem_code': '24G'}],
#      'exterior': [{'description': 'WHEELS: 18" X 7.5" POLISHED SATIN CARBON',
#        'msrp': 0.0,
#        'features': ['(STD)'],
#        'oem_code': 'WFC'}],
#      'interior': [{'description': 'DARK OLIVE/BLACK, LEATHER TRIMMED BUCKET SEATS',
#        'msrp': 1350.0,
#        'features': ['Front Seat Back Map Pockets',
#         'Driver Height Adjuster Seat',
#         'Heated Front Seats'],
#        'oem_code': 'ALXF'},
#       {'description': 'RADIO: 430 NAV',
#        'msrp': 1195.0,
#        'features': ['6.5" Touchscreen Display',
#         'Remote USB Port',
#         '5-Year SiriusXM Travel Link Service',
#         '40GB Hard Drive w/28GB Available',
#         'GPS Navigation',
#         'SiriusXM Travel Link'],
#        'oem_code': 'RHB'}],
#      'additional equipment': [{'description': 'CONNECTIVITY GROUP',
#        'msrp': 695.0,
#        'features': ['Vehicle Information Center',
#         'Remote USB Port',
#         'Uconnect Voice Command w/Bluetooth',
#         'Tire Pressure Monitoring Display'],
#        'oem_code': 'AAJ'},
#       {'description': 'DUAL TOP GROUP',
#        'msrp': 2185.0,
#        'features': ['Black 3-Piece Hard Top',
#         'Freedom Panel Storage Bag',
#         'Rear Window Defroster',
#         'Rear Window Wiper/Washer',
#         'Delete Sunrider Soft Top',
#         'Premium Black Sunrider Soft Top'],
#        'oem_code': 'AEM'},
#       {'description': 'PREMIUM BLACK SUNRIDER SOFT TOP',
#        'msrp': 0.0,
#        'features': None,
#        'oem_code': 'MX5'},
#       {'description': 'BLACK 3-PIECE HARD TOP',
#        'msrp': 0.0,
#        'features': ['Freedom Panel Storage Bag',
#         'Rear Window Defroster',
#         'Rear Window Wiper/Washer',
#         'Delete Sunrider Soft Top'],
#        'oem_code': 'MX3'},
#       {'description': 'JEEP TRAIL RATED KIT',
#        'msrp': 195.0,
#        'features': None,
#        'oem_code': 'XWX'},
#       {'description': 'HEATED FRONT SEATS',
#        'msrp': 0.0,
#        'features': None,
#        'oem_code': 'JPM'},
#       {'description': 'SUPPLEMENTAL FRONT SEAT SIDE AIR BAGS',
#        'msrp': 495.0,
#        'features': None,
#        'oem_code': 'CJ1'},
#       {'description': 'REMOTE START SYSTEM',
#        'msrp': 495.0,
#        'features': None,
#        'oem_code': 'XBM'},
#       {'description': 'AIR CONDITIONING W/AUTO TEMP CONTROL',
#        'msrp': 395.0,
#        'features': ['Humidity Sensor', 'Air Filtering'],
#        'oem_code': 'HAB'}]},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1637632624071,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': False,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=1C4HJWEGXHL627694',
#      'reportPullDateString': '2021-11-23T01:57:04.071+00:00'},
#     'truecar_plus_eligible': None,
#     'multilocation': False,
#     'equipment_rating': 'wellEquipped',
#     'location': 'Riverhead, NY',
#     'price_dropped': False,
#     'certified_pre_owned': None,
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=1C4HJWEGXHL627694',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/25090/94/76/1C4HJWEGXHL627694/BQDGXT75U3IBP6YAMVPF2GXTYY-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/25090/94/76/1C4HJWEGXHL627694/BQDGXT75U3IBP6YAMVPF2GXTYY-318.jpg']},
#    'dealership': {'id': 25090,
#     'name': 'Riverhead Chrysler Dodge Jeep Ram',
#     'links': {'website_link': 'https://www.riverheaddodge.com/'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': False},
#     'location': {'address1': '642 W Main St',
#      'address2': None,
#      'postal_code': '11901',
#      'lat': 40.9183,
#      'lng': -72.67094,
#      'city': 'Riverhead',
#      'state': 'NY',
#      'distance': 70.28},
#     'parent_id': 19286},
#    'payments': {'lease': None,
#     'loan': {'total_monthly_payment': 684.13,
#      'monthly_payment': 624.49,
#      'monthly_tax': 59.64,
#      'total_due_at_signing': 3899.5,
#      'due_at_signing': 3899.5,
#      'taxes_due_at_signing': 0.0,
#      'term': 60,
#      'credit_score': 850,
#      'disclaimer': 'This loan estimate is based off a 60 month term and $3,899.50 down payment. It does not include fees charged by this dealer and may not reflect your actual tax liability.',
#      'down_payment': 3899.5}},
#    'listed_at': '2021-11-23T00:43:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 640,
#       'cropAvailable': True,
#       'hash': 'listings/25090/94/76/1C4HJWEGXHL627694/BQDGXT75U3IBP6YAMVPF2GXTYY',
#       'height': 480}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': None,
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Dealer Price',
#     'show_discount_post_lead': False,
#     'description': 'no_discounts',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': None},
#    'pricing': {'list_price': 38995,
#     'member_discount': None,
#     'member_price': 38995,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 38995,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 97,
#     'market_difference': -1103.36,
#     'market_difference_display': -559,
#     'market_difference_percent': -0.029,
#     'market_difference_percent_display': -1.4,
#     'rating': 'FAIR',
#     'callout': {'label': 'Fair Price', 'quality': 'FAIR', 'quality_index': 2},
#     'great': 37512.72,
#     'good': 39028.39,
#     'min': 28418.73,
#     'max': 47364.55,
#     'avg': 37891.64,
#     'exceptional': 35997.06},
#    'prospected': False,
#    'prospected_at': None},
#   {'vehicle': {'body_style_slug': 'suv',
#     'body_style': 'SUV',
#     'drive_train': 'FWD',
#     'engine': '2.0L Inline-4 Gas Turbocharged',
#     'fuel_type': 'Gas',
#     'make_id': 47,
#     'make_slug': 'volvo',
#     'make': 'Volvo',
#     'model_id': 8104,
#     'model_slug': 'xc90',
#     'model': 'XC90',
#     'mpg_city': 21,
#     'mpg_combined': 24,
#     'mpg_highway': 29,
#     'style_id': 62519,
#     'style_slug': 't5-momentum-fwd',
#     'style': 'T5 Momentum FWD',
#     'transmission': 'Automatic',
#     'trim_slug': 'momentum',
#     'trim': 'T5 Momentum FWD',
#     'trim_id': None,
#     'year': 2019,
#     'chrome_trim_id': 401804,
#     'carfax_report_available': False,
#     'enable_discount': None,
#     'exterior_color_generic': 'White',
#     'exterior_color_rgb': 'DEDCD8',
#     'exterior_color': 'Crystal White Pearl Metallic',
#     'exterior_color_id': 940298,
#     'interior_color': 'Gray',
#     'interior_color_generic': 'Gray',
#     'interior_color_rgb': None,
#     'interior_color_id': None,
#     'list_price': 41499.0,
#     'member_discount': None,
#     'mileage': 32448,
#     'new_or_used': 'USED',
#     'stock_number': '448517',
#     'vin': 'YV4102CK7K1448517',
#     'truecar_make_id': None,
#     'truecar_model_id': None,
#     'doors': None,
#     'newly_listed': None,
#     'days_in_inventory': 19,
#     'make_logos': None,
#     'provider_name': None,
#     'request_price': None,
#     'manufacturer_options': [],
#     'bed_length': None,
#     'cab_type': None,
#     'roof_height': None,
#     'options': {},
#     'condition_history': {'isRentalCar': False,
#      'recallCount': 0,
#      'reportPullDate': 1639040387711,
#      'isFrameDamaged': False,
#      'ownerCount': 1,
#      'titleInfo': {'isSalvage': False,
#       'isCleanTitle': True,
#       'isLemon': False,
#       'isTheftRecovered': False,
#       'isFrameDamaged': False},
#      'isReportFree': False,
#      'maintenanceCount': 0,
#      'accidentCount': 0,
#      'isFleetCar': True,
#      'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=YV4102CK7K1448517',
#      'reportPullDateString': '2021-12-09T08:59:47.711+00:00'},
#     'truecar_plus_eligible': None,
#     'multilocation': True,
#     'equipment_rating': 'standard',
#     'location': 'New York, NY',
#     'price_dropped': False,
#     'certified_pre_owned': None,
#     'sponsored': None,
#     'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=YV4102CK7K1448517',
#     'frame_damaged': False,
#     'image': 'https://listings-prod.tcimg.net/listings/214232/17/85/YV4102CK7K1448517/3LWVHMXT5AYJWFWJY4TQJR7TBY-318.jpg',
#     'images': ['https://listings-prod.tcimg.net/listings/214232/17/85/YV4102CK7K1448517/3LWVHMXT5AYJWFWJY4TQJR7TBY-318.jpg']},
#    'dealership': {'id': 214232,
#     'name': 'Vroom',
#     'links': {'website_link': 'https://www.vroom.com/?utm_source=truecar&utm_campaign=national4&utm_medium=listings'},
#     'services': {'remote_purchasing': False,
#      'nationwide_delivery_provided': True},
#     'location': {'address1': '12053 Southwest Freeway (Highway 59)',
#      'address2': None,
#      'postal_code': '10013',
#      'lat': 40.7201984374718,
#      'lng': -74.0049785287648,
#      'city': 'New York',
#      'state': 'NY',
#      'distance': 2.11},
#     'parent_id': 102176},
#    'payments': {'lease': None, 'loan': None},
#    'listed_at': '2021-11-23T00:43:00.000+00:00',
#    'distance_retailing': False,
#    'images': [{'data': {'width': 1400,
#       'cropAvailable': False,
#       'hash': 'listings/214232/17/85/YV4102CK7K1448517/3LWVHMXT5AYJWFWJY4TQJR7TBY',
#       'height': 788}}],
#    'pricing_flags': {'show_list_price_label_pre_lead': False,
#     'discount_message_pre_lead': None,
#     'show_list_price_post_lead': False,
#     'cert_title': 'Offer',
#     'member_price_label_post_lead': 'Dealer Price',
#     'show_discount_post_lead': False,
#     'description': 'no_discounts',
#     'show_discount_pre_lead': False,
#     'discount_label_pre_lead': None},
#    'pricing': {'list_price': 41499,
#     'member_discount': None,
#     'member_price': 41499,
#     'total_fees': 0,
#     'other_fees_total': 0,
#     'dealer_installed_options_total': 0,
#     'total_fees_and_accessories': 0,
#     'total_price': 41499,
#     'transparency_pledge': None,
#     'list_price_includes_doc_fee': None,
#     'dealer_installed_options': [],
#     'savings_total': None,
#     'savings_total_percentage': None,
#     'other_fees': [],
#     'documentation_fee': None,
#     'tax_rate': None,
#     'price_history': None,
#     'tax_amount': None,
#     'total_taxed_price': None},
#    'price_curve': {'recent_offer_averages': None,
#     'curve_distance': 71,
#     'market_difference': 4932.19,
#     'market_difference_display': 2995,
#     'market_difference_percent': 0.106,
#     'market_difference_percent_display': 7.2,
#     'rating': 'EXCELLENT',
#     'callout': {'label': 'Excellent Price',
#      'quality': 'EXCELLENT',
#      'quality_index': 0},
#     'great': 45966.88,
#     'good': 47824.12,
#     'min': 34823.39,
#     'max': 58038.99,
#     'avg': 46431.19,
#     'exceptional': 44109.63},
#    'prospected': False,
#    'prospected_at': None}],
#  'location': {'postal_code': '10001',
#   'city': 'New York',
#   'state': 'NY',
#   'slug': 'new-york-ny',
#   'population': 1577385}}

# %%
results_json = response.json()

# %%
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['listings', 'page', 'per_page', 'total', 'fallback', 'fallback_step', 'refine_parameters', 'display', 'list_price', 'sponsored_listings', 'location'])

# %% [markdown]
# #### Step 6 - Find your Data

# %% [markdown]
# Necessary data
# - brand
# - model
# - mileage
# - year
# - price

# %%
results_json['listings']
# Out:
# [{'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7318,
#    'model_slug': 'c-class',
#    'model': 'C-Class',
#    'mpg_city': 23,
#    'mpg_combined': 26,
#    'mpg_highway': 32,
#    'style_id': 59105,
#    'style_slug': 'c-300-4matic-sedan',
#    'style': 'C 300 4MATIC Sedan',
#    'transmission': 'Automatic',
#    'trim_slug': 'c-300',
#    'trim': 'C 300 4MATIC Sedan',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395165,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '0A0A0B',
#    'exterior_color': 'Black',
#    'exterior_color_id': 887865,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 887849,
#    'list_price': 32901.0,
#    'member_discount': 500.0,
#    'mileage': 33578,
#    'new_or_used': 'USED',
#    'stock_number': '706336',
#    'vin': '55SWF4KB2JU263445',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 41,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1633203785758,
#     'isFrameDamaged': False,
#     'ownerCount': 2,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB2JU263445',
#     'reportPullDateString': '2021-10-02T19:43:05.758+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB2JU263445',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/45/34/55SWF4KB2JU263445/5KGRRRXITTJWGEHCACZ4LTSHDQ-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/45/34/55SWF4KB2JU263445/5KGRRRXITTJWGEHCACZ4LTSHDQ-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-10-02T18:40:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 1024,
#      'cropAvailable': True,
#      'hash': 'listings/2441/45/34/55SWF4KB2JU263445/5KGRRRXITTJWGEHCACZ4LTSHDQ',
#      'height': 768}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 32901,
#    'member_discount': None,
#    'member_price': 32901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 32901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 93,
#    'market_difference': 2182.98,
#    'market_difference_display': 1289,
#    'market_difference_percent': 0.062,
#    'market_difference_percent_display': 3.9,
#    'rating': 'EXCELLENT',
#    'callout': {'label': 'Excellent Price',
#     'quality': 'EXCELLENT',
#     'quality_index': 0},
#    'great': 34733.14,
#    'good': 36136.5,
#    'min': 26312.98,
#    'max': 43854.98,
#    'avg': 35083.98,
#    'exceptional': 33329.78},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '55SWF4KB2JU263445'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7318,
#    'model_slug': 'c-class',
#    'model': 'C-Class',
#    'mpg_city': 23,
#    'mpg_combined': 26,
#    'mpg_highway': 32,
#    'style_id': 59105,
#    'style_slug': 'c-300-4matic-sedan',
#    'style': 'C 300 4MATIC Sedan',
#    'transmission': 'Automatic',
#    'trim_slug': 'c-300',
#    'trim': 'C 300 4MATIC Sedan',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395165,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '0A0A0B',
#    'exterior_color': 'Black',
#    'exterior_color_id': 887865,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 887854,
#    'list_price': 33901.0,
#    'member_discount': 500.0,
#    'mileage': 23709,
#    'new_or_used': 'USED',
#    'stock_number': '183199',
#    'vin': 'WDDWF4KB9JR423290',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 75,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1632862816906,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDWF4KB9JR423290',
#     'reportPullDateString': '2021-09-28T21:00:16.906+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDDWF4KB9JR423290',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/90/32/WDDWF4KB9JR423290/GWT5BRKDFWHZH67AMK3LBZLJXM-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/90/32/WDDWF4KB9JR423290/GWT5BRKDFWHZH67AMK3LBZLJXM-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-09-28T18:40:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/2441/90/32/WDDWF4KB9JR423290/GWT5BRKDFWHZH67AMK3LBZLJXM',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 33901,
#    'member_discount': None,
#    'member_price': 33901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 33901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 18,
#    'market_difference': 1509.66,
#    'market_difference_display': 830,
#    'market_difference_percent': 0.043,
#    'market_difference_percent_display': 2.4,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 35056.55,
#    'good': 36472.98,
#    'min': 26557.99,
#    'max': 44263.32,
#    'avg': 35410.66,
#    'exceptional': 33640.12},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': 'WDDWF4KB9JR423290'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7318,
#    'model_slug': 'c-class',
#    'model': 'C-Class',
#    'mpg_city': 23,
#    'mpg_combined': 26,
#    'mpg_highway': 32,
#    'style_id': 59105,
#    'style_slug': 'c-300-4matic-sedan',
#    'style': 'C 300 4MATIC Sedan',
#    'transmission': 'Automatic',
#    'trim_slug': 'c-300',
#    'trim': 'C 300 4MATIC Sedan',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395165,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'White',
#    'exterior_color_rgb': 'E3E4E8',
#    'exterior_color': 'Polar White',
#    'exterior_color_id': 887864,
#    'interior_color': 'Silk Beige/Black',
#    'interior_color_generic': 'Beige',
#    'interior_color_rgb': 'E8D8BE',
#    'interior_color_id': 887855,
#    'list_price': 32901.0,
#    'member_discount': 500.0,
#    'mileage': 39768,
#    'new_or_used': 'USED',
#    'stock_number': '18748',
#    'vin': '55SWF4KB3JU282506',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 19,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1637696714736,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 1,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB3JU282506',
#     'reportPullDateString': '2021-11-23T19:45:14.736+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB3JU282506',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/06/25/55SWF4KB3JU282506/35QAO63JZ3YTCXSGSSZ4Z6ZVCU-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/06/25/55SWF4KB3JU282506/35QAO63JZ3YTCXSGSSZ4Z6ZVCU-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-11-23T18:43:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/2441/06/25/55SWF4KB3JU282506/35QAO63JZ3YTCXSGSSZ4Z6ZVCU',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 32901,
#    'member_discount': None,
#    'member_price': 32901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 32901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 34,
#    'market_difference': 1230.99,
#    'market_difference_display': 643,
#    'market_difference_percent': 0.036,
#    'market_difference_percent_display': 2.0,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 33790.67,
#    'good': 35155.95,
#    'min': 25598.99,
#    'max': 42664.99,
#    'avg': 34131.99,
#    'exceptional': 32425.39},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '55SWF4KB3JU282506'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7318,
#    'model_slug': 'c-class',
#    'model': 'C-Class',
#    'mpg_city': 23,
#    'mpg_combined': 26,
#    'mpg_highway': 32,
#    'style_id': 59105,
#    'style_slug': 'c-300-4matic-sedan',
#    'style': 'C 300 4MATIC Sedan',
#    'transmission': 'Automatic',
#    'trim_slug': 'c-300',
#    'trim': 'C 300 4MATIC Sedan',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395165,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '0A0A0B',
#    'exterior_color': 'Black',
#    'exterior_color_id': 887865,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 887854,
#    'list_price': 34901.0,
#    'member_discount': 500.0,
#    'mileage': 20685,
#    'new_or_used': 'USED',
#    'stock_number': '18542',
#    'vin': '55SWF4KB4JU273751',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 8,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1638560201992,
#     'isFrameDamaged': False,
#     'ownerCount': 2,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB4JU273751',
#     'reportPullDateString': '2021-12-03T19:36:41.992+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB4JU273751',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-12-04T00:43:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/2441/51/37/55SWF4KB4JU273751/3JEK3SYJNHXLJ7DJAXA5ESSO54',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 34901,
#    'member_discount': None,
#    'member_price': 34901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 34901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 34,
#    'market_difference': 1313.39,
#    'market_difference_display': 688,
#    'market_difference_percent': 0.036,
#    'market_difference_percent_display': 2.0,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 35852.25,
#    'good': 37300.82,
#    'min': 27160.79,
#    'max': 45267.99,
#    'avg': 36214.39,
#    'exceptional': 34403.67},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '55SWF4KB4JU273751'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'RWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7318,
#    'model_slug': 'c-class',
#    'model': 'C-Class',
#    'mpg_city': 24,
#    'mpg_combined': 27,
#    'mpg_highway': 33,
#    'style_id': 59102,
#    'style_slug': 'c-300-sedan-rwd',
#    'style': 'C 300 Sedan RWD',
#    'transmission': 'Automatic',
#    'trim_slug': 'c-300',
#    'trim': 'C 300 Sedan RWD',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395164,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Gray',
#    'exterior_color_rgb': '363938',
#    'exterior_color': 'Selenite Grey Metallic',
#    'exterior_color_id': 887729,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 887665,
#    'list_price': 30901.0,
#    'member_discount': 500.0,
#    'mileage': 28863,
#    'new_or_used': 'USED',
#    'stock_number': '53169N',
#    'vin': '55SWF4JB2JU275189',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 22,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1637436833228,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4JB2JU275189',
#     'reportPullDateString': '2021-11-20T19:33:53.228+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4JB2JU275189',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/89/51/55SWF4JB2JU275189/35N7YGLFXKUPMAGNLJDFLL6F74-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/89/51/55SWF4JB2JU275189/35N7YGLFXKUPMAGNLJDFLL6F74-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-11-20T18:42:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/2441/89/51/55SWF4JB2JU275189/35N7YGLFXKUPMAGNLJDFLL6F74',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 30901,
#    'member_discount': None,
#    'member_price': 30901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 30901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 80,
#    'market_difference': 2991.64,
#    'market_difference_display': 1814,
#    'market_difference_percent': 0.088,
#    'market_difference_percent_display': 5.9,
#    'rating': 'EXCELLENT',
#    'callout': {'label': 'Excellent Price',
#     'quality': 'EXCELLENT',
#     'quality_index': 0},
#    'great': 33553.72,
#    'good': 34909.42,
#    'min': 25419.48,
#    'max': 42365.81,
#    'avg': 33892.64,
#    'exceptional': 32198.01},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '55SWF4JB2JU275189'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '3.5L V-6 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 50,
#    'make_slug': 'lexus',
#    'make': 'Lexus',
#    'model_id': 8196,
#    'model_slug': 'rx',
#    'model': 'RX',
#    'mpg_city': 19,
#    'mpg_combined': 22,
#    'mpg_highway': 26,
#    'style_id': 63202,
#    'style_slug': 'rx-350-awd',
#    'style': 'RX 350 AWD',
#    'transmission': 'Automatic',
#    'trim_slug': 'rx-350',
#    'trim': 'RX 350 AWD',
#    'trim_id': None,
#    'year': 2019,
#    'chrome_trim_id': 403176,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_member',
#    'exterior_color_generic': 'Gray',
#    'exterior_color_rgb': '3C3D3E',
#    'exterior_color': 'Nebula Gray Pearl',
#    'exterior_color_id': 950221,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
#    'interior_color_id': 950210,
#    'list_price': 38569.0,
#    'member_discount': None,
#    'mileage': 34989,
#    'new_or_used': 'USED',
#    'stock_number': 'LM18047',
#    'vin': '2T2BZMCA1KC171676',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 66,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1633723869354,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=2T2BZMCA1KC171676',
#     'reportPullDateString': '2021-10-08T20:11:09.354+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=2T2BZMCA1KC171676',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/5836/76/16/2T2BZMCA1KC171676/OZSYZINMDLGBZ3IAZGMTJNMTVU-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/5836/76/16/2T2BZMCA1KC171676/OZSYZINMDLGBZ3IAZGMTJNMTVU-318.jpg'],
#    'member_price': 38569.0},
#   'dealership': {'id': 5836,
#    'name': 'Lexus of Manhattan',
#    'links': {'website_link': 'www.lexusofmanhattan.com'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '627 11th Avenue',
#     'address2': None,
#     'postal_code': '10036',
#     'lat': 40.76402,
#     'lng': -73.99644,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 0.96},
#    'parent_id': 19544},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-10-08T18:40:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 1600,
#      'cropAvailable': True,
#      'hash': 'listings/5836/76/16/2T2BZMCA1KC171676/OZSYZINMDLGBZ3IAZGMTJNMTVU',
#      'height': 1067}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': None,
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your <span class="true-price"><strong>TRUE</strong>Price</span>',
#    'show_discount_post_lead': False,
#    'description': 'no_discounts',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': None},
#   'pricing': {'list_price': 38569,
#    'member_discount': None,
#    'member_price': 38569,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 38569,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 93,
#    'market_difference': 2632.26,
#    'market_difference_display': 1543,
#    'market_difference_percent': 0.064,
#    'market_difference_percent_display': 4.0,
#    'rating': 'EXCELLENT',
#    'callout': {'label': 'Excellent Price',
#     'quality': 'EXCELLENT',
#     'quality_index': 0},
#    'great': 40789.25,
#    'good': 42437.3,
#    'min': 30900.94,
#    'max': 51501.58,
#    'avg': 41201.26,
#    'exceptional': 39141.2},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '2T2BZMCA1KC171676'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 8130,
#    'model_slug': 'glc',
#    'model': 'GLC',
#    'mpg_city': 22,
#    'mpg_combined': 24,
#    'mpg_highway': 27,
#    'style_id': 62744,
#    'style_slug': 'glc-300-4matic',
#    'style': 'GLC 300 4MATIC',
#    'transmission': 'Automatic',
#    'trim_slug': 'glc-300',
#    'trim': 'GLC 300 4MATIC',
#    'trim_id': None,
#    'year': 2019,
#    'chrome_trim_id': 402571,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'White',
#    'exterior_color_rgb': 'D2D0C1',
#    'exterior_color': 'Polar White',
#    'exterior_color_id': 944212,
#    'interior_color': 'Silk Beige Mb-Tex',
#    'interior_color_generic': 'Beige',
#    'interior_color_rgb': None,
#    'interior_color_id': None,
#    'list_price': 40901.0,
#    'member_discount': 500.0,
#    'mileage': 31021,
#    'new_or_used': 'USED',
#    'stock_number': '190816',
#    'vin': 'WDC0G4KBXKF545344',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 17,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1637786638435,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDC0G4KBXKF545344',
#     'reportPullDateString': '2021-11-24T20:43:58.435+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=WDC0G4KBXKF545344',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2441/44/53/WDC0G4KBXKF545344/ZIDUVKSRSQK2S4MWRMDOWCTDTI-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2441/44/53/WDC0G4KBXKF545344/ZIDUVKSRSQK2S4MWRMDOWCTDTI-318.jpg']},
#   'dealership': {'id': 2441,
#    'name': 'Mercedes-Benz Manhattan',
#    'links': {'website_link': 'http://www.mb-manhattan.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '770 11th Avenue',
#     'address2': None,
#     'postal_code': '10019',
#     'lat': 40.76813,
#     'lng': -73.99287,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 1.26},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-11-24T19:49:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/2441/44/53/WDC0G4KBXKF545344/ZIDUVKSRSQK2S4MWRMDOWCTDTI',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your Upfront Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Upfront Price Available'},
#   'pricing': {'list_price': 40901,
#    'member_discount': None,
#    'member_price': 40901,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 40901,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 80,
#    'market_difference': 749.53,
#    'market_difference_display': 245,
#    'market_difference_percent': 0.018,
#    'market_difference_percent_display': 0.6,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 41234.02,
#    'good': 42900.05,
#    'min': 31237.9,
#    'max': 52063.16,
#    'avg': 41650.53,
#    'exceptional': 39568.0},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': 'WDC0G4KBXKF545344'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '2.5L Inline-4 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 43,
#    'make_slug': 'nissan',
#    'make': 'Nissan',
#    'model_id': 7495,
#    'model_slug': 'rogue',
#    'model': 'Rogue',
#    'mpg_city': 25,
#    'mpg_combined': 27,
#    'mpg_highway': 32,
#    'style_id': 60664,
#    'style_slug': 'sv-awd',
#    'style': 'SV AWD',
#    'transmission': 'Automatic',
#    'trim_slug': 'sv',
#    'trim': 'SV AWD',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 392017,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '1D2020',
#    'exterior_color': 'Magnetic Black',
#    'exterior_color_id': None,
#    'interior_color': 'Charcoal',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': None,
#    'interior_color_id': None,
#    'list_price': 18495.0,
#    'member_discount': 0.0,
#    'mileage': 45032,
#    'new_or_used': 'USED',
#    'stock_number': '616587',
#    'vin': 'KNMAT2MV5JP616587',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 43,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {'interior': [{'description': 'CHARCOAL, CLOTH SEAT TRIM',
#       'msrp': 0.0,
#       'features': None,
#       'oem_code': 'G'}],
#     'additional equipment': [{'description': 'MARCH SOP SPEC',
#       'msrp': 0.0,
#       'features': None,
#       'oem_code': 'MAR'},
#      {'description': 'CHROME REAR BUMPER PROTECTOR',
#       'msrp': 155.0,
#       'features': None,
#       'oem_code': 'BUM'},
#      {'description': 'BLACK SPLASH GUARDS (SET OF 4)',
#       'msrp': 160.0,
#       'features': None,
#       'oem_code': 'SGD'},
#      {'description': 'FLOOR MATS & 2-PC CARGO AREA PROTECTOR',
#       'msrp': 275.0,
#       'features': ['2-pc front and 2-pc 2nd row floor mats', 'First Aid Kit'],
#       'oem_code': 'FL2'}]},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1635669297054,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 1,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=KNMAT2MV5JP616587',
#     'reportPullDateString': '2021-10-31T08:34:57.054+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'basicEquipped',
#    'location': 'Middle Village, NY',
#    'price_dropped': False,
#    'certified_pre_owned': None,
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=KNMAT2MV5JP616587',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/24344/87/65/KNMAT2MV5JP616587/6BSPZLAW4R55NQF2GAAXDQWLH4-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/24344/87/65/KNMAT2MV5JP616587/6BSPZLAW4R55NQF2GAAXDQWLH4-318.jpg']},
#   'dealership': {'id': 24344,
#    'name': 'Road Masters II Inc.',
#    'links': {'website_link': 'http://www.roadmasters2.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '62-01 Freshpond Road',
#     'address2': None,
#     'postal_code': '11379',
#     'lat': 40.7136,
#     'lng': -73.90062,
#     'city': 'Middle Village',
#     'state': 'NY',
#     'distance': 5.63},
#    'parent_id': None},
#   'payments': {'lease': None,
#    'loan': {'total_monthly_payment': 331.05,
#     'monthly_payment': 301.53,
#     'monthly_tax': 29.52,
#     'total_due_at_signing': 1849.5,
#     'due_at_signing': 1849.5,
#     'taxes_due_at_signing': 0.0,
#     'term': 60,
#     'credit_score': 850,
#     'disclaimer': 'This loan estimate is based off a 60 month term and $1,849.50 down payment. It does not include fees charged by this dealer and may not reflect your actual tax liability.',
#     'down_payment': 1849.5}},
#   'listed_at': '2021-10-31T07:41:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 900,
#      'cropAvailable': True,
#      'hash': 'listings/24344/87/65/KNMAT2MV5JP616587/6BSPZLAW4R55NQF2GAAXDQWLH4',
#      'height': 675}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': 'Upfront Price Available',
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Dealer Price',
#    'show_discount_post_lead': True,
#    'description': 'restricted_state_and_list_prices',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': None},
#   'pricing': {'list_price': 18495,
#    'member_discount': None,
#    'member_price': 18495,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 18495,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 86,
#    'market_difference': 1549.6,
#    'market_difference_display': 934,
#    'market_difference_percent': 0.077,
#    'market_difference_percent_display': 5.0,
#    'rating': 'EXCELLENT',
#    'callout': {'label': 'Excellent Price',
#     'quality': 'EXCELLENT',
#     'quality_index': 0},
#    'great': 19844.15,
#    'good': 20645.94,
#    'min': 15033.45,
#    'max': 25055.75,
#    'avg': 20044.6,
#    'exceptional': 19042.37},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': 'KNMAT2MV5JP616587'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '3.5L V-6 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 50,
#    'make_slug': 'lexus',
#    'make': 'Lexus',
#    'model_id': 7515,
#    'model_slug': 'rx',
#    'model': 'RX',
#    'mpg_city': 19,
#    'mpg_combined': 22,
#    'mpg_highway': 26,
#    'style_id': 60812,
#    'style_slug': 'rx-350-awd',
#    'style': 'RX 350 AWD',
#    'transmission': 'Automatic',
#    'trim_slug': 'rx-350',
#    'trim': 'RX 350 AWD',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 397903,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_member',
#    'exterior_color_generic': 'Black',
#    'exterior_color_rgb': '1A1A1F',
#    'exterior_color': 'Caviar',
#    'exterior_color_id': 916869,
#    'interior_color': 'Noble Brown',
#    'interior_color_generic': 'Brown',
#    'interior_color_rgb': '513D3C',
#    'interior_color_id': 945344,
#    'list_price': 37869.0,
#    'member_discount': None,
#    'mileage': 24935,
#    'new_or_used': 'USED',
#    'stock_number': 'LM18113',
#    'vin': '2T2BZMCAXJC163526',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 27,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 1,
#     'reportPullDate': 1637178272380,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=2T2BZMCAXJC163526',
#     'reportPullDateString': '2021-11-17T19:44:32.380+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=2T2BZMCAXJC163526',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/5836/26/35/2T2BZMCAXJC163526/XAHZYMYJB4EYJTMUPVOG44YEV4-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/5836/26/35/2T2BZMCAXJC163526/XAHZYMYJB4EYJTMUPVOG44YEV4-318.jpg'],
#    'member_price': 37869.0},
#   'dealership': {'id': 5836,
#    'name': 'Lexus of Manhattan',
#    'links': {'website_link': 'www.lexusofmanhattan.com'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '627 11th Avenue',
#     'address2': None,
#     'postal_code': '10036',
#     'lat': 40.76402,
#     'lng': -73.99644,
#     'city': 'New York',
#     'state': 'NY',
#     'distance': 0.96},
#    'parent_id': 19544},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-11-17T18:42:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 1600,
#      'cropAvailable': True,
#      'hash': 'listings/5836/26/35/2T2BZMCAXJC163526/XAHZYMYJB4EYJTMUPVOG44YEV4',
#      'height': 1200}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': None,
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Your <span class="true-price"><strong>TRUE</strong>Price</span>',
#    'show_discount_post_lead': False,
#    'description': 'no_discounts',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': None},
#   'pricing': {'list_price': 37869,
#    'member_discount': None,
#    'member_price': 37869,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 37869,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 17,
#    'market_difference': 1693.33,
#    'market_difference_display': 947,
#    'market_difference_percent': 0.043,
#    'market_difference_percent_display': 2.5,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 39166.7,
#    'good': 40749.19,
#    'min': 29671.74,
#    'max': 49452.91,
#    'avg': 39562.33,
#    'exceptional': 37584.21},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '2T2BZMCAXJC163526'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'AWD',
#    'engine': '3.5L V-6 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 50,
#    'make_slug': 'lexus',
#    'make': 'Lexus',
#    'model_id': 7466,
#    'model_slug': 'is',
#    'model': 'IS',
#    'mpg_city': 19,
#    'mpg_combined': 22,
#    'mpg_highway': 26,
#    'style_id': 60504,
#    'style_slug': 'is-300-awd',
#    'style': 'IS 300 AWD',
#    'transmission': 'Automatic',
#    'trim_slug': 'is-300',
#    'trim': 'IS 300 AWD',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 397397,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_member',
#    'exterior_color_generic': 'White',
#    'exterior_color_rgb': 'D7D4CC',
#    'exterior_color': 'Eminent White Pearl',
#    'exterior_color_id': 912404,
#    'interior_color': 'Chateau',
#    'interior_color_generic': 'Beige',
#    'interior_color_rgb': 'E8D8BE',
#    'interior_color_id': 912395,
#    'list_price': 31969.0,
#    'member_discount': None,
#    'mileage': 6317,
#    'new_or_used': 'USED',
#    'stock_number': 'LM18152',
#    'vin': 'JTHC81D2XJ5027622',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 10,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1638496105514,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=JTHC81D2XJ5027622',
#     'reportPullDateString': '2021-12-03T01:48:25.514+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'New York, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=JTHC81D2XJ5027622',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/5836/22/76/JTHC81D2XJ5027622/A6E7HPBKKCD52EP2DS4BQQY7ZQ-318.jpg',
# ...
#       'oem_code': 'G'}],
#     'packages': [{'description': 'PREMIUM PACKAGE',
#       'msrp': 1490.0,
#       'features': ['Memory Driver Seat & Outside Mirrors',
#        'Intelligent Aroundview Monitor (I-AVM)',
#        'Intelligent Cruise Control (ICC)',
#        'Heated Leather-Wrapped Steering Wheel',
#        'Radio: AM/FM/CD/AUX NissanConnect w/Navigation',
#        'Nissan door to door navigation w/3D building graphics and satellite imagery featuring POI search and online premium traffic information',
#        'HD radio',
#        'SiriusXM Traffic w/premium traffic information',
#        'SiriusXM travel link (weather',
#        'fuel prices',
#        'movie listings',
#        'stock info',
#        'sports and parking)',
#        'NissanConnect services powered by SiriusXM',
#        '7" color display w/multi-touch control',
#        'Apple CarPlay',
#        'Android Auto',
#        'SiriusXM Satellite Radio w/advanced audio features',
#        'USB connection port for iPod and other compatible devices',
#        'Bluetooth hands-free phone system',
#        'streaming audio via Bluetooth',
#        'hands-free text messaging assistant',
#        'over-the-air (OTA) updating for headunit firmware and navigation map software via a Wi-Fi WPA2 connection'],
#       'oem_code': 'PR1'}],
#     'additional equipment': [{'description': 'MARCH SOP SPEC',
#       'msrp': 0.0,
#       'features': None,
#       'oem_code': 'MAR'},
#      {'description': 'CHROME REAR BUMPER PROTECTOR',
#       'msrp': 155.0,
#       'features': None,
#       'oem_code': 'BUM'},
#      {'description': 'BLACK SPLASH GUARDS (SET OF 4)',
#       'msrp': 160.0,
#       'features': None,
#       'oem_code': 'SGD'},
#      {'description': 'FLOOR MATS & 2-PC CARGO AREA PROTECTOR',
#       'msrp': 275.0,
#       'features': ['2-pc front and 2-pc 2nd row floor mats', 'First Aid Kit'],
#       'oem_code': 'FL2'}]},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 2,
#     'reportPullDate': 1637657391715,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 0,
#     'accidentCount': 0,
#     'isFleetCar': False,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=JN8AT2MV0JW353113',
#     'reportPullDateString': '2021-11-23T08:49:51.715+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'fullyLoaded',
#    'location': 'Jackson Heights, NY',
#    'price_dropped': False,
#    'certified_pre_owned': 'oem-certified',
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=JN8AT2MV0JW353113',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/2189/13/31/JN8AT2MV0JW353113/G7SQYIJAAPEYTMNN3ZLYNUEW7A-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/2189/13/31/JN8AT2MV0JW353113/G7SQYIJAAPEYTMNN3ZLYNUEW7A-318.jpg']},
#   'dealership': {'id': 2189,
#    'name': 'Koeppel Nissan',
#    'links': {'website_link': 'www.koeppelnissan.com'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '74-15 Northern Blvd',
#     'address2': None,
#     'postal_code': '11372',
#     'lat': 40.75535,
#     'lng': -73.89219,
#     'city': 'Jackson Heights',
#     'state': 'NY',
#     'distance': 5.49},
#    'parent_id': 10237},
#   'payments': {'lease': None,
#    'loan': {'total_monthly_payment': 381.66,
#     'monthly_payment': 347.59,
#     'monthly_tax': 34.07,
#     'total_due_at_signing': 2188.9,
#     'due_at_signing': 2188.9,
#     'taxes_due_at_signing': 0.0,
#     'term': 60,
#     'credit_score': 850,
#     'disclaimer': 'This loan estimate is based off a 60 month term and $2,188.90 down payment. It does not include fees charged by this dealer and may not reflect your actual tax liability.',
#     'down_payment': 2188.9}},
#   'listed_at': '2021-12-09T07:43:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/2189/13/31/JN8AT2MV0JW353113/G7SQYIJAAPEYTMNN3ZLYNUEW7A',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': None,
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Dealer Price',
#    'show_discount_post_lead': False,
#    'description': 'no_discounts',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': None},
#   'pricing': {'list_price': 21889,
#    'member_discount': None,
#    'member_price': 21889,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 21889,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 84,
#    'market_difference': 1909.74,
#    'market_difference_display': 1153,
#    'market_difference_percent': 0.08,
#    'market_difference_percent_display': 5.3,
#    'rating': 'EXCELLENT',
#    'callout': {'label': 'Excellent Price',
#     'quality': 'EXCELLENT',
#     'quality_index': 0},
#    'great': 23560.75,
#    'good': 24512.7,
#    'min': 17849.05,
#    'max': 29748.43,
#    'avg': 23798.74,
#    'exceptional': 22608.8},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': 'JN8AT2MV0JW353113'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'FWD',
#    'engine': '2.5L Inline-4 Gas',
#    'fuel_type': 'Gas',
#    'make_id': 21,
#    'make_slug': 'ford',
#    'make': 'Ford',
#    'model_id': 1068,
#    'model_slug': 'fusion',
#    'model': 'Fusion',
#    'mpg_city': 22,
#    'mpg_combined': 26,
#    'mpg_highway': 34,
#    'style_id': 43840,
#    'style_slug': 'se-fwd',
#    'style': 'SE FWD',
#    'transmission': 'Automatic',
#    'trim_slug': 'se',
#    'trim': 'SE FWD',
#    'trim_id': None,
#    'year': 2014,
#    'chrome_trim_id': 360660,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'White',
#    'exterior_color_rgb': 'F7F7F5',
#    'exterior_color': 'Oxford White',
#    'exterior_color_id': 646238,
#    'interior_color': 'Dune',
#    'interior_color_generic': 'Beige',
#    'interior_color_rgb': 'E8D8BE',
#    'interior_color_id': 646225,
#    'list_price': 10995.0,
#    'member_discount': 225.0,
#    'mileage': 101569,
#    'new_or_used': 'USED',
#    'stock_number': '170824',
#    'vin': '3FA6P0H7XER170824',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 27,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': True,
#     'recallCount': 1,
#     'reportPullDate': 1636573376143,
#     'isFrameDamaged': False,
#     'ownerCount': 3,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 6,
#     'accidentCount': 0,
#     'isFleetCar': True,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=3FA6P0H7XER170824',
#     'reportPullDateString': '2021-11-10T19:42:56.143+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'unknown',
#    'location': 'Union City, NJ',
#    'price_dropped': False,
#    'certified_pre_owned': None,
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=3FA6P0H7XER170824',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/22960/24/08/3FA6P0H7XER170824/HLUK5TX2RFHDZ45HGAMGVLRPBU-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/22960/24/08/3FA6P0H7XER170824/HLUK5TX2RFHDZ45HGAMGVLRPBU-318.jpg']},
#   'dealership': {'id': 22960,
#    'name': "2 Manny's Auto Sales",
#    'links': {'website_link': 'http://www.2mannys.com/'},
#    'services': {'remote_purchasing': True,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '1316 Kennedy Blvd',
#     'address2': None,
#     'postal_code': '07087',
#     'lat': 40.76286,
#     'lng': -74.04202,
#     'city': 'Union City',
#     'state': 'NJ',
#     'distance': 2.53},
#    'parent_id': None},
#   'payments': {'lease': None, 'loan': None},
#   'listed_at': '2021-11-10T21:13:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 640,
#      'cropAvailable': True,
#      'hash': 'listings/22960/24/08/3FA6P0H7XER170824/HLUK5TX2RFHDZ45HGAMGVLRPBU',
#      'height': 480}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': True,
#    'discount_message_pre_lead': 'Discount Available',
#    'show_list_price_post_lead': True,
#    'cert_title': 'Certificate',
#    'member_price_label_post_lead': 'Your Discounted Price',
#    'show_discount_post_lead': True,
#    'description': 'non_restricted_state',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': 'Discount Available'},
#   'pricing': {'list_price': 10995,
#    'member_discount': None,
#    'member_price': 10995,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 10995,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 8,
#    'market_difference': 538.5,
#    'market_difference_display': 303,
#    'market_difference_percent': 0.047,
#    'market_difference_percent_display': 2.8,
#    'rating': 'GREAT',
#    'callout': {'label': 'Great Price', 'quality': 'GREAT', 'quality_index': 1},
#    'great': 11418.16,
#    'good': 11879.5,
#    'min': 8650.12,
#    'max': 14416.87,
#    'avg': 11533.5,
#    'exceptional': 10956.82},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '3FA6P0H7XER170824'},
#   'prospected': False,
#   'prospected_at': None},
#  {'vehicle': {'body_style_slug': 'sedan',
#    'body_style': 'Sedan',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 7318,
#    'model_slug': 'c-class',
#    'model': 'C-Class',
#    'mpg_city': 23,
#    'mpg_combined': 26,
#    'mpg_highway': 32,
#    'style_id': 59105,
#    'style_slug': 'c-300-4matic-sedan',
#    'style': 'C 300 4MATIC Sedan',
#    'transmission': 'Automatic',
#    'trim_slug': 'c-300',
#    'trim': 'C 300 4MATIC Sedan',
#    'trim_id': None,
#    'year': 2018,
#    'chrome_trim_id': 395165,
#    'carfax_report_available': False,
#    'enable_discount': None,
#    'exterior_color_generic': 'White',
#    'exterior_color_rgb': 'E3E4E8',
#    'exterior_color': 'Polar White',
#    'exterior_color_id': 887864,
#    'interior_color': 'Silk Beige/Black',
#    'interior_color_generic': 'Beige',
#    'interior_color_rgb': 'E8D8BE',
#    'interior_color_id': 887855,
#    'list_price': 23995.0,
#    'member_discount': None,
#    'mileage': 52345,
#    'new_or_used': 'USED',
#    'stock_number': '255492',
#    'vin': '55SWF4KB4JU255492',
#    'truecar_make_id': None,
#    'truecar_model_id': None,
#    'doors': None,
#    'newly_listed': None,
#    'days_in_inventory': 12,
#    'make_logos': None,
#    'provider_name': None,
#    'request_price': None,
#    'manufacturer_options': [],
#    'bed_length': None,
#    'cab_type': None,
#    'roof_height': None,
#    'options': {},
#    'condition_history': {'isRentalCar': False,
#     'recallCount': 0,
#     'reportPullDate': 1638323715546,
#     'isFrameDamaged': False,
#     'ownerCount': 1,
#     'titleInfo': {'isSalvage': False,
#      'isCleanTitle': True,
#      'isLemon': False,
#      'isTheftRecovered': False,
#      'isFrameDamaged': False},
#     'isReportFree': False,
#     'maintenanceCount': 5,
#     'accidentCount': 0,
#     'isFleetCar': True,
#     'auto_check_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB4JU255492',
#     'reportPullDateString': '2021-12-01T01:55:15.546+00:00'},
#    'truecar_plus_eligible': None,
#    'multilocation': False,
#    'equipment_rating': 'standard',
#    'location': 'Newark, NJ',
#    'price_dropped': False,
#    'certified_pre_owned': None,
#    'sponsored': None,
#    'autocheck_url': 'https://www.autocheck.com/vehiclehistory/?siteID=8900&vin=55SWF4KB4JU255492',
#    'frame_damaged': False,
#    'image': 'https://listings-prod.tcimg.net/listings/26431/92/54/55SWF4KB4JU255492/G6ZXTWPWD36VWNXTEKUT52NE7Y-318.jpg',
#    'images': ['https://listings-prod.tcimg.net/listings/26431/92/54/55SWF4KB4JU255492/G6ZXTWPWD36VWNXTEKUT52NE7Y-318.jpg']},
#   'dealership': {'id': 26431,
#    'name': 'Champion Auto Sales LLC - Broad Street Newark',
#    'links': {'website_link': 'http://www.championvehiclesales.com/'},
#    'services': {'remote_purchasing': False,
#     'nationwide_delivery_provided': False},
#    'location': {'address1': '1155-1161 Broad Street',
#     'address2': None,
#     'postal_code': '07114',
#     'lat': 40.7218837,
#     'lng': -74.1802932,
#     'city': 'Newark',
#     'state': 'NJ',
#     'distance': 9.8},
#    'parent_id': 172577},
#   'payments': {'lease': None,
#    'loan': {'total_monthly_payment': 414.78,
#     'monthly_payment': 386.54,
#     'monthly_tax': 28.24,
#     'total_due_at_signing': 2399.5,
#     'due_at_signing': 2399.5,
#     'taxes_due_at_signing': 0.0,
#     'term': 60,
#     'credit_score': 850,
#     'disclaimer': 'This loan estimate is based off a 60 month term and $2,399.50 down payment. It does not include fees charged by this dealer and may not reflect your actual tax liability.',
#     'down_payment': 2399.5}},
#   'listed_at': '2021-12-04T12:43:00.000+00:00',
#   'distance_retailing': False,
#   'images': [{'data': {'width': 898,
#      'cropAvailable': True,
#      'hash': 'listings/26431/92/54/55SWF4KB4JU255492/G6ZXTWPWD36VWNXTEKUT52NE7Y',
#      'height': 674}}],
#   'pricing_flags': {'show_list_price_label_pre_lead': False,
#    'discount_message_pre_lead': None,
#    'show_list_price_post_lead': False,
#    'cert_title': 'Offer',
#    'member_price_label_post_lead': 'Dealer Price',
#    'show_discount_post_lead': False,
#    'description': 'no_discounts',
#    'show_discount_pre_lead': False,
#    'discount_label_pre_lead': None},
#   'pricing': {'list_price': 23995,
#    'member_discount': None,
#    'member_price': 23995,
#    'total_fees': 0,
#    'other_fees_total': 0,
#    'dealer_installed_options_total': 0,
#    'total_fees_and_accessories': 0,
#    'total_price': 23995,
#    'transparency_pledge': None,
#    'list_price_includes_doc_fee': None,
#    'dealer_installed_options': [],
#    'savings_total': None,
#    'savings_total_percentage': None,
#    'other_fees': [],
#    'documentation_fee': None,
#    'tax_rate': None,
#    'price_history': None,
#    'tax_amount': None,
#    'total_taxed_price': None},
#   'price_curve': {'recent_offer_averages': None,
#    'curve_distance': 31,
#    'market_difference': 5489.07,
#    'market_difference_display': 3170,
#    'market_difference_percent': 0.186,
#    'market_difference_percent_display': 13.2,
#    'rating': 'EXCELLENT',
#    'callout': {'label': 'Excellent Price',
#     'quality': 'EXCELLENT',
#     'quality_index': 0},
#    'great': 29189.23,
#    'good': 30368.59,
#    'min': 22113.05,
#    'max': 36855.09,
#    'avg': 29484.07,
#    'exceptional': 28009.87},
#   'collapse': {'collapsed': False,
#    'count': 1,
#    'consolidated_dealer': '55SWF4KB4JU255492'},
#   'prospected': False,
#   'prospected_at': None}]

# %%
len(results_json['listings'])
# Out:
# 30

# %%
result_items = results_json['listings']

# %%
len(result_items)
# Out:
# 30

# %%
# brand 
result_items[0]['vehicle']['make']
# Out:
# 'Mercedes-Benz'

# %%
# model 
result_items[0]['vehicle']['model']
# Out:
# 'C-Class'

# %%
# mileage
result_items[0]['vehicle']['mileage']
# Out:
# 33578

# %%
# year
result_items[0]['vehicle']['year']
# Out:
# 2018

# %%
# price
result_items[0]['pricing']['list_price']
# Out:
# 32901

# %% [markdown]
# #### Step 7 - Put everything together & For-Loop

# %%
brand_ny = []
model_ny = []
mileage_ny = []
year_ny = []
price_ny = []

for result in result_items:
    
    # brand
    brand_ny.append(result['vehicle']['make'])
    
    # model
    model_ny.append(result['vehicle']['model'])
    
    # mileage
    mileage_ny.append(result['vehicle']['mileage'])
    
    # year
    year_ny.append(result['vehicle']['year'])
    
    # price
    price_ny.append(result['pricing']['list_price'])

# %%
len(brand_ny)
# Out:
# 30

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
df_ny_single = pd.DataFrame({'Brand': brand_ny, 'Model': model_ny, 'Mileage': mileage_ny, 'Year': year_ny,
                             'Price':price_ny})

# %%
df_ny_single
# Out:
#             Brand    Model  Mileage  Year  Price
# 0   Mercedes-Benz  C-Class    33578  2018  32901
# 1   Mercedes-Benz  C-Class    23709  2018  33901
# 2   Mercedes-Benz  C-Class    39768  2018  32901
# 3   Mercedes-Benz  C-Class    20685  2018  34901
# 4   Mercedes-Benz  C-Class    28863  2018  30901
# 5           Lexus       RX    34989  2019  38569
# 6   Mercedes-Benz      GLC    31021  2019  40901
# 7          Nissan    Rogue    45032  2018  18495
# 8           Lexus       RX    24935  2018  37869
# 9           Lexus       IS     6317  2018  31969
# 10  Mercedes-Benz      GLS    28326  2019  63901
# 11     Volkswagen   Tiguan   133014  2017  12995
# 12  Mercedes-Benz      GLC    27352  2019  40901
# 13  Mercedes-Benz  C-Class    38134  2018  33901
# 14  Mercedes-Benz      GLC    13430  2019  42901
# 15           Ford    F-150    71894  2014  19942
# 16         Toyota     RAV4    66027  2018  23995
# 17         Toyota    Camry    11845  2019  23969
# 18  Mercedes-Benz  C-Class    15651  2018  33901
# 19         Nissan    Rogue    43179  2018  20995
# 20     Volkswagen     Golf   155455  2012   4995
# 21  Mercedes-Benz      GLS    20263  2018  58901
# 22  Mercedes-Benz      GLE    38408  2020  56901
# 23  Mercedes-Benz      GLE    20036  2018  44901
# 24  Mercedes-Benz  E-Class    34483  2018  43901
# 25  Mercedes-Benz      GLE    43357  2018  64901
# 26  Mercedes-Benz  E-Class    15377  2018  63901
# 27         Nissan    Rogue    43147  2018  21889
# 28           Ford   Fusion   101569  2014  10995
# 29  Mercedes-Benz  C-Class    52345  2018  23995

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: ~5000results)

# %%
brand_ny = []
model_ny = []
mileage_ny = []
year_ny = []
price_ny = []

for i in range(1,170):

    headers = {
        'authority': 'www.truecar.com',
        'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
        'accept': 'application/json, text/plain, */*',
        'x-xsrf-token': 'Ur/kxt0PrKLpIlS3QELPXZBZHMSME0gTzs47TPfIUiC1LJqIt9HlLYrLTMgwB5qE6zC2M5Psn5Er+4Qm82MgEA==',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-new-york-ny/',
        'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
        'cookie': 'tc_v=732d8f6c-016d-4e04-99ea-962821b285bd; u=rBEABWDn9kVuLQARuYhKAg==; user_zip_code_san-francisco-ca=94102; user_zip_code_new-york-ny=10001; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=aLdzR1stp7FxiV6Cbnggg8fmtny6X9FAap2fnCqWeXg; referrer=ZTC0000000; g_state=^{^\\^i_p^\\^:1628151776913,^\\^i_l^\\^:2^}; capselaPreferredPostalCode=10001; XSRF-TOKEN=Ur^%^2Fkxt0PrKLpIlS3QELPXZBZHMSME0gTzs47TPfIUiC1LJqIt9HlLYrLTMgwB5qE6zC2M5Psn5Er^%^2B4Qm82MgEA^%^3D^%^3D; _abp_backend_session=cnN3bFdMQjJQYTlwRFFvS3oybm1oWTl0SVc3NVNGRng5Y01GWHlxa3BybWFJRXM1UkFueTFRWUhMYUtSVW1YZWxNaUFIZ2ZjS2FUQ2pVeURRNG5PeEh6VlRFQjZnRmFLN01PWHZFdjBQTis5UG9VRGFtWko4MFZNY2ZUUGRmS1pkSFdmcnB4TVkwMnJGREZBblZla1RRPT0tLW5BQjFPdHVvTk1VbHJZL3lwQ2MrTUE9PQ^%^3D^%^3D--a4caf99167368bcbbcd454b4ffe52eb35169abe0; _dd_s=rum=0&expire=1628067151364',
        'if-none-match': 'W/^\\^ad5f12263df3f1f7dad67afa854d2880^\\^',
    }

    params = (
        ('city', 'new-york'),
        ('collapse', 'true'),
        ('fallback', 'true'),
        ('include_incentives', 'true'),
        ('include_targeted_incentives', 'true'),
        ('new_or_used', 'u'),
        ('page', str(i)),
        ('per_page', '30'),
        ('postal_code', '10001'),
        ('search_event', 'true'),
        ('sort^/[^/]', 'best_match'),
        ('sponsored', 'true'),
        ('state', 'ny'),
    )

    # response
    response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)

    # json object
    results_json = response.json()
    
    # result items (30 items per page)
    result_items = results_json['listings']
    
    for result in result_items:
    
        # brand
        brand_ny.append(result['vehicle']['make'])

        # model
        model_ny.append(result['vehicle']['model'])

        # mileage
        mileage_ny.append(result['vehicle']['mileage'])

        # year
        year_ny.append(result['vehicle']['year'])

        # price
        price_ny.append(result['pricing']['list_price'])

# %%
df_ny_single = pd.DataFrame({'Brand': brand_ny, 'Model': model_ny, 'Mileage': mileage_ny, 'Year': year_ny,
                             'Price':price_ny})

# %%
df_ny_single
# Out:
#               Brand        Model  Mileage  Year    Price
# 0     Mercedes-Benz      C-Class    33578  2018  32901.0
# 1     Mercedes-Benz      C-Class    23709  2018  33901.0
# 2     Mercedes-Benz      C-Class    39768  2018  32901.0
# 3     Mercedes-Benz      C-Class    20685  2018  34901.0
# 4     Mercedes-Benz      C-Class    28863  2018  30901.0
# ...             ...          ...      ...   ...      ...
# 5065      Chevrolet       Malibu    58249  2019  16990.0
# 5066         Toyota        Camry    36298  2018  21890.0
# 5067            GMC  Sierra 1500    39893  2017  25590.0
# 5068            Kia        Forte    96130  2010   3990.0
# 5069          Honda        Pilot   140944  2011   8900.0
#
# [5070 rows x 5 columns]

# %%
df_ny_single.to_excel('output_5k.xlsx', index=False)

# %% [markdown]
# # Part 2 - Truecar.com - San Francisco

# %%
brand_sf = []
model_sf = []
mileage_sf = []
year_sf = []
price_sf = []

for i in range(1,170):
    headers = {
        'authority': 'www.truecar.com',
        'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^92^\\^, ^\\^',
        'accept': 'application/json, text/plain, */*',
        'x-xsrf-token': 'sRHovNRE9jEGmReSnaj0SFGY/L5+yUbMUmoVcX3SrQpWgpbyvpq/vmVwD+3t7aGRKvFWSWE2kU63X6obeXnfOg==',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-san-francisco-ca/',
        'accept-language': 'en-US,en;q=0.9,de-DE;q=0.8,de;q=0.7',
        'cookie': 'tc_v=732d8f6c-016d-4e04-99ea-962821b285bd; u=rBEABWDn9kVuLQARuYhKAg==; user_zip_code_san-francisco-ca=94102; user_zip_code_new-york-ny=10001; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=aLdzR1stp7FxiV6Cbnggg8fmtny6X9FAap2fnCqWeXg; referrer=ZTC0000000; g_state=^{^\\^i_p^\\^:1628151776913,^\\^i_l^\\^:2^}; capselaPreferredPostalCode=94102; XSRF-TOKEN=sRHovNRE9jEGmReSnaj0SFGY^%^2FL5^%^2ByUbMUmoVcX3SrQpWgpbyvpq^%^2FvmVwD^%^2B3t7aGRKvFWSWE2kU63X6obeXnfOg^%^3D^%^3D; _abp_backend_session=a3VMTkJGelNWbmptb3Q4aHlObjNIT1VXNFBZNXREeEg0SHo4MEZGdTNoalFRSzV2VldsaStYa3J6UDZSdGJvZDJsRUtXUkJVZ0ZycXhrbU5PZ0gxZms3RGFtRFJVbXZTeTFzeGI3WGo2VGVxUmptdm1OYVdmZGVrWlFvMDIxQVdLZ1BnM1A2SGZBa1pKbXhERlZOVzlRPT0tLW9ONTI2Y0xLM0lLY1g1NE5qSEpaSVE9PQ^%^3D^%^3D--4c4bf94f0b241212f5e3b798c48f4a5f0e366f7f; _dd_s=rum=0&expire=1628089775124',
        'if-none-match': 'W/^\\^a5ee0fa2b55644cda4fcbfe817357d97^\\^',
    }

    params = (
        ('city', 'san-francisco'),
        ('collapse', 'true'),
        ('fallback', 'true'),
        ('include_incentives', 'true'),
        ('include_targeted_incentives', 'true'),
        ('new_or_used', 'u'),
        ('page', str(i)),
        ('per_page', '30'),
        ('postal_code', '94102'),
        ('search_event', 'true'),
        ('sort^/[^/]', 'best_match'),
        ('sponsored', 'true'),
        ('state', 'ca'),
    )

    # response
    response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)

    # json object
    results_json = response.json()
    
    # result items (30 items per page)
    result_items = results_json['listings']
    
    for result in result_items:
    
        # brand
        brand_sf.append(result['vehicle']['make'])

        # model
        model_sf.append(result['vehicle']['model'])

        # mileage
        mileage_sf.append(result['vehicle']['mileage'])

        # year
        year_sf.append(result['vehicle']['year'])

        # price
        price_sf.append(result['pricing']['list_price'])

# %%
df_sf_single = pd.DataFrame({'Brand': brand_sf, 'Model': model_sf, 'Mileage': mileage_sf, 'Year': year_sf,
                             'Price':price_sf})

# %%
df_sf_single
# Out:
#        Brand     Model  Mileage  Year    Price
# 0        BMW  3 Series    18882  2018  27997.0
# 1        BMW  3 Series    28213  2018  34447.0
# 2        BMW        X2    60529  2018  27595.0
# 3        BMW  3 Series    30005  2018  32997.0
# 4     Toyota   Corolla    74780  2019  17309.0
# ...      ...       ...      ...   ...      ...
# 5065     Kia      Soul    14748  2020  21998.0
# 5066  Nissan    Altima    21782  2018  18999.0
# 5067   Honda    Accord    30511  2018  26999.0
# 5068  Nissan     Rogue    89372  2016  17998.0
# 5069     BMW      X5 M   106455  2016  40999.0
#
# [5070 rows x 5 columns]

# %% [markdown]
# # Part 3 - Combine Data & Connect to Database - PostgreSQL

# %%
# merge dataframes
merged_dataframes = pd.concat([df_ny_single, df_sf_single], ignore_index=True)

# %%
merged_dataframes
# Out:
#                Brand    Model  Mileage  Year    Price
# 0      Mercedes-Benz  C-Class    33578  2018  32901.0
# 1      Mercedes-Benz  C-Class    23709  2018  33901.0
# 2      Mercedes-Benz  C-Class    39768  2018  32901.0
# 3      Mercedes-Benz  C-Class    20685  2018  34901.0
# 4      Mercedes-Benz  C-Class    28863  2018  30901.0
# ...              ...      ...      ...   ...      ...
# 10135            Kia     Soul    14748  2020  21998.0
# 10136         Nissan   Altima    21782  2018  18999.0
# 10137          Honda   Accord    30511  2018  26999.0
# 10138         Nissan    Rogue    89372  2016  17998.0
# 10139            BMW     X5 M   106455  2016  40999.0
#
# [10140 rows x 5 columns]

# %%
type(merged_dataframes['Price'][0])
# Out:
# numpy.float64

# %%
merged_dataframes['Price'] = merged_dataframes['Price'].astype('Int64')

# %%
type(merged_dataframes['Price'][0])
# Out:
# numpy.int64

# %%
# output updated dataframe
merged_dataframes
# Out:
#                Brand    Model  Mileage  Year  Price
# 0      Mercedes-Benz  C-Class    33578  2018  32901
# 1      Mercedes-Benz  C-Class    23709  2018  33901
# 2      Mercedes-Benz  C-Class    39768  2018  32901
# 3      Mercedes-Benz  C-Class    20685  2018  34901
# 4      Mercedes-Benz  C-Class    28863  2018  30901
# ...              ...      ...      ...   ...    ...
# 10135            Kia     Soul    14748  2020  21998
# 10136         Nissan   Altima    21782  2018  18999
# 10137          Honda   Accord    30511  2018  26999
# 10138         Nissan    Rogue    89372  2016  17998
# 10139            BMW     X5 M   106455  2016  40999
#
# [10140 rows x 5 columns]

# %% [markdown]
# #### Excel File

# %%
merged_dataframes.to_excel('merged_dataframes.xlsx', index=False)

# %% [markdown]
# #### Connect to PostgreSQL

# %%
# create sqlalchemy engine

# postgres es el nombre de la base de datos
engine = create_engine('postgresql://postgres:dadax33@localhost:5432')
# merged_dataframe_cars es el nombre de la tabla 
merged_dataframes.to_sql('merged_dataframes_cars', engine)
