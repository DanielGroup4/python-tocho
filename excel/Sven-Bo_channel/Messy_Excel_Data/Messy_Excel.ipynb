# %% [markdown]
# # Read Messy Excel Data With Pandas 🐼

# %% [markdown]
# ## Quick and Easy Way (with `xlwings`)

# %%
# Install/Upgrade xlwings
# !pip install xlwings --upgrade --quiet
# Out:
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\Dael\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# Import xlwings
import xlwings as xw

# %%
# Loads the selected cell(s) of the active workbook into a pandas DataFrame. 
# If you don’t have pandas installed, it returns the values as nested lists.
df_quick = xw.load(index=False)
df_quick
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_5304/3801789525.py in <module>
#       1 # Loads the selected cell(s) of the active workbook into a pandas DataFrame.
#       2 # If you don’t have pandas installed, it returns the values as nested lists.
# ----> 3 df_quick = xw.load(index=False)
#       4 df_quick
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\xlwings\main.py in load(index, header, chunksize)
#    4548     .. versionchanged:: 0.23.1
#    4549     """
# -> 4550     selection = books.active.selection
#    4551     if selection.shape == (1, 1):
#    4552         selection = selection.current_region
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\xlwings\main.py in active(self)
#    4780         Returns the active Book.
#    4781         """
# -> 4782         return Book(impl=self.impl.active)
#    4783
#    4784     def add(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\xlwings\main.py in impl(self)
#    4959     @property
#    4960     def impl(self):
# -> 4961         return apps.active.books.impl
#    4962
#    4963
#
# AttributeError: 'NoneType' object has no attribute 'books'

# %% [markdown]
# ## Pandas read_excel()

# %% [markdown]
# ### Import & Set Up Filepath

# %%
# Install Libraries (if not installed yet)
# Openpyxl: Optional Pandas dependency to read/write Excel Files
# !pip install pandas --quiet 
# !pip install openpyxl --quiet

# %%
# Imports
import pandas as pd
from pathlib import Path

# %%
# Define File Path to Excel File
DATA_DIR = Path.cwd() / 'data'
file_path_messy_data = DATA_DIR / 'data_messy.xlsx'

# %% [markdown]
# ### pd.read_excel - Options

# %% [markdown]
# >**pandas.`read_excel`**(<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;io,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;sheet_name=0,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;header=0,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;usecols=None,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;true_values=None,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;skipfooter=0<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;converters=None,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;dtype=None,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;)

# %% [markdown]
# #### Without any additional options

# %%
# Read Excel without additional arguments
df = pd.read_excel(file_path_messy_data)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Get Sheet Names

# %%
# Get Sheets Names
xl = pd.ExcelFile(file_path_messy_data)
xl.sheet_names
# Out:
# ['Sheet1', 'Orders', 'Returns']

# %% [markdown]
# #### sheet_name

# %%
# Specify Sheet Name
df = pd.read_excel(file_path_messy_data,
                   sheet_name='Orders')
df.head()
# Out:
#    Unnamed: 0                  Unnamed: 1 Unnamed: 2          Unnamed: 3  \
# 0         NaN  Business Transactions 2020        NaN                 NaN
# 1         NaN                         NaN        NaN                 NaN
# 2         NaN                         NaN        NaN                 NaN
# 3         NaN                         NaN        NaN  Remarks from Jeff:
# 4         NaN                    Order ID   Returned             Remarks
#
#     Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8    Unnamed: 9  \
# 0          NaN        NaN         NaN        NaN        NaN           NaN
# 1          NaN        NaN         NaN        NaN        NaN           NaN
# 2          NaN        NaN         NaN        NaN        NaN           NaN
# 3          NaN        NaN         NaN        NaN        NaN           NaN
# 4  Postal Code        NaN  Product ID   Category        NaN  Product Name
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  Unnamed: 14  \
# 0         NaN         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN         NaN          NaN
# 4       Sales    Quantity    Discount      Profit          NaN
#
#       Unnamed: 15  Unnamed: 16   Unnamed: 17
# 0             NaN          NaN           NaN
# 1             NaN          NaN           NaN
# 2             NaN  Total Sales  Total Profit
# 3  Quick Summary:  733215.2552         12476
# 4             NaN          NaN           NaN

# %% [markdown]
# #### header

# %%
# Specify Row (0-indexed) to use for the column labels
df = pd.read_excel(file_path_messy_data,
                   sheet_name='Orders',
                   header=5)
df.head()
# Out:
#    Unnamed: 0        Order ID Returned        Remarks  Postal Code Unnamed: 5  \
# 0         NaN  CA-2017-114412      NaN            NaN      28027.0      South
# 1         NaN  US-2017-156909      NaN            NaN      19140.0       East
# 2         NaN  CA-2017-107727      NaN            NaN       7090.0    Central
# 3         NaN  CA-2017-120999      Yes  Need to check      60540.0    Central
# 4         NaN  CA-2017-139619      NaN            NaN       1852.0      South
#
#         Product ID         Category Unnamed: 8  \
# 0  OFF-PA-10002365  Office Supplies      Paper
# 1  FUR-CH-10002774        Furniture     Chairs
# 2  OFF-PA-10000249  Office Supplies      Paper
# 3  TEC-PH-10004093       Technology     Phones
# 4  OFF-ST-10003282  Office Supplies    Storage
#
#                                         Product Name    Sales  Quantity  \
# 0                                         Xerox 1967   15.552         3
# 1                 Global Deluxe Stacking Chair, Gray   71.372         2
# 2                                  Easy-staple paper   29.472         3
# 3                                 Panasonic Kx-TS550  147.168         4
# 4  Advantus 10-Drawer Portable Organizer, Chrome ...   95.616         2
#
#   Discount   Profit  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0      20%   5.4432          NaN          NaN          NaN          NaN
# 1      30%  -1.0196          NaN          NaN          NaN          NaN
# 2      20%   9.9468          NaN          NaN          NaN          NaN
# 3      20%  16.5564          NaN          NaN          NaN          NaN
# 4      20%   9.5616          NaN          NaN          NaN          NaN

# %% [markdown]
# #### usecols

# %%
# Indicate comma separated list of Excel column ranges (e.g. “A:E” or “A,C,E:F”). Ranges are inclusive of both sides
df = pd.read_excel(file_path_messy_data,
                   sheet_name='Orders',
                   header=5,
                   usecols='B:N')
df.head()
# Out:
#          Order ID Returned        Remarks  Postal Code Unnamed: 5  \
# 0  CA-2017-114412      NaN            NaN      28027.0      South
# 1  US-2017-156909      NaN            NaN      19140.0       East
# 2  CA-2017-107727      NaN            NaN       7090.0    Central
# 3  CA-2017-120999      Yes  Need to check      60540.0    Central
# 4  CA-2017-139619      NaN            NaN       1852.0      South
#
#         Product ID         Category Unnamed: 8  \
# 0  OFF-PA-10002365  Office Supplies      Paper
# 1  FUR-CH-10002774        Furniture     Chairs
# 2  OFF-PA-10000249  Office Supplies      Paper
# 3  TEC-PH-10004093       Technology     Phones
# 4  OFF-ST-10003282  Office Supplies    Storage
#
#                                         Product Name    Sales  Quantity  \
# 0                                         Xerox 1967   15.552         3
# 1                 Global Deluxe Stacking Chair, Gray   71.372         2
# 2                                  Easy-staple paper   29.472         3
# 3                                 Panasonic Kx-TS550  147.168         4
# 4  Advantus 10-Drawer Portable Organizer, Chrome ...   95.616         2
#
#   Discount   Profit
# 0      20%   5.4432
# 1      30%  -1.0196
# 2      20%   9.9468
# 3      20%  16.5564
# 4      20%   9.5616

# %%
# Select different column range
df = pd.read_excel(file_path_messy_data,
                   sheet_name='Orders',
                   header=5,
                   usecols='B:C,E:N')
df.head()
# Out:
#          Order ID Returned  Postal Code Unnamed: 5       Product ID  \
# 0  CA-2017-114412      NaN      28027.0      South  OFF-PA-10002365
# 1  US-2017-156909      NaN      19140.0       East  FUR-CH-10002774
# 2  CA-2017-107727      NaN       7090.0    Central  OFF-PA-10000249
# 3  CA-2017-120999      Yes      60540.0    Central  TEC-PH-10004093
# 4  CA-2017-139619      NaN       1852.0      South  OFF-ST-10003282
#
#           Category Unnamed: 8  \
# 0  Office Supplies      Paper
# 1        Furniture     Chairs
# 2  Office Supplies      Paper
# 3       Technology     Phones
# 4  Office Supplies    Storage
#
#                                         Product Name    Sales  Quantity  \
# 0                                         Xerox 1967   15.552         3
# 1                 Global Deluxe Stacking Chair, Gray   71.372         2
# 2                                  Easy-staple paper   29.472         3
# 3                                 Panasonic Kx-TS550  147.168         4
# 4  Advantus 10-Drawer Portable Organizer, Chrome ...   95.616         2
#
#   Discount   Profit
# 0      20%   5.4432
# 1      30%  -1.0196
# 2      20%   9.9468
# 3      20%  16.5564
# 4      20%   9.5616

# %% [markdown]
# #### true_values

# %%
# Specify values to consider as True.
df = pd.read_excel(file_path_messy_data,
                   sheet_name='Orders',
                   header=5,
                   usecols='B:C,E:N',
                   true_values=['Yes']
                   )
df.head()
# Out:
#          Order ID Returned  Postal Code Unnamed: 5       Product ID  \
# 0  CA-2017-114412      NaN      28027.0      South  OFF-PA-10002365
# 1  US-2017-156909      NaN      19140.0       East  FUR-CH-10002774
# 2  CA-2017-107727      NaN       7090.0    Central  OFF-PA-10000249
# 3  CA-2017-120999     True      60540.0    Central  TEC-PH-10004093
# 4  CA-2017-139619      NaN       1852.0      South  OFF-ST-10003282
#
#           Category Unnamed: 8  \
# 0  Office Supplies      Paper
# 1        Furniture     Chairs
# 2  Office Supplies      Paper
# 3       Technology     Phones
# 4  Office Supplies    Storage
#
#                                         Product Name    Sales  Quantity  \
# 0                                         Xerox 1967   15.552         3
# 1                 Global Deluxe Stacking Chair, Gray   71.372         2
# 2                                  Easy-staple paper   29.472         3
# 3                                 Panasonic Kx-TS550  147.168         4
# 4  Advantus 10-Drawer Portable Organizer, Chrome ...   95.616         2
#
#   Discount   Profit
# 0      20%   5.4432
# 1      30%  -1.0196
# 2      20%   9.9468
# 3      20%  16.5564
# 4      20%   9.5616

# %%
# Check last entry of DataFrame
df.tail()
# Out:
#             Order ID Returned  Postal Code Unnamed: 5       Product ID  \
# 3308  CA-2017-121258     True      92627.0       West  FUR-FU-10000747
# 3309  CA-2017-121258     True      92627.0       West  TEC-PH-10003645
# 3310  CA-2017-121258     True      92627.0       West  OFF-PA-10004041
# 3311  CA-2017-119914      NaN      92683.0       West  OFF-AP-10002684
# 3312             NaN      NaN          NaN        NaN              NaN
#
#              Category   Unnamed: 8  \
# 3308        Furniture  Furnishings
# 3309       Technology       Phones
# 3310  Office Supplies        Paper
# 3311  Office Supplies   Appliances
# 3312              NaN          NaN
#
#                                            Product Name        Sales  \
# 3308  Tenex B1-RE Series Chair Mats for Low Pile Car...      91.9600
# 3309                              Aastra 57i VoIP phone     258.5760
# 3310  It's Hot Message Books with Stickers, 2 3/4" x 5"      29.6000
# 3311  Acco 7-Outlet Masterpiece Power Center, Wihtou...     243.1600
# 3312                                              Total  733215.2552
#
#       Quantity Discount      Profit
# 3308         2       0%     15.6332
# 3309         2      20%     19.3932
# 3310         4       0%     13.3200
# 3311         2       0%     72.9480
# 3312     12476      NaN  93439.2696

# %% [markdown]
# #### skipfooter

# %%
# Rows at the end to skip 
df = pd.read_excel(file_path_messy_data,
                   sheet_name='Orders',
                   header=5,
                   usecols='B:C,E:N',
                   true_values=['Yes'],
                   skipfooter = 2
                   )
df.tail()
# Out:
#             Order ID Returned  Postal Code Unnamed: 5       Product ID  \
# 3306  CA-2017-163629      NaN        30605      South  TEC-AC-10001539
# 3307  CA-2017-163629      NaN        30605      South  TEC-PH-10004006
# 3308  CA-2017-121258     True        92627       West  FUR-FU-10000747
# 3309  CA-2017-121258     True        92627       West  TEC-PH-10003645
# 3310  CA-2017-121258     True        92627       West  OFF-PA-10004041
#
#              Category   Unnamed: 8  \
# 3306       Technology  Accessories
# 3307       Technology       Phones
# 3308        Furniture  Furnishings
# 3309       Technology       Phones
# 3310  Office Supplies        Paper
#
#                                            Product Name    Sales  Quantity  \
# 3306  Logitech G430 Surround Sound Gaming Headset wi...   79.990         1
# 3307                    Panasonic KX - TS880B Telephone  206.100         5
# 3308  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 3309                              Aastra 57i VoIP phone  258.576         2
# 3310  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
#
#      Discount   Profit
# 3306       0%  28.7964
# 3307       0%  55.6470
# 3308       0%  15.6332
# 3309      20%  19.3932
# 3310       0%  13.3200

# %% [markdown]
# #### converters

# %%
# Print a concise summary of the DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3311 entries, 0 to 3310
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      3311 non-null   object
#  1   Returned      288 non-null    object
#  2   Postal Code   3311 non-null   int64
#  3   Unnamed: 5    3311 non-null   object
#  4   Product ID    3311 non-null   object
#  5   Category      3311 non-null   object
#  6   Unnamed: 8    3311 non-null   object
#  7   Product Name  3311 non-null   object
#  8   Sales         3311 non-null   float64
#  9   Quantity      3311 non-null   int64
#  10  Discount      3311 non-null   object
#  11  Profit        3311 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 310.5+ KB

# %%
# Discount is currently an 'object' (string)
df['Discount'].iloc[0]
# Out:
# '20%'

# %%
# Check type
type(df['Discount'].iloc[0])
# Out:
# str

# %%
# String cannot perform math operations
'20%' * 2
# Out:
# '20%20%'

# %%
# Convert %-column to float; Step-by-Step
discount = '20%'
discount = discount.replace('%','')
discount = float(discount) / 100
discount
# Out:
# 0.2

# %%
# Create Function to covert % to float
def convert_discount(row):
    '''Convert string (%) to float'''
    pct_value = row.replace('%','')
    pct_value = float(pct_value) / 100
    return pct_value

# %%
# Converters: Dict of functions for converting values in certain columns
df = pd.read_excel(file_path_messy_data,
                   sheet_name='Orders',
                   header=5,
                   usecols='B:C,E:N',
                   true_values=['Yes'],
                   skipfooter = 2,
                   converters={'Discount': convert_discount}
                   )
df.head()
# Out:
#          Order ID Returned  Postal Code Unnamed: 5       Product ID  \
# 0  CA-2017-114412      NaN        28027      South  OFF-PA-10002365
# 1  US-2017-156909      NaN        19140       East  FUR-CH-10002774
# 2  CA-2017-107727      NaN         7090    Central  OFF-PA-10000249
# 3  CA-2017-120999     True        60540    Central  TEC-PH-10004093
# 4  CA-2017-139619      NaN         1852      South  OFF-ST-10003282
#
#           Category Unnamed: 8  \
# 0  Office Supplies      Paper
# 1        Furniture     Chairs
# 2  Office Supplies      Paper
# 3       Technology     Phones
# 4  Office Supplies    Storage
#
#                                         Product Name    Sales  Quantity  \
# 0                                         Xerox 1967   15.552         3
# 1                 Global Deluxe Stacking Chair, Gray   71.372         2
# 2                                  Easy-staple paper   29.472         3
# 3                                 Panasonic Kx-TS550  147.168         4
# 4  Advantus 10-Drawer Portable Organizer, Chrome ...   95.616         2
#
#    Discount   Profit
# 0       0.2   5.4432
# 1       0.3  -1.0196
# 2       0.2   9.9468
# 3       0.2  16.5564
# 4       0.2   9.5616

# %% [markdown]
# #### dtype

# %%
# Print a concise summary of the DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3311 entries, 0 to 3310
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      3311 non-null   object
#  1   Returned      288 non-null    object
#  2   Postal Code   3311 non-null   int64
#  3   Unnamed: 5    3311 non-null   object
#  4   Product ID    3311 non-null   object
#  5   Category      3311 non-null   object
#  6   Unnamed: 8    3311 non-null   object
#  7   Product Name  3311 non-null   object
#  8   Sales         3311 non-null   float64
#  9   Quantity      3311 non-null   int64
#  10  Discount      3311 non-null   float64
#  11  Profit        3311 non-null   float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 310.5+ KB

# %%
# Specify data type for columns.
df = pd.read_excel(file_path_messy_data,
                   sheet_name='Orders',
                   header=5,
                   usecols='B:C,E:N',
                   true_values=['Yes'],
                   skipfooter = 2,
                   converters={'Discount': convert_discount},
                   dtype={'Postal Code':'object'}                   
                   )
df.head()
# Out:
#          Order ID Returned Postal Code Unnamed: 5       Product ID  \
# 0  CA-2017-114412      NaN       28027      South  OFF-PA-10002365
# 1  US-2017-156909      NaN       19140       East  FUR-CH-10002774
# 2  CA-2017-107727      NaN       07090    Central  OFF-PA-10000249
# 3  CA-2017-120999     True       60540    Central  TEC-PH-10004093
# 4  CA-2017-139619      NaN       01852      South  OFF-ST-10003282
#
#           Category Unnamed: 8  \
# 0  Office Supplies      Paper
# 1        Furniture     Chairs
# 2  Office Supplies      Paper
# 3       Technology     Phones
# 4  Office Supplies    Storage
#
#                                         Product Name    Sales  Quantity  \
# 0                                         Xerox 1967   15.552         3
# 1                 Global Deluxe Stacking Chair, Gray   71.372         2
# 2                                  Easy-staple paper   29.472         3
# 3                                 Panasonic Kx-TS550  147.168         4
# 4  Advantus 10-Drawer Portable Organizer, Chrome ...   95.616         2
#
#    Discount   Profit
# 0       0.2   5.4432
# 1       0.3  -1.0196
# 2       0.2   9.9468
# 3       0.2  16.5564
# 4       0.2   9.5616

# %% [markdown]
# ## Additional Clean Up of Columns

# %%
# Convert nan-values to False
df.fillna(False, inplace=True)
df.head()
# Out:
#          Order ID  Returned Postal Code Unnamed: 5       Product ID  \
# 0  CA-2017-114412     False       28027      South  OFF-PA-10002365
# 1  US-2017-156909     False       19140       East  FUR-CH-10002774
# 2  CA-2017-107727     False       07090    Central  OFF-PA-10000249
# 3  CA-2017-120999      True       60540    Central  TEC-PH-10004093
# 4  CA-2017-139619     False       01852      South  OFF-ST-10003282
#
#           Category Unnamed: 8  \
# 0  Office Supplies      Paper
# 1        Furniture     Chairs
# 2  Office Supplies      Paper
# 3       Technology     Phones
# 4  Office Supplies    Storage
#
#                                         Product Name    Sales  Quantity  \
# 0                                         Xerox 1967   15.552         3
# 1                 Global Deluxe Stacking Chair, Gray   71.372         2
# 2                                  Easy-staple paper   29.472         3
# 3                                 Panasonic Kx-TS550  147.168         4
# 4  Advantus 10-Drawer Portable Organizer, Chrome ...   95.616         2
#
#    Discount   Profit
# 0       0.2   5.4432
# 1       0.3  -1.0196
# 2       0.2   9.9468
# 3       0.2  16.5564
# 4       0.2   9.5616

# %%
# Rename unnamed columns
df = df.rename(columns={"Unnamed: 5": "Region",
                        "Unnamed: 8": "Sub-Category"})
df.head()
# Out:
#          Order ID  Returned Postal Code   Region       Product ID  \
# 0  CA-2017-114412     False       28027    South  OFF-PA-10002365
# 1  US-2017-156909     False       19140     East  FUR-CH-10002774
# 2  CA-2017-107727     False       07090  Central  OFF-PA-10000249
# 3  CA-2017-120999      True       60540  Central  TEC-PH-10004093
# 4  CA-2017-139619     False       01852    South  OFF-ST-10003282
#
#           Category Sub-Category  \
# 0  Office Supplies        Paper
# 1        Furniture       Chairs
# 2  Office Supplies        Paper
# 3       Technology       Phones
# 4  Office Supplies      Storage
#
#                                         Product Name    Sales  Quantity  \
# 0                                         Xerox 1967   15.552         3
# 1                 Global Deluxe Stacking Chair, Gray   71.372         2
# 2                                  Easy-staple paper   29.472         3
# 3                                 Panasonic Kx-TS550  147.168         4
# 4  Advantus 10-Drawer Portable Organizer, Chrome ...   95.616         2
#
#    Discount   Profit
# 0       0.2   5.4432
# 1       0.3  -1.0196
# 2       0.2   9.9468
# 3       0.2  16.5564
# 4       0.2   9.5616

# %%
# Drop duplicates (if any)
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 🚩 Export back to Excel

# %%
# Define File Path
file_path_cleaned_data = DATA_DIR / 'data_cleaned.xlsx'

# %%
# Export DataFrame to Excel
df.to_excel(file_path_cleaned_data,
            sheet_name='Cleaned_Data',
            index=False)
